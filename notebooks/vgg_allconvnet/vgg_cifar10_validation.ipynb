# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar10_vgg_model/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/test_batch.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=10, training=False)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= 50
        validation_accuracy /= 50
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(15)
# Out:
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1
# INFO:tensorflow:loss: 18.051, best accuracy: 0.102
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-90
# INFO:tensorflow:loss: 14.414, best accuracy: 0.102
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-181
# INFO:tensorflow:loss: 13.342, best accuracy: 0.162
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-270
# INFO:tensorflow:loss: 12.542, best accuracy: 0.213
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-359
# INFO:tensorflow:loss: 11.710, best accuracy: 0.268
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-535
# INFO:tensorflow:loss: 10.326, best accuracy: 0.312
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-621
# INFO:tensorflow:loss: 9.754, best accuracy: 0.319
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-707
# INFO:tensorflow:loss: 9.128, best accuracy: 0.359
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-793
# INFO:tensorflow:loss: 8.588, best accuracy: 0.385
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-880
# INFO:tensorflow:loss: 8.387, best accuracy: 0.287
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-968
# INFO:tensorflow:loss: 7.626, best accuracy: 0.398
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1056
# INFO:tensorflow:loss: 7.169, best accuracy: 0.426
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1144
# INFO:tensorflow:loss: 6.781, best accuracy: 0.434
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1232
# INFO:tensorflow:loss: 6.405, best accuracy: 0.433
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1406
# INFO:tensorflow:loss: 5.794, best accuracy: 0.442
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1491
# INFO:tensorflow:loss: 5.492, best accuracy: 0.443
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1576
# INFO:tensorflow:loss: 5.156, best accuracy: 0.474
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1662
# INFO:tensorflow:loss: 4.846, best accuracy: 0.502
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1747
# INFO:tensorflow:loss: 4.629, best accuracy: 0.487
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1834
# INFO:tensorflow:loss: 4.475, best accuracy: 0.473
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-1921
# INFO:tensorflow:loss: 4.171, best accuracy: 0.506
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2008
# INFO:tensorflow:loss: 4.109, best accuracy: 0.478
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2095
# INFO:tensorflow:loss: 3.783, best accuracy: 0.522
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2269
# INFO:tensorflow:loss: 3.466, best accuracy: 0.526
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2354
# INFO:tensorflow:loss: 3.275, best accuracy: 0.552
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2439
# INFO:tensorflow:loss: 3.190, best accuracy: 0.531
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2524
# INFO:tensorflow:loss: 3.025, best accuracy: 0.557
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2610
# INFO:tensorflow:loss: 2.877, best accuracy: 0.567
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2697
# INFO:tensorflow:loss: 2.717, best accuracy: 0.588
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2784
# INFO:tensorflow:loss: 2.686, best accuracy: 0.563
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2871
# INFO:tensorflow:loss: 2.539, best accuracy: 0.580
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-2958
# INFO:tensorflow:loss: 2.399, best accuracy: 0.605
# INFO:tensorflow:Loading checkpoint cifar10_vgg_model/model.ckpt-3131
