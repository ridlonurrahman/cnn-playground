# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar100_vgg_model2/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50#int(50000/batch_size)
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar100', '../../cifar/cifar100/test.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=100)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= eval_batch_count
        validation_accuracy /= eval_batch_count
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(5)
# Out:
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1
# INFO:tensorflow:loss: 7.165, best accuracy: 0.011
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-73
# INFO:tensorflow:loss: 6.923, best accuracy: 0.036
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-144
# INFO:tensorflow:loss: 6.728, best accuracy: 0.053
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-144
# INFO:tensorflow:loss: 6.745, best accuracy: 0.051
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-216
# INFO:tensorflow:loss: 6.531, best accuracy: 0.071
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-286
# INFO:tensorflow:loss: 6.435, best accuracy: 0.087
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-355
# INFO:tensorflow:loss: 6.334, best accuracy: 0.095
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-424
# INFO:tensorflow:loss: 6.254, best accuracy: 0.098
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-493
# INFO:tensorflow:loss: 6.127, best accuracy: 0.125
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-562
# INFO:tensorflow:loss: 6.036, best accuracy: 0.128
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-633
# INFO:tensorflow:loss: 5.961, best accuracy: 0.135
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-633
# INFO:tensorflow:loss: 5.955, best accuracy: 0.136
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-702
# INFO:tensorflow:loss: 5.870, best accuracy: 0.147
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-771
# INFO:tensorflow:loss: 5.742, best accuracy: 0.162
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-839
# INFO:tensorflow:loss: 5.691, best accuracy: 0.171
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-907
# INFO:tensorflow:loss: 5.623, best accuracy: 0.179
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-974
# INFO:tensorflow:loss: 5.542, best accuracy: 0.185
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1044
# INFO:tensorflow:loss: 5.442, best accuracy: 0.198
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1044
# INFO:tensorflow:loss: 5.434, best accuracy: 0.203
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1114
# INFO:tensorflow:loss: 5.363, best accuracy: 0.215
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1181
# INFO:tensorflow:loss: 5.294, best accuracy: 0.223
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1248
# INFO:tensorflow:loss: 5.213, best accuracy: 0.228
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1316
# INFO:tensorflow:loss: 5.155, best accuracy: 0.239
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1384
# INFO:tensorflow:loss: 5.074, best accuracy: 0.247
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1452
# INFO:tensorflow:loss: 5.047, best accuracy: 0.249
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1522
# INFO:tensorflow:loss: 4.959, best accuracy: 0.263
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1522
# INFO:tensorflow:loss: 4.962, best accuracy: 0.267
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1590
# INFO:tensorflow:loss: 4.917, best accuracy: 0.264
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1657
# INFO:tensorflow:loss: 4.845, best accuracy: 0.273
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1723
# INFO:tensorflow:loss: 4.801, best accuracy: 0.282
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1791
# INFO:tensorflow:loss: 4.751, best accuracy: 0.286
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1858
# INFO:tensorflow:loss: 4.711, best accuracy: 0.292
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1927
# INFO:tensorflow:loss: 4.700, best accuracy: 0.287
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1927
# INFO:tensorflow:loss: 4.702, best accuracy: 0.285
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1996
# INFO:tensorflow:loss: 4.668, best accuracy: 0.295
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2063
# INFO:tensorflow:loss: 4.619, best accuracy: 0.297
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2129
# INFO:tensorflow:loss: 4.538, best accuracy: 0.310
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2196
