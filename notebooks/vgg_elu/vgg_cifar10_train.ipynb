# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from datetime import datetime
from train import *
from loss import *
from accuracy import *
from model import *

import cifar_input
import os.path
import time
import numpy as np
import tensorflow as tf

# %%
max_steps = 500000
train_dir = 'cifar10_vgg_model2/'
batch_size = 128
log_device_placement = False

# %%
with tf.Graph().as_default():
    global_step = tf.contrib.framework.get_or_create_global_step()
    
    # Generating images and its labels
    # build_inputs('cifar10/cifar100', cifar dataset dir, batch size, mode)
    images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/data_batch*', batch_size, 'train')
    
    # Creating graph. NUM_CLASESS=10 (CIFAR-10) or NUM_CLASESS=100 (CIFAR-100)
    logits = inference(images, NUM_CLASSES=10)
    
    # Loss/Error and Accuracy
    losses = loss(logits, labels)
    accuracies = accuracy(logits, labels)
    
    # Our train_op (Only minimizing loss)
    train_op = train(losses, global_step, batch_size)
    
    
    # SessionRunHook. Logging will be done each x steps.
    class _LoggerHook(tf.train.SessionRunHook):
        
      def begin(self):
        self._step = -1
        # Creating train_dir if it does not exist and writing to log file
        if not os.path.exists(train_dir):
            os.makedirs(train_dir)
        open(train_dir+'training_data.csv', 'w').close()
        f = open(train_dir+"log.txt",'ab')
        f.write('\n\n==== Run ===\nInfo: VGG\n')
        f.close()

      def before_run(self, run_context):
        # Increment step, reset start_time, and asking for loss and accuracy tensor
        self._step += 1
        self._start_time = time.time()
        return tf.train.SessionRunArgs([losses, accuracies])

      def after_run(self, run_context, run_values):
        duration = time.time() - self._start_time # Calculating time
        loss_value = run_values.results[0]
        accuracy_value = run_values.results[1]
        # Printing log, accuracy, and loss
        if self._step % 10 == 0:
          print("{0}: step {1}, error = {2:.4f}, accuracy = {3:.4f}. ({4:.3f} sec/step)\n".format(
              datetime.now(), self._step, loss_value, accuracy_value, float(duration)))
                
          f = open(train_dir+"log.txt",'ab')
          f.write("{0}: step {1}, error = {2:.4f}, accuracy = {3:.4f}. ({4:.3f} sec/step)\n".format(
              datetime.now(), self._step, loss_value, accuracy_value, float(duration)))
          f.close()
                
          f = open(train_dir+"training_data.csv",'ab')
          f.write('{0},{1},{2}\n'.format(self._step, loss_value, accuracy_value))
          f.close()
            
    with tf.train.MonitoredTrainingSession(checkpoint_dir=train_dir,
                                           hooks=[tf.train.StopAtStepHook(last_step=max_steps),
                                                  tf.train.NanTensorHook(losses),
                                                  _LoggerHook()],save_checkpoint_secs=30, 
                                           config=tf.ConfigProto(
                                               log_device_placement=log_device_placement)) as mon_sess:
        while not mon_sess.should_stop():
            mon_sess.run(train_op)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:35:52.853589: step 0, error = 4.8358, accuracy = 0.0859. (3.472 sec/step)
#
# 2017-03-16 13:35:55.684678: step 10, error = 5.1074, accuracy = 0.2031. (0.336 sec/step)
#
# 2017-03-16 13:35:59.168293: step 20, error = 5.4176, accuracy = 0.1562. (0.333 sec/step)
#
# 2017-03-16 13:36:03.397333: step 30, error = 5.1448, accuracy = 0.1641. (0.438 sec/step)
#
# 2017-03-16 13:36:07.534616: step 40, error = 4.9131, accuracy = 0.1953. (0.434 sec/step)
#
# 2017-03-16 13:36:11.655467: step 50, error = 4.9711, accuracy = 0.2266. (0.398 sec/step)
#
# 2017-03-16 13:36:15.932149: step 60, error = 4.6127, accuracy = 0.2812. (0.436 sec/step)
#
# 2017-03-16 13:36:20.097891: step 70, error = 4.5922, accuracy = 0.2891. (0.358 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 78 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:36:23.644583: step 80, error = 4.7797, accuracy = 0.2812. (0.217 sec/step)
#
# 2017-03-16 13:36:26.853281: step 90, error = 4.6620, accuracy = 0.2500. (0.326 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.63992
# 2017-03-16 13:36:30.150655: step 100, error = 4.6141, accuracy = 0.2266. (0.323 sec/step)
#
# 2017-03-16 13:36:33.475762: step 110, error = 4.8142, accuracy = 0.2344. (0.333 sec/step)
#
# 2017-03-16 13:36:37.200430: step 120, error = 4.4885, accuracy = 0.3281. (0.392 sec/step)
#
# 2017-03-16 13:36:41.355416: step 130, error = 4.6505, accuracy = 0.3438. (0.406 sec/step)
#
# 2017-03-16 13:36:45.494777: step 140, error = 4.4871, accuracy = 0.2969. (0.413 sec/step)
#
# 2017-03-16 13:36:49.707745: step 150, error = 4.3229, accuracy = 0.3281. (0.406 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 158 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:36:54.067958: step 160, error = 4.8391, accuracy = 0.2734. (0.361 sec/step)
#
# 2017-03-16 13:36:57.654464: step 170, error = 4.4609, accuracy = 0.3516. (0.311 sec/step)
#
# 2017-03-16 13:37:01.000623: step 180, error = 4.3036, accuracy = 0.3438. (0.336 sec/step)
#
# 2017-03-16 13:37:04.292955: step 190, error = 4.5033, accuracy = 0.3281. (0.322 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.6671
# 2017-03-16 13:37:07.646499: step 200, error = 4.2908, accuracy = 0.3984. (0.347 sec/step)
#
# 2017-03-16 13:37:11.191237: step 210, error = 4.3491, accuracy = 0.3438. (0.439 sec/step)
#
# 2017-03-16 13:37:15.390737: step 220, error = 4.8151, accuracy = 0.2578. (0.414 sec/step)
#
# 2017-03-16 13:37:19.504843: step 230, error = 4.3525, accuracy = 0.3125. (0.396 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 239 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:37:24.191988: step 240, error = 4.2861, accuracy = 0.3672. (0.326 sec/step)
#
# 2017-03-16 13:37:28.306966: step 250, error = 4.4287, accuracy = 0.3438. (0.441 sec/step)
#
# 2017-03-16 13:37:32.009244: step 260, error = 4.2645, accuracy = 0.3984. (0.350 sec/step)
#
# 2017-03-16 13:37:35.319611: step 270, error = 4.2952, accuracy = 0.3984. (0.319 sec/step)
#
# 2017-03-16 13:37:38.670749: step 280, error = 4.3728, accuracy = 0.3828. (0.316 sec/step)
#
# 2017-03-16 13:37:41.996718: step 290, error = 4.0493, accuracy = 0.4141. (0.327 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.6496
# 2017-03-16 13:37:45.386623: step 300, error = 4.1704, accuracy = 0.3906. (0.382 sec/step)
#
# 2017-03-16 13:37:49.647505: step 310, error = 4.0728, accuracy = 0.4609. (0.412 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 319 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:37:54.437476: step 320, error = 4.1301, accuracy = 0.4531. (0.244 sec/step)
#
# 2017-03-16 13:37:58.386037: step 330, error = 4.1800, accuracy = 0.4375. (0.427 sec/step)
#
# 2017-03-16 13:38:02.594585: step 340, error = 4.2567, accuracy = 0.3594. (0.413 sec/step)
#
# 2017-03-16 13:38:06.480542: step 350, error = 3.9706, accuracy = 0.4766. (0.322 sec/step)
#
# 2017-03-16 13:38:09.820415: step 360, error = 4.2496, accuracy = 0.4375. (0.333 sec/step)
#
# 2017-03-16 13:38:13.177564: step 370, error = 4.1286, accuracy = 0.3984. (0.344 sec/step)
#
# 2017-03-16 13:38:16.484245: step 380, error = 4.0101, accuracy = 0.4766. (0.328 sec/step)
#
# 2017-03-16 13:38:19.805839: step 390, error = 4.1062, accuracy = 0.3672. (0.327 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 400 into cifar10_vgg_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.55865
# 2017-03-16 13:38:24.469184: step 400, error = 3.9518, accuracy = 0.4219. (0.336 sec/step)
#
# 2017-03-16 13:38:28.334980: step 410, error = 3.8695, accuracy = 0.4844. (0.425 sec/step)
#
# 2017-03-16 13:38:32.586850: step 420, error = 3.9382, accuracy = 0.4453. (0.401 sec/step)
#
# 2017-03-16 13:38:36.702675: step 430, error = 3.8364, accuracy = 0.5000. (0.400 sec/step)
#
# 2017-03-16 13:38:40.789340: step 440, error = 4.0740, accuracy = 0.4062. (0.377 sec/step)
#
# 2017-03-16 13:38:44.058644: step 450, error = 3.9885, accuracy = 0.4453. (0.332 sec/step)
#
# 2017-03-16 13:38:47.375568: step 460, error = 4.0845, accuracy = 0.4062. (0.345 sec/step)
#
# 2017-03-16 13:38:50.686787: step 470, error = 3.7491, accuracy = 0.5156. (0.326 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 480 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:38:54.419202: step 480, error = 3.8580, accuracy = 0.4922. (0.226 sec/step)
#
# 2017-03-16 13:38:58.211005: step 490, error = 3.9293, accuracy = 0.4531. (0.396 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.6372
# 2017-03-16 13:39:02.388408: step 500, error = 3.7990, accuracy = 0.4531. (0.406 sec/step)
#
# 2017-03-16 13:39:06.555200: step 510, error = 3.9978, accuracy = 0.4062. (0.409 sec/step)
#
# 2017-03-16 13:39:10.752887: step 520, error = 3.7604, accuracy = 0.4609. (0.458 sec/step)
#
# 2017-03-16 13:39:14.960862: step 530, error = 3.7908, accuracy = 0.4766. (0.418 sec/step)
#
# 2017-03-16 13:39:18.435375: step 540, error = 3.7342, accuracy = 0.4922. (0.324 sec/step)
#
# 2017-03-16 13:39:21.769735: step 550, error = 3.9820, accuracy = 0.4062. (0.332 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 557 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:39:25.250172: step 560, error = 3.7484, accuracy = 0.5078. (0.328 sec/step)
#
# 2017-03-16 13:39:28.559926: step 570, error = 3.7490, accuracy = 0.5078. (0.341 sec/step)
#
# 2017-03-16 13:39:32.158505: step 580, error = 3.8635, accuracy = 0.4766. (0.457 sec/step)
#
# 2017-03-16 13:39:36.391048: step 590, error = 3.7054, accuracy = 0.5312. (0.470 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61766
# 2017-03-16 13:39:40.592196: step 600, error = 3.9536, accuracy = 0.3672. (0.439 sec/step)
#
# 2017-03-16 13:39:44.821620: step 610, error = 3.7553, accuracy = 0.4922. (0.420 sec/step)
#
# 2017-03-16 13:39:49.034060: step 620, error = 3.7845, accuracy = 0.4766. (0.427 sec/step)
#
# 2017-03-16 13:39:52.780604: step 630, error = 3.7140, accuracy = 0.4922. (0.345 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 635 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:39:56.202483: step 640, error = 3.9450, accuracy = 0.4688. (0.334 sec/step)
#
# 2017-03-16 13:39:59.529678: step 650, error = 3.6385, accuracy = 0.4766. (0.328 sec/step)
#
# 2017-03-16 13:40:02.860997: step 660, error = 3.7210, accuracy = 0.5000. (0.348 sec/step)
#
# 2017-03-16 13:40:06.214012: step 670, error = 3.6312, accuracy = 0.5391. (0.345 sec/step)
#
# 2017-03-16 13:40:10.333999: step 680, error = 3.4731, accuracy = 0.5625. (0.430 sec/step)
#
# 2017-03-16 13:40:14.567142: step 690, error = 3.5536, accuracy = 0.4688. (0.411 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61411
# 2017-03-16 13:40:18.844066: step 700, error = 3.7872, accuracy = 0.4609. (0.447 sec/step)
#
# 2017-03-16 13:40:22.997711: step 710, error = 3.7673, accuracy = 0.4531. (0.449 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 714 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:40:27.213639: step 720, error = 3.7402, accuracy = 0.4688. (0.323 sec/step)
#
# 2017-03-16 13:40:30.552063: step 730, error = 3.5956, accuracy = 0.5156. (0.326 sec/step)
#
# 2017-03-16 13:40:33.869170: step 740, error = 3.6880, accuracy = 0.5000. (0.319 sec/step)
#
# 2017-03-16 13:40:37.178032: step 750, error = 3.4382, accuracy = 0.6484. (0.323 sec/step)
#
# 2017-03-16 13:40:40.474262: step 760, error = 3.6285, accuracy = 0.4844. (0.319 sec/step)
#
# 2017-03-16 13:40:44.370746: step 770, error = 3.5769, accuracy = 0.5000. (0.423 sec/step)
#
# 2017-03-16 13:40:48.553939: step 780, error = 3.3900, accuracy = 0.6250. (0.367 sec/step)
#
# 2017-03-16 13:40:52.806720: step 790, error = 3.6070, accuracy = 0.5156. (0.413 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 795 into cifar10_vgg_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.60237
# 2017-03-16 13:40:57.271108: step 800, error = 3.3066, accuracy = 0.6406. (0.439 sec/step)
#
# 2017-03-16 13:41:01.461800: step 810, error = 3.5277, accuracy = 0.5469. (0.411 sec/step)
#
# 2017-03-16 13:41:04.841955: step 820, error = 3.6941, accuracy = 0.5234. (0.328 sec/step)
#
# 2017-03-16 13:41:08.147414: step 830, error = 3.6945, accuracy = 0.4844. (0.333 sec/step)
#
# 2017-03-16 13:41:11.472558: step 840, error = 3.5157, accuracy = 0.4844. (0.333 sec/step)
#
# 2017-03-16 13:41:14.792241: step 850, error = 3.4306, accuracy = 0.5938. (0.341 sec/step)
#
# 2017-03-16 13:41:18.451891: step 860, error = 3.5762, accuracy = 0.5156. (0.402 sec/step)
#
# 2017-03-16 13:41:22.614853: step 870, error = 3.2681, accuracy = 0.6250. (0.390 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 876 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:41:27.053125: step 880, error = 3.5388, accuracy = 0.5859. (0.417 sec/step)
#
# 2017-03-16 13:41:31.296201: step 890, error = 3.2974, accuracy = 0.5938. (0.420 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61313
# 2017-03-16 13:41:35.539331: step 900, error = 3.4527, accuracy = 0.5547. (0.410 sec/step)
#
# 2017-03-16 13:41:39.207590: step 910, error = 3.2317, accuracy = 0.6094. (0.322 sec/step)
#
# 2017-03-16 13:41:42.527590: step 920, error = 3.3556, accuracy = 0.5938. (0.319 sec/step)
#
# 2017-03-16 13:41:45.827381: step 930, error = 3.4649, accuracy = 0.5391. (0.333 sec/step)
#
# 2017-03-16 13:41:49.144881: step 940, error = 3.5301, accuracy = 0.6016. (0.333 sec/step)
#
# 2017-03-16 13:41:52.590933: step 950, error = 3.4204, accuracy = 0.5625. (0.410 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 957 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:41:57.199677: step 960, error = 3.3013, accuracy = 0.6016. (0.369 sec/step)
#
# 2017-03-16 13:42:01.310051: step 970, error = 3.3819, accuracy = 0.5938. (0.399 sec/step)
#
# 2017-03-16 13:42:05.601244: step 980, error = 3.4519, accuracy = 0.5781. (0.426 sec/step)
#
# 2017-03-16 13:42:09.875414: step 990, error = 3.3678, accuracy = 0.5781. (0.444 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.62625
# 2017-03-16 13:42:13.616284: step 1000, error = 3.5426, accuracy = 0.5391. (0.338 sec/step)
#
# 2017-03-16 13:42:16.929684: step 1010, error = 3.5122, accuracy = 0.5156. (0.325 sec/step)
#
# 2017-03-16 13:42:20.260794: step 1020, error = 3.3076, accuracy = 0.6250. (0.349 sec/step)
#
# 2017-03-16 13:42:23.586636: step 1030, error = 3.4486, accuracy = 0.5469. (0.347 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1036 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:42:26.985486: step 1040, error = 3.5006, accuracy = 0.5703. (0.288 sec/step)
#
# 2017-03-16 13:42:31.193104: step 1050, error = 3.3051, accuracy = 0.5547. (0.405 sec/step)
#
# 2017-03-16 13:42:35.536029: step 1060, error = 3.3596, accuracy = 0.5859. (0.443 sec/step)
#
# 2017-03-16 13:42:39.815113: step 1070, error = 3.2291, accuracy = 0.6406. (0.414 sec/step)
#
# 2017-03-16 13:42:44.133261: step 1080, error = 3.3288, accuracy = 0.5781. (0.427 sec/step)
#
# 2017-03-16 13:42:48.137327: step 1090, error = 3.2394, accuracy = 0.6562. (0.335 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.64326
# 2017-03-16 13:42:51.448431: step 1100, error = 3.1975, accuracy = 0.6172. (0.333 sec/step)
#
# 2017-03-16 13:42:54.844408: step 1110, error = 3.2283, accuracy = 0.6328. (0.335 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1113 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:42:58.455882: step 1120, error = 3.2252, accuracy = 0.6719. (0.327 sec/step)
#
# 2017-03-16 13:43:01.800236: step 1130, error = 3.1674, accuracy = 0.6484. (0.343 sec/step)
#
# 2017-03-16 13:43:05.884564: step 1140, error = 3.2577, accuracy = 0.5938. (0.464 sec/step)
#
# 2017-03-16 13:43:10.085333: step 1150, error = 3.1401, accuracy = 0.6953. (0.436 sec/step)
#
# 2017-03-16 13:43:14.525875: step 1160, error = 3.1726, accuracy = 0.6094. (0.448 sec/step)
#
# 2017-03-16 13:43:18.784353: step 1170, error = 3.0932, accuracy = 0.6641. (0.439 sec/step)
#
# 2017-03-16 13:43:22.939774: step 1180, error = 3.1039, accuracy = 0.5938. (0.380 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1189 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:43:26.573973: step 1190, error = 3.0593, accuracy = 0.6953. (0.227 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61714
# 2017-03-16 13:43:29.658089: step 1200, error = 3.0794, accuracy = 0.6484. (0.337 sec/step)
#
# 2017-03-16 13:43:32.954375: step 1210, error = 3.2583, accuracy = 0.6094. (0.325 sec/step)
#
# 2017-03-16 13:43:36.305405: step 1220, error = 3.0439, accuracy = 0.6953. (0.335 sec/step)
#
# 2017-03-16 13:43:40.147932: step 1230, error = 3.1479, accuracy = 0.6953. (0.411 sec/step)
#
# 2017-03-16 13:43:44.408886: step 1240, error = 3.0818, accuracy = 0.6250. (0.409 sec/step)
#
# 2017-03-16 13:43:48.654031: step 1250, error = 3.4207, accuracy = 0.6016. (0.400 sec/step)
#
# 2017-03-16 13:43:52.867644: step 1260, error = 3.3677, accuracy = 0.5625. (0.415 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1268 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:43:57.506422: step 1270, error = 3.0964, accuracy = 0.6328. (0.270 sec/step)
#
# 2017-03-16 13:44:00.748204: step 1280, error = 3.2172, accuracy = 0.6250. (0.334 sec/step)
#
# 2017-03-16 13:44:04.082930: step 1290, error = 3.1687, accuracy = 0.6094. (0.344 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.64828
# 2017-03-16 13:44:07.418731: step 1300, error = 3.1193, accuracy = 0.5859. (0.346 sec/step)
#
# 2017-03-16 13:44:10.737417: step 1310, error = 3.0865, accuracy = 0.6719. (0.332 sec/step)
#
# 2017-03-16 13:44:14.435481: step 1320, error = 3.2249, accuracy = 0.6172. (0.437 sec/step)
#
# 2017-03-16 13:44:18.738179: step 1330, error = 3.1842, accuracy = 0.6172. (0.450 sec/step)
#
# 2017-03-16 13:44:23.045840: step 1340, error = 3.0249, accuracy = 0.6016. (0.431 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1348 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:44:27.598283: step 1350, error = 3.2047, accuracy = 0.6250. (0.271 sec/step)
#
# 2017-03-16 13:44:31.688201: step 1360, error = 3.1202, accuracy = 0.6094. (0.411 sec/step)
#
# 2017-03-16 13:44:35.273389: step 1370, error = 2.9274, accuracy = 0.7344. (0.330 sec/step)
#
# 2017-03-16 13:44:38.589998: step 1380, error = 3.2419, accuracy = 0.5703. (0.329 sec/step)
#
# 2017-03-16 13:44:42.012403: step 1390, error = 2.9797, accuracy = 0.6719. (0.332 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.63678
# 2017-03-16 13:44:45.343353: step 1400, error = 2.9591, accuracy = 0.6953. (0.335 sec/step)
#
# 2017-03-16 13:44:48.875370: step 1410, error = 3.0269, accuracy = 0.7109. (0.434 sec/step)
#
# 2017-03-16 13:44:53.189146: step 1420, error = 2.9736, accuracy = 0.6875. (0.469 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1428 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:44:57.905859: step 1430, error = 3.0794, accuracy = 0.6328. (0.338 sec/step)
#
# 2017-03-16 13:45:02.220051: step 1440, error = 3.0749, accuracy = 0.6406. (0.558 sec/step)
#
# 2017-03-16 13:45:06.575217: step 1450, error = 2.9250, accuracy = 0.6562. (0.414 sec/step)
#
# 2017-03-16 13:45:10.327256: step 1460, error = 3.0908, accuracy = 0.6172. (0.335 sec/step)
#
# 2017-03-16 13:45:13.643769: step 1470, error = 2.9433, accuracy = 0.6953. (0.326 sec/step)
#
# 2017-03-16 13:45:16.948679: step 1480, error = 3.1709, accuracy = 0.6562. (0.325 sec/step)
#
# 2017-03-16 13:45:20.258842: step 1490, error = 2.8783, accuracy = 0.7031. (0.331 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61019
# 2017-03-16 13:45:23.656932: step 1500, error = 2.8884, accuracy = 0.6641. (0.338 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1508 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:45:28.188095: step 1510, error = 2.9882, accuracy = 0.6406. (0.318 sec/step)
#
# 2017-03-16 13:45:32.462315: step 1520, error = 2.8538, accuracy = 0.7344. (0.427 sec/step)
#
# 2017-03-16 13:45:36.675990: step 1530, error = 3.2005, accuracy = 0.6094. (0.397 sec/step)
#
# 2017-03-16 13:45:40.982530: step 1540, error = 2.9425, accuracy = 0.6797. (0.447 sec/step)
#
# 2017-03-16 13:45:44.774041: step 1550, error = 2.9084, accuracy = 0.6719. (0.329 sec/step)
#
# 2017-03-16 13:45:48.122606: step 1560, error = 2.9023, accuracy = 0.6641. (0.342 sec/step)
#
# 2017-03-16 13:45:51.476711: step 1570, error = 2.9610, accuracy = 0.6484. (0.332 sec/step)
#
# 2017-03-16 13:45:54.806470: step 1580, error = 2.9183, accuracy = 0.6797. (0.327 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1587 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:45:58.399985: step 1590, error = 3.2140, accuracy = 0.6406. (0.362 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.57295
# 2017-03-16 13:46:02.520803: step 1600, error = 3.0220, accuracy = 0.6250. (0.417 sec/step)
#
# 2017-03-16 13:46:06.801245: step 1610, error = 3.0558, accuracy = 0.6406. (0.457 sec/step)
#
# 2017-03-16 13:46:11.103645: step 1620, error = 2.9127, accuracy = 0.6172. (0.415 sec/step)
#
# 2017-03-16 13:46:15.367150: step 1630, error = 2.9228, accuracy = 0.6719. (0.457 sec/step)
#
# 2017-03-16 13:46:19.401156: step 1640, error = 2.8049, accuracy = 0.7266. (0.319 sec/step)
#
# 2017-03-16 13:46:22.743514: step 1650, error = 2.9687, accuracy = 0.6484. (0.319 sec/step)
#
# 2017-03-16 13:46:26.070978: step 1660, error = 2.9796, accuracy = 0.6562. (0.305 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1664 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:46:29.485207: step 1670, error = 2.7522, accuracy = 0.7578. (0.306 sec/step)
#
# 2017-03-16 13:46:32.829528: step 1680, error = 2.8857, accuracy = 0.7188. (0.347 sec/step)
#
# 2017-03-16 13:46:36.828099: step 1690, error = 2.9793, accuracy = 0.6250. (0.397 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.59596
# 2017-03-16 13:46:41.042058: step 1700, error = 2.7822, accuracy = 0.7188. (0.434 sec/step)
#
# 2017-03-16 13:46:45.317182: step 1710, error = 2.7692, accuracy = 0.6797. (0.438 sec/step)
#
# 2017-03-16 13:46:49.510433: step 1720, error = 3.0381, accuracy = 0.6250. (0.378 sec/step)
#
# 2017-03-16 13:46:53.758083: step 1730, error = 3.0424, accuracy = 0.6406. (0.413 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1741 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:46:57.601354: step 1740, error = 3.0169, accuracy = 0.6094. (0.777 sec/step)
#
# 2017-03-16 13:47:00.642464: step 1750, error = 2.8847, accuracy = 0.7031. (0.309 sec/step)
#
# 2017-03-16 13:47:03.964259: step 1760, error = 2.7908, accuracy = 0.7031. (0.326 sec/step)
#
# 2017-03-16 13:47:07.304667: step 1770, error = 3.0140, accuracy = 0.6406. (0.333 sec/step)
#
# 2017-03-16 13:47:11.054001: step 1780, error = 2.9912, accuracy = 0.6406. (0.410 sec/step)
#
# 2017-03-16 13:47:15.332286: step 1790, error = 2.8918, accuracy = 0.6172. (0.433 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.59441
# 2017-03-16 13:47:19.588597: step 1800, error = 2.8174, accuracy = 0.6406. (0.440 sec/step)
#
# 2017-03-16 13:47:23.836471: step 1810, error = 2.7139, accuracy = 0.7266. (0.433 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1819 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:47:28.597547: step 1820, error = 2.8387, accuracy = 0.7188. (0.234 sec/step)
#
# 2017-03-16 13:47:31.846513: step 1830, error = 2.8201, accuracy = 0.6953. (0.326 sec/step)
#
# 2017-03-16 13:47:35.178089: step 1840, error = 2.8599, accuracy = 0.6719. (0.322 sec/step)
#
# 2017-03-16 13:47:38.591615: step 1850, error = 2.7938, accuracy = 0.7031. (0.328 sec/step)
#
# 2017-03-16 13:47:41.938143: step 1860, error = 2.9743, accuracy = 0.6406. (0.347 sec/step)
#
# 2017-03-16 13:47:45.522938: step 1870, error = 2.6299, accuracy = 0.7969. (0.414 sec/step)
#
# 2017-03-16 13:47:49.798120: step 1880, error = 2.8397, accuracy = 0.6641. (0.419 sec/step)
#
# 2017-03-16 13:47:53.936011: step 1890, error = 2.8065, accuracy = 0.7031. (0.437 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1899 into cifar10_vgg_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.56327
# 2017-03-16 13:47:58.599368: step 1900, error = 2.6229, accuracy = 0.7500. (0.306 sec/step)
#
# 2017-03-16 13:48:02.672221: step 1910, error = 2.8014, accuracy = 0.6641. (0.416 sec/step)
#
# 2017-03-16 13:48:06.398268: step 1920, error = 2.8082, accuracy = 0.6797. (0.329 sec/step)
#
# 2017-03-16 13:48:09.735108: step 1930, error = 2.7461, accuracy = 0.6719. (0.324 sec/step)
#
# 2017-03-16 13:48:13.113115: step 1940, error = 2.8641, accuracy = 0.7031. (0.342 sec/step)
#
# 2017-03-16 13:48:16.436500: step 1950, error = 2.7935, accuracy = 0.6562. (0.316 sec/step)
#
# 2017-03-16 13:48:19.906085: step 1960, error = 2.7305, accuracy = 0.6953. (0.396 sec/step)
#
# 2017-03-16 13:48:24.114169: step 1970, error = 2.6381, accuracy = 0.7266. (0.438 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1979 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:48:28.934300: step 1980, error = 2.7268, accuracy = 0.7344. (0.258 sec/step)
#
# 2017-03-16 13:48:32.771481: step 1990, error = 2.7287, accuracy = 0.7422. (0.496 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.60688
# 2017-03-16 13:48:36.959368: step 2000, error = 2.6960, accuracy = 0.7266. (0.403 sec/step)
#
# 2017-03-16 13:48:41.136775: step 2010, error = 2.7166, accuracy = 0.7031. (0.338 sec/step)
#
# 2017-03-16 13:48:44.456349: step 2020, error = 2.7425, accuracy = 0.6875. (0.334 sec/step)
#
# 2017-03-16 13:48:47.821023: step 2030, error = 2.6421, accuracy = 0.7266. (0.337 sec/step)
#
# 2017-03-16 13:48:51.168705: step 2040, error = 2.7090, accuracy = 0.7188. (0.337 sec/step)
#
# 2017-03-16 13:48:54.513018: step 2050, error = 2.7187, accuracy = 0.7031. (0.318 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2059 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:48:59.083521: step 2060, error = 2.8540, accuracy = 0.6641. (0.313 sec/step)
#
# 2017-03-16 13:49:03.194377: step 2070, error = 2.6029, accuracy = 0.7578. (0.433 sec/step)
#
# 2017-03-16 13:49:07.387492: step 2080, error = 2.6891, accuracy = 0.7109. (0.427 sec/step)
#
# 2017-03-16 13:49:11.700256: step 2090, error = 2.7036, accuracy = 0.6953. (0.442 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.58136
# 2017-03-16 13:49:15.699236: step 2100, error = 2.6308, accuracy = 0.7188. (0.346 sec/step)
#
# 2017-03-16 13:49:19.061248: step 2110, error = 2.7045, accuracy = 0.7344. (0.338 sec/step)
#
# 2017-03-16 13:49:22.385114: step 2120, error = 2.5886, accuracy = 0.7812. (0.346 sec/step)
#
# 2017-03-16 13:49:25.742860: step 2130, error = 2.5860, accuracy = 0.7734. (0.334 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2138 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:49:29.312170: step 2140, error = 2.6749, accuracy = 0.7344. (0.232 sec/step)
#
# 2017-03-16 13:49:33.173905: step 2150, error = 2.6402, accuracy = 0.7344. (0.417 sec/step)
#
# 2017-03-16 13:49:37.455888: step 2160, error = 2.7295, accuracy = 0.6953. (0.418 sec/step)
#
# 2017-03-16 13:49:41.738153: step 2170, error = 2.7342, accuracy = 0.7266. (0.440 sec/step)
#
# 2017-03-16 13:49:46.168979: step 2180, error = 2.6216, accuracy = 0.7422. (0.429 sec/step)
#
# 2017-03-16 13:49:50.309890: step 2190, error = 2.5614, accuracy = 0.7969. (0.351 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.63201
# 2017-03-16 13:49:53.692321: step 2200, error = 2.5947, accuracy = 0.7344. (0.329 sec/step)
#
# 2017-03-16 13:49:57.014025: step 2210, error = 2.6849, accuracy = 0.6562. (0.345 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2215 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:50:00.488145: step 2220, error = 2.7122, accuracy = 0.6953. (0.330 sec/step)
#
# 2017-03-16 13:50:03.867205: step 2230, error = 2.6686, accuracy = 0.7109. (0.348 sec/step)
#
# 2017-03-16 13:50:07.708995: step 2240, error = 2.6645, accuracy = 0.7188. (0.404 sec/step)
#
# 2017-03-16 13:50:11.960841: step 2250, error = 2.6847, accuracy = 0.6875. (0.419 sec/step)
#
# 2017-03-16 13:50:16.266971: step 2260, error = 2.5044, accuracy = 0.7578. (0.433 sec/step)
#
# 2017-03-16 13:50:20.523049: step 2270, error = 2.5914, accuracy = 0.7344. (0.430 sec/step)
#
# 2017-03-16 13:50:24.688766: step 2280, error = 2.7847, accuracy = 0.6562. (0.399 sec/step)
#
# 2017-03-16 13:50:28.290388: step 2290, error = 2.5394, accuracy = 0.7578. (0.335 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2292 into cifar10_vgg_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.59116
# 2017-03-16 13:50:32.285326: step 2300, error = 2.7136, accuracy = 0.6562. (0.349 sec/step)
#
# 2017-03-16 13:50:35.641365: step 2310, error = 2.6177, accuracy = 0.7266. (0.330 sec/step)
#
# 2017-03-16 13:50:38.966063: step 2320, error = 2.5272, accuracy = 0.7578. (0.331 sec/step)
#
# 2017-03-16 13:50:42.782762: step 2330, error = 2.5901, accuracy = 0.7578. (0.423 sec/step)
#
# 2017-03-16 13:50:47.064415: step 2340, error = 2.6442, accuracy = 0.7344. (0.423 sec/step)
#
# 2017-03-16 13:50:51.344886: step 2350, error = 2.4992, accuracy = 0.7344. (0.386 sec/step)
#
# 2017-03-16 13:50:55.584433: step 2360, error = 2.6178, accuracy = 0.7031. (0.420 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2369 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:51:00.173150: step 2370, error = 2.6588, accuracy = 0.6875. (0.318 sec/step)
#
# 2017-03-16 13:51:03.562942: step 2380, error = 2.5526, accuracy = 0.7734. (0.340 sec/step)
#
# 2017-03-16 13:51:06.887000: step 2390, error = 2.6113, accuracy = 0.7578. (0.333 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.63534
# 2017-03-16 13:51:10.231227: step 2400, error = 2.5848, accuracy = 0.7344. (0.339 sec/step)
#
# 2017-03-16 13:51:13.571922: step 2410, error = 2.5916, accuracy = 0.7188. (0.328 sec/step)
#
# 2017-03-16 13:51:17.056378: step 2420, error = 2.5975, accuracy = 0.6797. (0.372 sec/step)
#
# 2017-03-16 13:51:21.371437: step 2430, error = 2.4874, accuracy = 0.7344. (0.420 sec/step)
#
# 2017-03-16 13:51:25.657943: step 2440, error = 2.6076, accuracy = 0.7344. (0.452 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2449 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:51:30.482375: step 2450, error = 2.6093, accuracy = 0.7344. (0.307 sec/step)
#
# 2017-03-16 13:51:34.560198: step 2460, error = 2.6322, accuracy = 0.6953. (0.431 sec/step)
#
# 2017-03-16 13:51:38.341081: step 2470, error = 2.7212, accuracy = 0.7109. (0.306 sec/step)
#
# 2017-03-16 13:51:41.701033: step 2480, error = 2.4554, accuracy = 0.7344. (0.343 sec/step)
#
# 2017-03-16 13:51:45.065554: step 2490, error = 2.5467, accuracy = 0.7031. (0.332 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61991
# 2017-03-16 13:51:48.400294: step 2500, error = 2.5201, accuracy = 0.6875. (0.323 sec/step)
#
# 2017-03-16 13:51:51.783589: step 2510, error = 2.5008, accuracy = 0.7422. (0.365 sec/step)
#
# 2017-03-16 13:51:56.044332: step 2520, error = 2.5563, accuracy = 0.7109. (0.426 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2529 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:52:00.681470: step 2530, error = 2.6259, accuracy = 0.6719. (0.259 sec/step)
#
# 2017-03-16 13:52:04.929228: step 2540, error = 2.5133, accuracy = 0.7578. (0.432 sec/step)
#
# 2017-03-16 13:52:09.226002: step 2550, error = 2.4050, accuracy = 0.7969. (0.408 sec/step)
#
# 2017-03-16 13:52:13.060967: step 2560, error = 2.4831, accuracy = 0.7891. (0.341 sec/step)
#
# 2017-03-16 13:52:16.411480: step 2570, error = 2.3619, accuracy = 0.7734. (0.343 sec/step)
#
# 2017-03-16 13:52:19.749049: step 2580, error = 2.4432, accuracy = 0.7344. (0.316 sec/step)
#
# 2017-03-16 13:52:23.120435: step 2590, error = 2.5534, accuracy = 0.7109. (0.357 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.62753
# 2017-03-16 13:52:26.459033: step 2600, error = 2.5000, accuracy = 0.7500. (0.349 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2609 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:52:31.172779: step 2610, error = 2.4747, accuracy = 0.7266. (0.273 sec/step)
#
# 2017-03-16 13:52:35.244095: step 2620, error = 2.7294, accuracy = 0.6641. (0.414 sec/step)
#
# 2017-03-16 13:52:39.467883: step 2630, error = 2.3156, accuracy = 0.7656. (0.415 sec/step)
#
# 2017-03-16 13:52:43.749671: step 2640, error = 2.4839, accuracy = 0.7500. (0.423 sec/step)
#
# 2017-03-16 13:52:47.700925: step 2650, error = 2.2743, accuracy = 0.8047. (0.334 sec/step)
#
# 2017-03-16 13:52:51.019586: step 2660, error = 2.5868, accuracy = 0.6953. (0.338 sec/step)
#
# 2017-03-16 13:52:54.411533: step 2670, error = 2.4553, accuracy = 0.7578. (0.357 sec/step)
#
# 2017-03-16 13:52:57.733239: step 2680, error = 2.4844, accuracy = 0.7344. (0.337 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2688 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:53:01.372306: step 2690, error = 2.4823, accuracy = 0.7266. (0.238 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.55164
# 2017-03-16 13:53:05.649427: step 2700, error = 2.3417, accuracy = 0.7734. (0.422 sec/step)
#
# 2017-03-16 13:53:09.871640: step 2710, error = 2.5065, accuracy = 0.7344. (0.408 sec/step)
#
# 2017-03-16 13:53:14.177811: step 2720, error = 2.5032, accuracy = 0.7422. (0.424 sec/step)
#
# 2017-03-16 13:53:18.382651: step 2730, error = 2.4943, accuracy = 0.6875. (0.403 sec/step)
#
# 2017-03-16 13:53:22.443404: step 2740, error = 2.6268, accuracy = 0.6875. (0.353 sec/step)
#
# 2017-03-16 13:53:25.809445: step 2750, error = 2.4626, accuracy = 0.7188. (0.342 sec/step)
#
# 2017-03-16 13:53:29.140129: step 2760, error = 2.3773, accuracy = 0.7891. (0.334 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2764 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:53:32.635692: step 2770, error = 2.3134, accuracy = 0.7734. (0.335 sec/step)
#
# 2017-03-16 13:53:35.961259: step 2780, error = 2.6116, accuracy = 0.6953. (0.327 sec/step)
#
# 2017-03-16 13:53:40.073741: step 2790, error = 2.4070, accuracy = 0.7344. (0.423 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.58267
# 2017-03-16 13:53:44.370772: step 2800, error = 2.4038, accuracy = 0.7734. (0.431 sec/step)
#
# 2017-03-16 13:53:48.584752: step 2810, error = 2.3402, accuracy = 0.7422. (0.431 sec/step)
#
# 2017-03-16 13:53:52.837964: step 2820, error = 2.3714, accuracy = 0.7344. (0.406 sec/step)
#
# 2017-03-16 13:53:57.024665: step 2830, error = 2.5156, accuracy = 0.6797. (0.356 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2841 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:54:00.979359: step 2840, error = 2.4200, accuracy = 0.7422. (0.886 sec/step)
#
# 2017-03-16 13:54:03.904890: step 2850, error = 2.3464, accuracy = 0.7656. (0.317 sec/step)
#
# 2017-03-16 13:54:07.274035: step 2860, error = 2.4030, accuracy = 0.7344. (0.334 sec/step)
#
# 2017-03-16 13:54:10.652316: step 2870, error = 2.4389, accuracy = 0.7578. (0.346 sec/step)
#
# 2017-03-16 13:54:14.491276: step 2880, error = 2.5120, accuracy = 0.7031. (0.438 sec/step)
#
# 2017-03-16 13:54:18.716907: step 2890, error = 2.4054, accuracy = 0.7266. (0.423 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.59627
# 2017-03-16 13:54:22.887231: step 2900, error = 2.2181, accuracy = 0.7891. (0.392 sec/step)
#
# 2017-03-16 13:54:27.229225: step 2910, error = 2.4219, accuracy = 0.7188. (0.424 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2919 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:54:32.016362: step 2920, error = 2.4492, accuracy = 0.7656. (0.272 sec/step)
#
# 2017-03-16 13:54:35.375714: step 2930, error = 2.3080, accuracy = 0.7422. (0.327 sec/step)
#
# 2017-03-16 13:54:38.740901: step 2940, error = 2.3820, accuracy = 0.7656. (0.330 sec/step)
#
# 2017-03-16 13:54:42.111388: step 2950, error = 2.4414, accuracy = 0.7578. (0.331 sec/step)
#
# 2017-03-16 13:54:45.458366: step 2960, error = 2.3620, accuracy = 0.7344. (0.341 sec/step)
#
# 2017-03-16 13:54:49.159076: step 2970, error = 2.3362, accuracy = 0.7578. (0.419 sec/step)
#
# 2017-03-16 13:54:53.329972: step 2980, error = 2.4043, accuracy = 0.7422. (0.413 sec/step)
#
# 2017-03-16 13:54:57.592228: step 2990, error = 2.5148, accuracy = 0.7031. (0.410 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2999 into cifar10_vgg_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 2.53974
# 2017-03-16 13:55:02.259963: step 3000, error = 2.2773, accuracy = 0.7812. (0.312 sec/step)
#
# 2017-03-16 13:55:06.443011: step 3010, error = 2.1986, accuracy = 0.8203. (0.395 sec/step)
#
# 2017-03-16 13:55:10.091017: step 3020, error = 2.3732, accuracy = 0.8047. (0.321 sec/step)
#
# 2017-03-16 13:55:13.489531: step 3030, error = 2.4886, accuracy = 0.7344. (0.354 sec/step)
#
# 2017-03-16 13:55:16.856134: step 3040, error = 2.5007, accuracy = 0.6562. (0.340 sec/step)
#
# 2017-03-16 13:55:20.225686: step 3050, error = 2.3024, accuracy = 0.7891. (0.342 sec/step)
#
# 2017-03-16 13:55:23.661828: step 3060, error = 2.3165, accuracy = 0.7812. (0.368 sec/step)
#
# 2017-03-16 13:55:27.851703: step 3070, error = 2.2811, accuracy = 0.7656. (0.381 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3079 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:55:32.615186: step 3080, error = 2.3064, accuracy = 0.8047. (0.291 sec/step)
#
# 2017-03-16 13:55:36.435888: step 3090, error = 2.4993, accuracy = 0.7031. (0.380 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.59787
# 2017-03-16 13:55:40.755004: step 3100, error = 2.3830, accuracy = 0.7266. (0.440 sec/step)
#
# 2017-03-16 13:55:44.748234: step 3110, error = 2.2782, accuracy = 0.7891. (0.347 sec/step)
#
# 2017-03-16 13:55:48.102380: step 3120, error = 2.1376, accuracy = 0.8125. (0.332 sec/step)
#
# 2017-03-16 13:55:51.483243: step 3130, error = 2.2471, accuracy = 0.7734. (0.333 sec/step)
#
# 2017-03-16 13:55:54.847807: step 3140, error = 2.1908, accuracy = 0.8047. (0.334 sec/step)
#
# 2017-03-16 13:55:58.180316: step 3150, error = 2.2529, accuracy = 0.7969. (0.324 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3159 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:56:02.768323: step 3160, error = 2.3020, accuracy = 0.7578. (0.333 sec/step)
#
# 2017-03-16 13:56:06.972669: step 3170, error = 2.1732, accuracy = 0.8125. (0.448 sec/step)
#
# 2017-03-16 13:56:11.279406: step 3180, error = 2.4454, accuracy = 0.7031. (0.420 sec/step)
#
# 2017-03-16 13:56:15.656745: step 3190, error = 2.1857, accuracy = 0.7969. (0.433 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.56472
# 2017-03-16 13:56:19.743874: step 3200, error = 2.2447, accuracy = 0.7734. (0.347 sec/step)
#
# 2017-03-16 13:56:23.089871: step 3210, error = 2.4206, accuracy = 0.7109. (0.336 sec/step)
#
# 2017-03-16 13:56:26.480282: step 3220, error = 2.3078, accuracy = 0.7422. (0.348 sec/step)
#
# 2017-03-16 13:56:29.860796: step 3230, error = 2.4793, accuracy = 0.6719. (0.335 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3236 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:56:33.238275: step 3240, error = 2.1920, accuracy = 0.8125. (0.276 sec/step)
#
# 2017-03-16 13:56:37.332971: step 3250, error = 2.1933, accuracy = 0.8203. (0.430 sec/step)
#
# 2017-03-16 13:56:41.618914: step 3260, error = 2.2798, accuracy = 0.7344. (0.461 sec/step)
#
# 2017-03-16 13:56:46.017018: step 3270, error = 2.1752, accuracy = 0.7812. (0.423 sec/step)
#
# 2017-03-16 13:56:50.314912: step 3280, error = 2.1878, accuracy = 0.7812. (0.447 sec/step)
#
# 2017-03-16 13:56:54.544931: step 3290, error = 2.2933, accuracy = 0.6953. (0.367 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61902
# 2017-03-16 13:56:57.925617: step 3300, error = 2.3645, accuracy = 0.7266. (0.353 sec/step)
#
# 2017-03-16 13:57:01.296328: step 3310, error = 2.2829, accuracy = 0.7656. (0.345 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3312 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:57:04.771367: step 3320, error = 2.3374, accuracy = 0.7422. (0.353 sec/step)
#
# 2017-03-16 13:57:08.127719: step 3330, error = 2.2754, accuracy = 0.7656. (0.343 sec/step)
#
# 2017-03-16 13:57:12.102273: step 3340, error = 2.1710, accuracy = 0.8203. (0.428 sec/step)
#
# 2017-03-16 13:57:16.393356: step 3350, error = 2.3241, accuracy = 0.7266. (0.341 sec/step)
#
# 2017-03-16 13:57:20.758778: step 3360, error = 2.3595, accuracy = 0.7109. (0.495 sec/step)
#
# 2017-03-16 13:57:24.993105: step 3370, error = 2.1502, accuracy = 0.8125. (0.389 sec/step)
#
# 2017-03-16 13:57:29.304040: step 3380, error = 2.1528, accuracy = 0.7969. (0.435 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3388 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:57:32.988612: step 3390, error = 2.1724, accuracy = 0.7734. (0.218 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.60163
# 2017-03-16 13:57:36.363324: step 3400, error = 2.3702, accuracy = 0.7344. (0.343 sec/step)
#
# 2017-03-16 13:57:39.745758: step 3410, error = 2.1190, accuracy = 0.8047. (0.315 sec/step)
#
# 2017-03-16 13:57:43.104416: step 3420, error = 2.0012, accuracy = 0.8750. (0.323 sec/step)
#
# 2017-03-16 13:57:46.961591: step 3430, error = 2.2086, accuracy = 0.7734. (0.434 sec/step)
#
# 2017-03-16 13:57:51.332061: step 3440, error = 2.2512, accuracy = 0.7578. (0.408 sec/step)
#
# 2017-03-16 13:57:55.651253: step 3450, error = 2.2318, accuracy = 0.7500. (0.419 sec/step)
#
# 2017-03-16 13:57:59.941389: step 3460, error = 2.3718, accuracy = 0.7031. (0.420 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3466 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:58:04.411548: step 3470, error = 2.0639, accuracy = 0.8359. (0.310 sec/step)
#
# 2017-03-16 13:58:07.800632: step 3480, error = 2.0974, accuracy = 0.8047. (0.340 sec/step)
#
# 2017-03-16 13:58:11.136454: step 3490, error = 2.1430, accuracy = 0.7812. (0.318 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.62228
# 2017-03-16 13:58:14.498047: step 3500, error = 2.0784, accuracy = 0.7812. (0.338 sec/step)
#
# 2017-03-16 13:58:17.866979: step 3510, error = 2.2377, accuracy = 0.7656. (0.351 sec/step)
#
# 2017-03-16 13:58:21.779037: step 3520, error = 2.1492, accuracy = 0.7891. (0.463 sec/step)
#
# 2017-03-16 13:58:26.111639: step 3530, error = 2.2046, accuracy = 0.7656. (0.439 sec/step)
#
# 2017-03-16 13:58:30.337479: step 3540, error = 2.1862, accuracy = 0.7656. (0.524 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3546 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:58:34.824083: step 3550, error = 2.0983, accuracy = 0.8125. (0.453 sec/step)
#
# 2017-03-16 13:58:39.115382: step 3560, error = 2.0826, accuracy = 0.7812. (0.393 sec/step)
#
# 2017-03-16 13:58:42.527160: step 3570, error = 2.2829, accuracy = 0.7344. (0.345 sec/step)
#
# 2017-03-16 13:58:45.929745: step 3580, error = 2.0644, accuracy = 0.8359. (0.339 sec/step)
#
# 2017-03-16 13:58:49.270348: step 3590, error = 2.2038, accuracy = 0.7891. (0.337 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.61058
# 2017-03-16 13:58:52.803604: step 3600, error = 2.2257, accuracy = 0.7422. (0.350 sec/step)
#
# 2017-03-16 13:58:56.761955: step 3610, error = 1.9463, accuracy = 0.8359. (0.438 sec/step)
#
# 2017-03-16 13:59:01.182439: step 3620, error = 2.1227, accuracy = 0.7812. (0.421 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3625 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:59:05.897908: step 3630, error = 2.1950, accuracy = 0.7578. (0.424 sec/step)
#
# 2017-03-16 13:59:10.233356: step 3640, error = 1.9516, accuracy = 0.8281. (0.422 sec/step)
#
# 2017-03-16 13:59:14.449305: step 3650, error = 2.0190, accuracy = 0.8203. (0.378 sec/step)
#
# 2017-03-16 13:59:17.826330: step 3660, error = 2.0238, accuracy = 0.7891. (0.330 sec/step)
#
# 2017-03-16 13:59:21.185654: step 3670, error = 2.0926, accuracy = 0.7969. (0.328 sec/step)
#
# 2017-03-16 13:59:24.581321: step 3680, error = 2.1327, accuracy = 0.7812. (0.355 sec/step)
#
# 2017-03-16 13:59:27.919777: step 3690, error = 2.0594, accuracy = 0.7734. (0.316 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.54909
# 2017-03-16 13:59:32.035092: step 3700, error = 1.9180, accuracy = 0.8359. (0.460 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3703 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 13:59:36.515392: step 3710, error = 2.2612, accuracy = 0.7500. (0.429 sec/step)
#
# 2017-03-16 13:59:40.822743: step 3720, error = 2.1759, accuracy = 0.7422. (0.411 sec/step)
#
# 2017-03-16 13:59:45.118502: step 3730, error = 2.0988, accuracy = 0.8203. (0.406 sec/step)
#
# 2017-03-16 13:59:49.473371: step 3740, error = 2.0639, accuracy = 0.8047. (0.408 sec/step)
#
# 2017-03-16 13:59:52.952442: step 3750, error = 2.0717, accuracy = 0.7656. (0.349 sec/step)
#
# 2017-03-16 13:59:56.327103: step 3760, error = 2.1863, accuracy = 0.7734. (0.336 sec/step)
#
# 2017-03-16 13:59:59.724459: step 3770, error = 2.2238, accuracy = 0.7344. (0.349 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3781 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:00:03.564997: step 3780, error = 2.0984, accuracy = 0.8047. (0.828 sec/step)
#
# 2017-03-16 14:00:07.184465: step 3790, error = 2.1862, accuracy = 0.7344. (0.430 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.53013
# 2017-03-16 14:00:11.556934: step 3800, error = 2.0338, accuracy = 0.8047. (0.437 sec/step)
#
# 2017-03-16 14:00:15.855716: step 3810, error = 2.0969, accuracy = 0.7656. (0.442 sec/step)
#
# 2017-03-16 14:00:20.143402: step 3820, error = 2.1566, accuracy = 0.7812. (0.429 sec/step)
#
# 2017-03-16 14:00:24.434468: step 3830, error = 2.0844, accuracy = 0.7656. (0.427 sec/step)
#
# 2017-03-16 14:00:27.986852: step 3840, error = 2.0353, accuracy = 0.7969. (0.361 sec/step)
#
# 2017-03-16 14:00:31.381599: step 3850, error = 2.2492, accuracy = 0.7344. (0.341 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3856 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:00:35.036925: step 3860, error = 1.9738, accuracy = 0.8438. (0.351 sec/step)
#
# 2017-03-16 14:00:38.407073: step 3870, error = 2.3846, accuracy = 0.6875. (0.330 sec/step)
#
# 2017-03-16 14:00:42.189582: step 3880, error = 2.0911, accuracy = 0.8125. (0.435 sec/step)
#
# 2017-03-16 14:00:46.509187: step 3890, error = 2.1910, accuracy = 0.7344. (0.457 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.55116
# 2017-03-16 14:00:50.755157: step 3900, error = 2.0804, accuracy = 0.7656. (0.436 sec/step)
#
# 2017-03-16 14:00:55.073033: step 3910, error = 2.1120, accuracy = 0.7031. (0.422 sec/step)
#
# 2017-03-16 14:00:59.377695: step 3920, error = 2.0432, accuracy = 0.7969. (0.411 sec/step)
#
# 2017-03-16 14:01:02.993238: step 3930, error = 1.9896, accuracy = 0.7969. (0.341 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3932 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:01:06.492692: step 3940, error = 1.8934, accuracy = 0.8516. (0.340 sec/step)
#
# 2017-03-16 14:01:09.858467: step 3950, error = 1.9184, accuracy = 0.8594. (0.327 sec/step)
#
# 2017-03-16 14:01:13.223713: step 3960, error = 2.0823, accuracy = 0.7656. (0.336 sec/step)
#
# 2017-03-16 14:01:16.927579: step 3970, error = 2.0278, accuracy = 0.8047. (0.431 sec/step)
#
# 2017-03-16 14:01:21.242037: step 3980, error = 2.0033, accuracy = 0.8516. (0.436 sec/step)
#
# 2017-03-16 14:01:25.556551: step 3990, error = 1.8924, accuracy = 0.8359. (0.422 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.56119
# 2017-03-16 14:01:29.799048: step 4000, error = 2.1030, accuracy = 0.7734. (0.438 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4010 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:01:34.555872: step 4010, error = 2.0084, accuracy = 0.8125. (0.340 sec/step)
#
# 2017-03-16 14:01:37.910313: step 4020, error = 2.0932, accuracy = 0.7500. (0.357 sec/step)
#
# 2017-03-16 14:01:41.279423: step 4030, error = 1.9611, accuracy = 0.8047. (0.341 sec/step)
#
# 2017-03-16 14:01:44.646132: step 4040, error = 2.0177, accuracy = 0.7812. (0.340 sec/step)
#
# 2017-03-16 14:01:48.005063: step 4050, error = 2.1838, accuracy = 0.7578. (0.329 sec/step)
#
# 2017-03-16 14:01:51.444119: step 4060, error = 1.8833, accuracy = 0.8438. (0.363 sec/step)
#
# 2017-03-16 14:01:55.731777: step 4070, error = 1.9709, accuracy = 0.7812. (0.441 sec/step)
#
# 2017-03-16 14:01:59.998411: step 4080, error = 1.9503, accuracy = 0.7656. (0.402 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4090 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:02:05.003314: step 4090, error = 2.0529, accuracy = 0.7656. (0.273 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.55766
# 2017-03-16 14:02:08.897842: step 4100, error = 2.0532, accuracy = 0.7266. (0.445 sec/step)
#
# 2017-03-16 14:02:12.771230: step 4110, error = 1.9731, accuracy = 0.7891. (0.348 sec/step)
#
# 2017-03-16 14:02:16.138101: step 4120, error = 1.9814, accuracy = 0.8047. (0.333 sec/step)
#
# 2017-03-16 14:02:19.533389: step 4130, error = 1.9843, accuracy = 0.7891. (0.346 sec/step)
#
# 2017-03-16 14:02:22.923721: step 4140, error = 1.9382, accuracy = 0.7812. (0.344 sec/step)
#
# 2017-03-16 14:02:26.365004: step 4150, error = 1.9243, accuracy = 0.8047. (0.399 sec/step)
#
# 2017-03-16 14:02:30.694402: step 4160, error = 1.9724, accuracy = 0.8125. (0.423 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4169 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:02:35.322028: step 4170, error = 1.9730, accuracy = 0.7891. (0.236 sec/step)
#
# 2017-03-16 14:02:39.512088: step 4180, error = 1.9133, accuracy = 0.8047. (0.452 sec/step)
#
# 2017-03-16 14:02:43.817699: step 4190, error = 2.0851, accuracy = 0.7266. (0.423 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.57823
# 2017-03-16 14:02:47.684038: step 4200, error = 1.9621, accuracy = 0.8047. (0.351 sec/step)
#
# 2017-03-16 14:02:51.056100: step 4210, error = 2.0318, accuracy = 0.7578. (0.350 sec/step)
#
# 2017-03-16 14:02:54.454049: step 4220, error = 2.0920, accuracy = 0.7578. (0.326 sec/step)
#
# 2017-03-16 14:02:57.822808: step 4230, error = 1.9535, accuracy = 0.8281. (0.330 sec/step)
#
# 2017-03-16 14:03:01.300756: step 4240, error = 1.9311, accuracy = 0.8125. (0.386 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4248 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:03:05.726827: step 4250, error = 1.9546, accuracy = 0.7812. (0.310 sec/step)
#
# 2017-03-16 14:03:10.063864: step 4260, error = 2.0772, accuracy = 0.7812. (0.431 sec/step)
#
# 2017-03-16 14:03:14.373892: step 4270, error = 1.9671, accuracy = 0.7344. (0.424 sec/step)
#
# 2017-03-16 14:03:18.618313: step 4280, error = 1.8981, accuracy = 0.8125. (0.395 sec/step)
#
# 2017-03-16 14:03:22.714999: step 4290, error = 2.0747, accuracy = 0.7891. (0.348 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.60636
# 2017-03-16 14:03:26.051954: step 4300, error = 1.9967, accuracy = 0.7734. (0.328 sec/step)
#
# 2017-03-16 14:03:29.447642: step 4310, error = 2.1097, accuracy = 0.7812. (0.343 sec/step)
#
# 2017-03-16 14:03:32.834387: step 4320, error = 1.8730, accuracy = 0.8125. (0.332 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4326 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:03:36.584538: step 4330, error = 1.9776, accuracy = 0.7422. (0.361 sec/step)
#
# 2017-03-16 14:03:40.857058: step 4340, error = 2.0280, accuracy = 0.7812. (0.433 sec/step)
#
# 2017-03-16 14:03:45.279143: step 4350, error = 1.8457, accuracy = 0.8281. (0.431 sec/step)
#
# 2017-03-16 14:03:49.556447: step 4360, error = 2.0154, accuracy = 0.7891. (0.438 sec/step)
#
# 2017-03-16 14:03:53.845394: step 4370, error = 2.0173, accuracy = 0.7422. (0.431 sec/step)
#
# 2017-03-16 14:03:57.860411: step 4380, error = 1.9842, accuracy = 0.7656. (0.327 sec/step)
#
# 2017-03-16 14:04:01.260444: step 4390, error = 1.9858, accuracy = 0.7344. (0.333 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.59301
# INFO:tensorflow:Saving checkpoints for 4401 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:04:05.166393: step 4400, error = 1.8313, accuracy = 0.8438. (0.878 sec/step)
#
# 2017-03-16 14:04:08.170822: step 4410, error = 1.9536, accuracy = 0.7734. (0.344 sec/step)
#
# 2017-03-16 14:04:11.534015: step 4420, error = 1.9018, accuracy = 0.7891. (0.336 sec/step)
#
# 2017-03-16 14:04:15.744093: step 4430, error = 1.9788, accuracy = 0.7734. (0.448 sec/step)
#
# 2017-03-16 14:04:20.057906: step 4440, error = 1.9112, accuracy = 0.7734. (0.421 sec/step)
#
# 2017-03-16 14:04:24.335817: step 4450, error = 1.8788, accuracy = 0.8359. (0.439 sec/step)
#
# 2017-03-16 14:04:28.653538: step 4460, error = 1.9494, accuracy = 0.7656. (0.430 sec/step)
#
# 2017-03-16 14:04:32.759135: step 4470, error = 1.7936, accuracy = 0.8281. (0.338 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4477 into cifar10_vgg_model2/model.ckpt.
# 2017-03-16 14:04:36.402912: step 4480, error = 1.8140, accuracy = 0.8203. (0.250 sec/step)
#
# 2017-03-16 14:04:39.781738: step 4490, error = 1.9819, accuracy = 0.7578. (0.334 sec/step)
#
# INFO:tensorflow:global_step/sec: 2.59335
# 2017-03-16 14:04:43.176620: step 4500, error = 1.9702, accuracy = 0.7812. (0.347 sec/step)
#
# 2017-03-16 14:04:46.589455: step 4510, error = 1.9339, accuracy = 0.8203. (0.335 sec/step)
#
# ...
#
# 2017-03-16 17:07:31.478859: step 28170, error = 0.3382, accuracy = 0.9609. (0.552 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 28172 into cifar10_vgg_model2/model.ckpt.
# ResourceExhaustedErrorTraceback (most recent call last)
# <ipython-input-3-93ec2fa589b1> in <module>()
#      61                                                log_device_placement=log_device_placement)) as mon_sess:
#      62         while not mon_sess.should_stop():
# ---> 63             mon_sess.run(train_op)
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     460                           feed_dict=feed_dict,
#     461                           options=options,
# --> 462                           run_metadata=run_metadata)
#     463
#     464   def should_stop(self):
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     784                               feed_dict=feed_dict,
#     785                               options=options,
# --> 786                               run_metadata=run_metadata)
#     787       except errors.AbortedError:
#     788         logging.info('An AbortedError was raised. Closing the current session. '
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, *args, **kwargs)
#     742
#     743   def run(self, *args, **kwargs):
# --> 744     return self._sess.run(*args, **kwargs)
#     745
#     746
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     897               results=outputs[hook] if hook in outputs else None,
#     898               options=options,
# --> 899               run_metadata=run_metadata))
#     900     self._should_stop = self._should_stop or run_context.stop_requested
#     901
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/basic_session_run_hooks.pyc in after_run(self, run_context, run_values)
#     353     if self._timer.should_trigger_for_step(global_step):
#     354       self._timer.update_last_triggered_step(global_step)
# --> 355       self._save(global_step, run_context.session)
#     356
#     357   def end(self, session):
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/basic_session_run_hooks.pyc in _save(self, step, session)
#     369       l.before_save(session, step)
#     370
# --> 371     self._get_saver().save(session, self._save_path, global_step=step)
#     372     self._summary_writer.add_session_log(
#     373         SessionLog(
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.pyc in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1372       model_checkpoint_path = sess.run(
#    1373           self.saver_def.save_tensor_name,
# -> 1374           {self.saver_def.filename_tensor_name: checkpoint_file})
#    1375       model_checkpoint_path = compat.as_str(model_checkpoint_path)
#    1376       if write_state:
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# ResourceExhaustedError: cifar10_vgg_model2/model.ckpt-28172_temp_37ef64c60f354a74a63a9b5eb379e40f/part-00001-of-00002.data-00000-of-00001.tempstate8362418674437790013
# 	 [[Node: save/SaveV2_1 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](save/ShardedFilename_1, save/SaveV2_1/tensor_names, save/SaveV2_1/shape_and_slices, conv1_1/biases, conv1_1/biases/ExponentialMovingAverage, conv1_1/weights, conv1_1/weights/ExponentialMovingAverage, conv1_2/biases, conv1_2/biases/ExponentialMovingAverage, conv1_2/weights, conv1_2/weights/ExponentialMovingAverage, conv2_1/biases, conv2_1/biases/ExponentialMovingAverage, conv2_1/weights, conv2_1/weights/ExponentialMovingAverage, conv2_2/biases, conv2_2/biases/ExponentialMovingAverage, conv2_2/weights, conv2_2/weights/ExponentialMovingAverage, conv3_1/biases, conv3_1/biases/ExponentialMovingAverage, conv3_1/weights, conv3_1/weights/ExponentialMovingAverage, conv3_2/biases, conv3_2/biases/ExponentialMovingAverage, conv3_2/weights, conv3_2/weights/ExponentialMovingAverage, conv3_3/biases, conv3_3/biases/ExponentialMovingAverage, conv3_3/weights, conv3_3/weights/ExponentialMovingAverage, fc_3/biases, fc_3/biases/ExponentialMovingAverage, fc_3/weights, fc_3/weights/ExponentialMovingAverage, fc_4/biases, fc_4/biases/ExponentialMovingAverage, fc_4/weights, fc_4/weights/ExponentialMovingAverage, softmax_linear/biases, softmax_linear/biases/ExponentialMovingAverage, softmax_linear/weights, softmax_linear/weights/ExponentialMovingAverage)]]
#
# Caused by op u'save/SaveV2_1', defined at:
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-93ec2fa589b1>", line 61, in <module>
#     log_device_placement=log_device_placement)) as mon_sess:
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 315, in MonitoredTrainingSession
#     return MonitoredSession(session_creator=session_creator, hooks=all_hooks)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 601, in __init__
#     session_creator, hooks, should_recover=True)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 434, in __init__
#     self._sess = _RecoverableSession(self._coordinated_creator)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 767, in __init__
#     _WrappedSession.__init__(self, self._create_session())
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 772, in _create_session
#     return self._sess_creator.create_session()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 494, in create_session
#     self.tf_sess = self._session_creator.create_session()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 366, in create_session
#     self._scaffold.finalize()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 180, in finalize
#     lambda: training_saver.Saver(sharded=True, allow_empty=True,
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 232, in get_or_default
#     op = default_constructor()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.py", line 181, in <lambda>
#     write_version=saver_pb2.SaverDef.V2))
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 1051, in __init__
#     self.build()
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 1081, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 669, in build
#     save_tensor = self._AddShardedSaveOps(filename_tensor, per_device)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 356, in _AddShardedSaveOps
#     return self._AddShardedSaveOpsForV2(filename_tensor, per_device)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 330, in _AddShardedSaveOpsForV2
#     sharded_saves.append(self._AddSaveOps(sharded_filename, saveables))
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 271, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/saver.py", line 214, in save_op
#     tensors)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/ops/gen_io_ops.py", line 779, in save_v2
#     tensors=tensors, name=name)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# ResourceExhaustedError (see above for traceback): cifar10_vgg_model2/model.ckpt-28172_temp_37ef64c60f354a74a63a9b5eb379e40f/part-00001-of-00002.data-00000-of-00001.tempstate8362418674437790013
# 	 [[Node: save/SaveV2_1 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](save/ShardedFilename_1, save/SaveV2_1/tensor_names, save/SaveV2_1/shape_and_slices, conv1_1/biases, conv1_1/biases/ExponentialMovingAverage, conv1_1/weights, conv1_1/weights/ExponentialMovingAverage, conv1_2/biases, conv1_2/biases/ExponentialMovingAverage, conv1_2/weights, conv1_2/weights/ExponentialMovingAverage, conv2_1/biases, conv2_1/biases/ExponentialMovingAverage, conv2_1/weights, conv2_1/weights/ExponentialMovingAverage, conv2_2/biases, conv2_2/biases/ExponentialMovingAverage, conv2_2/weights, conv2_2/weights/ExponentialMovingAverage, conv3_1/biases, conv3_1/biases/ExponentialMovingAverage, conv3_1/weights, conv3_1/weights/ExponentialMovingAverage, conv3_2/biases, conv3_2/biases/ExponentialMovingAverage, conv3_2/weights, conv3_2/weights/ExponentialMovingAverage, conv3_3/biases, conv3_3/biases/ExponentialMovingAverage, conv3_3/weights, conv3_3/weights/ExponentialMovingAverage, fc_3/biases, fc_3/biases/ExponentialMovingAverage, fc_3/weights, fc_3/weights/ExponentialMovingAverage, fc_4/biases, fc_4/biases/ExponentialMovingAverage, fc_4/weights, fc_4/weights/ExponentialMovingAverage, softmax_linear/biases, softmax_linear/biases/ExponentialMovingAverage, softmax_linear/weights, softmax_linear/weights/ExponentialMovingAverage)]]
