# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from datetime import datetime
from train import *
from loss import *
from accuracy import *
from model import *

import cifar_input
import os.path
import time
import numpy as np
import tensorflow as tf

# %%
max_steps = 20000
train_dir = 'cifar100_vgg_model/'
batch_size = 128
log_device_placement = False

# %%
with tf.Graph().as_default():
    global_step = tf.contrib.framework.get_or_create_global_step()
    
    # Generating images and its labels
    # build_inputs('cifar10/cifar100', cifar dataset dir, batch size, mode)
    images, labels = cifar_input.build_input('cifar100', '../../cifar/cifar100/train.bin', batch_size, 'train')
    
    # Creating graph. NUM_CLASESS=10 (CIFAR-10) or NUM_CLASESS=100 (CIFAR-100)
    logits = inference(images, NUM_CLASSES=100)
    
    # Loss/Error and Accuracy
    losses = loss(logits, labels)
    accuracies = accuracy(logits, labels)
    
    # Our train_op (Only minimizing loss)
    train_op = train(losses, global_step, batch_size)
    
    
    # SessionRunHook. Logging will be done each x steps.
    class _LoggerHook(tf.train.SessionRunHook):
        
      def begin(self):
        self._step = -1
        # Creating train_dir if it does not exist and writing to log file
        if not os.path.exists(train_dir):
            os.makedirs(train_dir)
        open(train_dir+'training_data.csv', 'w').close()
        f = open(train_dir+"log.txt",'ab')
        f.write('\n\n==== Run ===\nInfo: Alexnet\n')
        f.close()

      def before_run(self, run_context):
        # Increment step, reset start_time, and asking for loss and accuracy tensor
        self._step += 1
        self._start_time = time.time()
        return tf.train.SessionRunArgs([losses, accuracies])

      def after_run(self, run_context, run_values):
        duration = time.time() - self._start_time # Calculating time
        loss_value = run_values.results[0]
        accuracy_value = run_values.results[1]
        # Printing log, accuracy, and loss
        if self._step % 10 == 0:
          print("{0}: step {1}, error = {2:.4f}, accuracy = {3:.4f}. ({4:.3f} sec/step)\n".format(
              datetime.now(), self._step, loss_value, accuracy_value, float(duration)))
                
          f = open(train_dir+"log.txt",'ab')
          f.write("{0}: step {1}, error = {2:.4f}, accuracy = {3:.4f}. ({4:.3f} sec/step)\n".format(
              datetime.now(), self._step, loss_value, accuracy_value, float(duration)))
          f.close()
                
          f = open(train_dir+"training_data.csv",'ab')
          f.write('{0},{1},{2}\n'.format(self._step, loss_value, accuracy_value))
          f.close()
            
    with tf.train.MonitoredTrainingSession(checkpoint_dir=train_dir,
                                           hooks=[tf.train.StopAtStepHook(last_step=max_steps),
                                                  tf.train.NanTensorHook(losses),
                                                  _LoggerHook()],save_checkpoint_secs=30, 
                                           config=tf.ConfigProto(
                                               log_device_placement=log_device_placement)) as mon_sess:
        while not mon_sess.should_stop():
            mon_sess.run(train_op)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:52:35.468722: step 0, error = 10.4530, accuracy = 0.0234. (2.888 sec/step)
#
# 2017-03-11 23:52:37.656500: step 10, error = 10.4113, accuracy = 0.0234. (0.282 sec/step)
#
# 2017-03-11 23:52:40.411404: step 20, error = 10.3688, accuracy = 0.0078. (0.299 sec/step)
#
# 2017-03-11 23:52:43.643619: step 30, error = 10.2852, accuracy = 0.0234. (0.339 sec/step)
#
# 2017-03-11 23:52:46.785665: step 40, error = 10.2302, accuracy = 0.0391. (0.324 sec/step)
#
# 2017-03-11 23:52:49.958294: step 50, error = 10.1201, accuracy = 0.0000. (0.313 sec/step)
#
# 2017-03-11 23:52:53.116586: step 60, error = 10.0549, accuracy = 0.0234. (0.322 sec/step)
#
# 2017-03-11 23:52:56.269246: step 70, error = 9.8906, accuracy = 0.0234. (0.307 sec/step)
#
# 2017-03-11 23:52:59.114365: step 80, error = 10.0199, accuracy = 0.0156. (0.274 sec/step)
#
# 2017-03-11 23:53:01.715862: step 90, error = 9.8749, accuracy = 0.0312. (0.249 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.39057
# 2017-03-11 23:53:04.762420: step 100, error = 9.8468, accuracy = 0.0547. (0.339 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 103 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:53:08.037452: step 110, error = 9.6309, accuracy = 0.0547. (0.327 sec/step)
#
# 2017-03-11 23:53:11.130980: step 120, error = 9.7829, accuracy = 0.0078. (0.335 sec/step)
#
# 2017-03-11 23:53:14.318824: step 130, error = 9.5737, accuracy = 0.0156. (0.317 sec/step)
#
# 2017-03-11 23:53:17.448437: step 140, error = 9.5311, accuracy = 0.0391. (0.335 sec/step)
#
# 2017-03-11 23:53:20.338951: step 150, error = 9.3703, accuracy = 0.0859. (0.261 sec/step)
#
# 2017-03-11 23:53:22.992027: step 160, error = 9.4034, accuracy = 0.0312. (0.262 sec/step)
#
# 2017-03-11 23:53:25.997084: step 170, error = 9.5179, accuracy = 0.0469. (0.326 sec/step)
#
# 2017-03-11 23:53:29.163852: step 180, error = 9.3650, accuracy = 0.0625. (0.313 sec/step)
#
# 2017-03-11 23:53:32.279401: step 190, error = 9.0567, accuracy = 0.0625. (0.309 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.25897
# INFO:tensorflow:Saving checkpoints for 201 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:53:35.683901: step 200, error = 8.9216, accuracy = 0.1094. (0.564 sec/step)
#
# 2017-03-11 23:53:38.646734: step 210, error = 9.1313, accuracy = 0.0703. (0.322 sec/step)
#
# 2017-03-11 23:53:41.609962: step 220, error = 9.0847, accuracy = 0.0391. (0.259 sec/step)
#
# 2017-03-11 23:53:44.255177: step 230, error = 8.9601, accuracy = 0.0703. (0.270 sec/step)
#
# 2017-03-11 23:53:47.231801: step 240, error = 8.8919, accuracy = 0.0781. (0.312 sec/step)
#
# 2017-03-11 23:53:50.419238: step 250, error = 8.8392, accuracy = 0.0703. (0.311 sec/step)
#
# 2017-03-11 23:53:53.634916: step 260, error = 8.6608, accuracy = 0.1172. (0.339 sec/step)
#
# 2017-03-11 23:53:56.861448: step 270, error = 8.8013, accuracy = 0.0547. (0.326 sec/step)
#
# 2017-03-11 23:54:00.007755: step 280, error = 8.6943, accuracy = 0.1016. (0.317 sec/step)
#
# 2017-03-11 23:54:02.977014: step 290, error = 8.9551, accuracy = 0.0781. (0.249 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.31015
# INFO:tensorflow:Saving checkpoints for 301 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:54:05.871408: step 300, error = 8.5909, accuracy = 0.0781. (0.499 sec/step)
#
# 2017-03-11 23:54:08.673214: step 310, error = 8.6708, accuracy = 0.1016. (0.316 sec/step)
#
# 2017-03-11 23:54:11.790823: step 320, error = 8.5198, accuracy = 0.0938. (0.309 sec/step)
#
# 2017-03-11 23:54:14.929319: step 330, error = 8.3675, accuracy = 0.1016. (0.311 sec/step)
#
# 2017-03-11 23:54:18.119949: step 340, error = 8.4212, accuracy = 0.1016. (0.307 sec/step)
#
# 2017-03-11 23:54:21.311187: step 350, error = 8.4261, accuracy = 0.1172. (0.316 sec/step)
#
# 2017-03-11 23:54:24.311526: step 360, error = 8.4951, accuracy = 0.0703. (0.267 sec/step)
#
# 2017-03-11 23:54:26.959644: step 370, error = 8.1515, accuracy = 0.1641. (0.257 sec/step)
#
# 2017-03-11 23:54:29.896340: step 380, error = 8.4536, accuracy = 0.0469. (0.303 sec/step)
#
# 2017-03-11 23:54:33.096062: step 390, error = 8.5538, accuracy = 0.0625. (0.324 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 400 into cifar100_vgg_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.25168
# 2017-03-11 23:54:36.410458: step 400, error = 7.9693, accuracy = 0.1641. (0.164 sec/step)
#
# 2017-03-11 23:54:39.537404: step 410, error = 8.1304, accuracy = 0.1406. (0.300 sec/step)
#
# 2017-03-11 23:54:42.716526: step 420, error = 8.0642, accuracy = 0.1016. (0.315 sec/step)
#
# 2017-03-11 23:54:45.712878: step 430, error = 8.1347, accuracy = 0.1250. (0.241 sec/step)
#
# 2017-03-11 23:54:48.353734: step 440, error = 7.9278, accuracy = 0.1172. (0.275 sec/step)
#
# 2017-03-11 23:54:51.225164: step 450, error = 7.9218, accuracy = 0.1484. (0.332 sec/step)
#
# 2017-03-11 23:54:54.444378: step 460, error = 8.0274, accuracy = 0.1250. (0.325 sec/step)
#
# 2017-03-11 23:54:57.649011: step 470, error = 7.7974, accuracy = 0.1328. (0.307 sec/step)
#
# 2017-03-11 23:55:00.857255: step 480, error = 7.7724, accuracy = 0.1172. (0.323 sec/step)
#
# 2017-03-11 23:55:04.048166: step 490, error = 7.7457, accuracy = 0.1250. (0.307 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 497 into cifar100_vgg_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.24429
# 2017-03-11 23:55:07.234287: step 500, error = 7.9616, accuracy = 0.0469. (0.275 sec/step)
#
# 2017-03-11 23:55:09.869282: step 510, error = 7.8464, accuracy = 0.0781. (0.253 sec/step)
#
# 2017-03-11 23:55:12.773673: step 520, error = 7.6170, accuracy = 0.1016. (0.342 sec/step)
#
# 2017-03-11 23:55:15.954041: step 530, error = 7.6611, accuracy = 0.0938. (0.325 sec/step)
#
# 2017-03-11 23:55:19.184361: step 540, error = 7.5631, accuracy = 0.1328. (0.320 sec/step)
#
# 2017-03-11 23:55:22.387378: step 550, error = 7.4836, accuracy = 0.1406. (0.307 sec/step)
#
# 2017-03-11 23:55:25.608135: step 560, error = 7.5659, accuracy = 0.0859. (0.333 sec/step)
#
# 2017-03-11 23:55:28.701628: step 570, error = 7.3138, accuracy = 0.1719. (0.272 sec/step)
#
# 2017-03-11 23:55:31.358964: step 580, error = 7.1907, accuracy = 0.1875. (0.275 sec/step)
#
# 2017-03-11 23:55:34.224306: step 590, error = 7.1787, accuracy = 0.1484. (0.325 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 597 into cifar100_vgg_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.30888
# 2017-03-11 23:55:37.455652: step 600, error = 7.2319, accuracy = 0.1562. (0.302 sec/step)
#
# 2017-03-11 23:55:40.651186: step 610, error = 7.4039, accuracy = 0.1250. (0.325 sec/step)
#
# 2017-03-11 23:55:43.857115: step 620, error = 7.0609, accuracy = 0.2188. (0.306 sec/step)
#
# 2017-03-11 23:55:46.978819: step 630, error = 7.3932, accuracy = 0.0938. (0.323 sec/step)
#
# 2017-03-11 23:55:50.158465: step 640, error = 7.3927, accuracy = 0.1172. (0.291 sec/step)
#
# 2017-03-11 23:55:52.829664: step 650, error = 7.1391, accuracy = 0.1797. (0.265 sec/step)
#
# 2017-03-11 23:55:55.711834: step 660, error = 6.9337, accuracy = 0.1875. (0.324 sec/step)
#
# 2017-03-11 23:55:58.881271: step 670, error = 7.0019, accuracy = 0.1797. (0.299 sec/step)
#
# 2017-03-11 23:56:02.143457: step 680, error = 6.9696, accuracy = 0.1641. (0.311 sec/step)
#
# 2017-03-11 23:56:05.395146: step 690, error = 7.2162, accuracy = 0.1250. (0.341 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 694 into cifar100_vgg_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.20608
# 2017-03-11 23:56:08.645881: step 700, error = 6.8623, accuracy = 0.1797. (0.327 sec/step)
#
# 2017-03-11 23:56:11.755654: step 710, error = 6.9014, accuracy = 0.1484. (0.263 sec/step)
#
# 2017-03-11 23:56:14.432999: step 720, error = 6.8656, accuracy = 0.1562. (0.273 sec/step)
#
# 2017-03-11 23:56:17.313645: step 730, error = 6.7123, accuracy = 0.1641. (0.337 sec/step)
#
# 2017-03-11 23:56:20.521525: step 740, error = 6.8552, accuracy = 0.1562. (0.334 sec/step)
#
# 2017-03-11 23:56:23.752716: step 750, error = 6.6353, accuracy = 0.1484. (0.318 sec/step)
#
# 2017-03-11 23:56:26.952368: step 760, error = 6.9239, accuracy = 0.1406. (0.339 sec/step)
#
# 2017-03-11 23:56:30.162139: step 770, error = 6.8300, accuracy = 0.1562. (0.331 sec/step)
#
# 2017-03-11 23:56:33.256102: step 780, error = 6.8034, accuracy = 0.1719. (0.274 sec/step)
#
# 2017-03-11 23:56:35.925686: step 790, error = 7.0336, accuracy = 0.1172. (0.269 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 793 into cifar100_vgg_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.30712
# 2017-03-11 23:56:38.884070: step 800, error = 6.6456, accuracy = 0.1484. (0.312 sec/step)
#
# 2017-03-11 23:56:42.099951: step 810, error = 6.8199, accuracy = 0.1094. (0.326 sec/step)
#
# 2017-03-11 23:56:45.281448: step 820, error = 6.6482, accuracy = 0.1797. (0.311 sec/step)
#
# 2017-03-11 23:56:48.469843: step 830, error = 6.4013, accuracy = 0.1875. (0.323 sec/step)
#
# 2017-03-11 23:56:51.675129: step 840, error = 6.6184, accuracy = 0.1797. (0.316 sec/step)
#
# 2017-03-11 23:56:54.787768: step 850, error = 6.5131, accuracy = 0.1562. (0.277 sec/step)
#
# 2017-03-11 23:56:57.465096: step 860, error = 6.2195, accuracy = 0.1953. (0.272 sec/step)
#
# 2017-03-11 23:57:00.346353: step 870, error = 6.4866, accuracy = 0.1641. (0.334 sec/step)
#
# 2017-03-11 23:57:03.529277: step 880, error = 6.4603, accuracy = 0.1719. (0.305 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 890 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:57:06.985434: step 890, error = 6.4277, accuracy = 0.1484. (0.174 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.20067
# 2017-03-11 23:57:10.128154: step 900, error = 6.3796, accuracy = 0.1641. (0.328 sec/step)
#
# 2017-03-11 23:57:13.368907: step 910, error = 6.2776, accuracy = 0.1953. (0.309 sec/step)
#
# 2017-03-11 23:57:16.426182: step 920, error = 6.4041, accuracy = 0.1875. (0.252 sec/step)
#
# 2017-03-11 23:57:19.107409: step 930, error = 6.0392, accuracy = 0.2031. (0.260 sec/step)
#
# 2017-03-11 23:57:22.088238: step 940, error = 5.9069, accuracy = 0.2188. (0.305 sec/step)
#
# 2017-03-11 23:57:25.283810: step 950, error = 6.1458, accuracy = 0.2109. (0.306 sec/step)
#
# 2017-03-11 23:57:28.550369: step 960, error = 6.1811, accuracy = 0.1484. (0.316 sec/step)
#
# 2017-03-11 23:57:31.775264: step 970, error = 6.1416, accuracy = 0.1484. (0.311 sec/step)
#
# 2017-03-11 23:57:34.981982: step 980, error = 6.0847, accuracy = 0.1719. (0.317 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 986 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:57:38.065297: step 990, error = 5.9089, accuracy = 0.2031. (0.262 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.26446
# 2017-03-11 23:57:40.760482: step 1000, error = 6.1144, accuracy = 0.1797. (0.272 sec/step)
#
# 2017-03-11 23:57:43.765809: step 1010, error = 5.8999, accuracy = 0.1875. (0.361 sec/step)
#
# 2017-03-11 23:57:47.035282: step 1020, error = 5.7388, accuracy = 0.2734. (0.343 sec/step)
#
# 2017-03-11 23:57:50.280703: step 1030, error = 6.0766, accuracy = 0.1484. (0.329 sec/step)
#
# 2017-03-11 23:57:53.559342: step 1040, error = 6.0742, accuracy = 0.2031. (0.319 sec/step)
#
# 2017-03-11 23:57:56.771213: step 1050, error = 6.1875, accuracy = 0.1328. (0.308 sec/step)
#
# 2017-03-11 23:57:59.741536: step 1060, error = 6.0572, accuracy = 0.1641. (0.265 sec/step)
#
# 2017-03-11 23:58:02.454368: step 1070, error = 5.6625, accuracy = 0.2734. (0.273 sec/step)
#
# 2017-03-11 23:58:05.455973: step 1080, error = 6.1138, accuracy = 0.1562. (0.329 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1085 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:58:08.756498: step 1090, error = 5.6935, accuracy = 0.1953. (0.317 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.20519
# 2017-03-11 23:58:11.960043: step 1100, error = 5.6884, accuracy = 0.2891. (0.324 sec/step)
#
# 2017-03-11 23:58:15.201495: step 1110, error = 5.8754, accuracy = 0.1719. (0.319 sec/step)
#
# 2017-03-11 23:58:18.450781: step 1120, error = 5.5823, accuracy = 0.2656. (0.310 sec/step)
#
# 2017-03-11 23:58:21.436287: step 1130, error = 5.9341, accuracy = 0.1406. (0.278 sec/step)
#
# 2017-03-11 23:58:24.116685: step 1140, error = 5.7132, accuracy = 0.2031. (0.269 sec/step)
#
# 2017-03-11 23:58:27.206943: step 1150, error = 5.4981, accuracy = 0.2656. (0.337 sec/step)
#
# 2017-03-11 23:58:30.474116: step 1160, error = 5.7469, accuracy = 0.1953. (0.331 sec/step)
#
# 2017-03-11 23:58:33.706979: step 1170, error = 5.7165, accuracy = 0.1953. (0.317 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1181 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:58:37.233395: step 1180, error = 5.8378, accuracy = 0.1484. (0.597 sec/step)
#
# 2017-03-11 23:58:40.238821: step 1190, error = 5.4269, accuracy = 0.2344. (0.316 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.21098
# 2017-03-11 23:58:43.103446: step 1200, error = 5.5581, accuracy = 0.2344. (0.260 sec/step)
#
# 2017-03-11 23:58:45.752444: step 1210, error = 5.3950, accuracy = 0.2734. (0.273 sec/step)
#
# 2017-03-11 23:58:48.894661: step 1220, error = 5.6320, accuracy = 0.2031. (0.332 sec/step)
#
# 2017-03-11 23:58:52.071569: step 1230, error = 5.3727, accuracy = 0.1719. (0.338 sec/step)
#
# 2017-03-11 23:58:55.273739: step 1240, error = 5.6242, accuracy = 0.1953. (0.322 sec/step)
#
# 2017-03-11 23:58:58.532006: step 1250, error = 5.4719, accuracy = 0.2500. (0.328 sec/step)
#
# 2017-03-11 23:59:01.727244: step 1260, error = 5.5467, accuracy = 0.1875. (0.331 sec/step)
#
# 2017-03-11 23:59:04.610761: step 1270, error = 5.6707, accuracy = 0.1953. (0.264 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1280 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:59:07.427090: step 1280, error = 5.4680, accuracy = 0.2109. (0.144 sec/step)
#
# 2017-03-11 23:59:10.402650: step 1290, error = 5.6425, accuracy = 0.1328. (0.323 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.27067
# 2017-03-11 23:59:13.679067: step 1300, error = 5.2071, accuracy = 0.2656. (0.337 sec/step)
#
# 2017-03-11 23:59:16.924717: step 1310, error = 5.3897, accuracy = 0.2344. (0.324 sec/step)
#
# 2017-03-11 23:59:20.116221: step 1320, error = 5.1100, accuracy = 0.3281. (0.273 sec/step)
#
# 2017-03-11 23:59:23.325203: step 1330, error = 5.3614, accuracy = 0.2031. (0.324 sec/step)
#
# 2017-03-11 23:59:26.206292: step 1340, error = 5.1232, accuracy = 0.2031. (0.264 sec/step)
#
# 2017-03-11 23:59:28.881502: step 1350, error = 5.0413, accuracy = 0.2969. (0.280 sec/step)
#
# 2017-03-11 23:59:31.923759: step 1360, error = 5.2519, accuracy = 0.2031. (0.323 sec/step)
#
# 2017-03-11 23:59:35.176611: step 1370, error = 5.5287, accuracy = 0.2031. (0.347 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1377 into cifar100_vgg_model/model.ckpt.
# 2017-03-11 23:59:38.436037: step 1380, error = 5.0614, accuracy = 0.2812. (0.306 sec/step)
#
# 2017-03-11 23:59:41.712015: step 1390, error = 5.2622, accuracy = 0.2344. (0.335 sec/step)
