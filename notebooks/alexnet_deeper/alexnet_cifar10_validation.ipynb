# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar10_alexnet_model/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/test_batch.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=10)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= 50
        validation_accuracy /= 50
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(15)
# Out:
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1
# INFO:tensorflow:loss: 17.361, best accuracy: 0.098
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-68
# INFO:tensorflow:loss: 15.666, best accuracy: 0.340
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-203
# INFO:tensorflow:loss: 13.528, best accuracy: 0.378
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-266
# INFO:tensorflow:loss: 12.471, best accuracy: 0.434
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-335
# INFO:tensorflow:loss: 11.518, best accuracy: 0.469
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-467
# INFO:tensorflow:loss: 9.933, best accuracy: 0.532
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-532
# INFO:tensorflow:loss: 9.289, best accuracy: 0.520
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-668
# INFO:tensorflow:loss: 7.978, best accuracy: 0.578
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-730
# INFO:tensorflow:loss: 7.524, best accuracy: 0.587
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-797
# INFO:tensorflow:loss: 7.054, best accuracy: 0.573
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-933
# INFO:tensorflow:loss: 6.057, best accuracy: 0.621
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-995
# INFO:tensorflow:loss: 5.710, best accuracy: 0.628
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1063
# INFO:tensorflow:loss: 5.368, best accuracy: 0.618
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1196
# INFO:tensorflow:loss: 4.723, best accuracy: 0.634
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1260
# INFO:tensorflow:loss: 4.430, best accuracy: 0.650
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1329
# INFO:tensorflow:loss: 4.351, best accuracy: 0.600
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1461
# INFO:tensorflow:loss: 3.696, best accuracy: 0.667
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1527
# INFO:tensorflow:loss: 3.564, best accuracy: 0.645
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1663
# INFO:tensorflow:loss: 3.139, best accuracy: 0.669
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1725
# INFO:tensorflow:loss: 3.060, best accuracy: 0.652
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1793
# INFO:tensorflow:loss: 2.905, best accuracy: 0.655
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1926
# INFO:tensorflow:loss: 2.514, best accuracy: 0.708
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1990
# INFO:tensorflow:loss: 2.469, best accuracy: 0.687
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2058
# INFO:tensorflow:loss: 2.374, best accuracy: 0.687
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2188
# INFO:tensorflow:loss: 2.095, best accuracy: 0.717
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2253
# INFO:tensorflow:loss: 2.147, best accuracy: 0.685
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2388
# INFO:tensorflow:loss: 1.873, best accuracy: 0.718
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2450
# INFO:tensorflow:loss: 1.891, best accuracy: 0.695
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2516
# INFO:tensorflow:loss: 1.824, best accuracy: 0.701
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2650
# INFO:tensorflow:loss: 1.667, best accuracy: 0.715
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2712
# INFO:tensorflow:loss: 1.628, best accuracy: 0.726
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2780
# INFO:tensorflow:loss: 1.575, best accuracy: 0.720
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2910
# INFO:tensorflow:loss: 1.612, best accuracy: 0.702
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2974
# INFO:tensorflow:loss: 1.495, best accuracy: 0.716
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3042
