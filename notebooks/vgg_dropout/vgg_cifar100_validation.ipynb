# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar100_vgg_model/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50#int(50000/batch_size)
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar100', '../../cifar/cifar100/test.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=100)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= eval_batch_count
        validation_accuracy /= eval_batch_count
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(5)
# Out:
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1
# INFO:tensorflow:loss: 10.452, best accuracy: 0.010
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1
# INFO:tensorflow:loss: 10.452, best accuracy: 0.010
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-103
# INFO:tensorflow:loss: 9.701, best accuracy: 0.032
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-201
# INFO:tensorflow:loss: 9.062, best accuracy: 0.063
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-301
# INFO:tensorflow:loss: 8.579, best accuracy: 0.097
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-301
# INFO:tensorflow:loss: 8.579, best accuracy: 0.097
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-400
# INFO:tensorflow:loss: 8.029, best accuracy: 0.122
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-497
# INFO:tensorflow:loss: 7.728, best accuracy: 0.132
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-497
# INFO:tensorflow:loss: 7.728, best accuracy: 0.132
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-597
# INFO:tensorflow:loss: 7.370, best accuracy: 0.131
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-694
# INFO:tensorflow:loss: 6.876, best accuracy: 0.170
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-793
# INFO:tensorflow:loss: 6.568, best accuracy: 0.193
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-793
# INFO:tensorflow:loss: 6.568, best accuracy: 0.193
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-890
# INFO:tensorflow:loss: 6.401, best accuracy: 0.173
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-986
# INFO:tensorflow:loss: 5.949, best accuracy: 0.213
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-986
# INFO:tensorflow:loss: 5.949, best accuracy: 0.213
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1085
# INFO:tensorflow:loss: 5.771, best accuracy: 0.214
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1181
# INFO:tensorflow:loss: 5.489, best accuracy: 0.241
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1280
# INFO:tensorflow:loss: 5.554, best accuracy: 0.214
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1280
# INFO:tensorflow:loss: 5.554, best accuracy: 0.214
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1377
# INFO:tensorflow:loss: 5.180, best accuracy: 0.239
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1472
# INFO:tensorflow:loss: 4.916, best accuracy: 0.260
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1472
# INFO:tensorflow:loss: 4.916, best accuracy: 0.260
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1570
# INFO:tensorflow:loss: 4.877, best accuracy: 0.238
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1665
# INFO:tensorflow:loss: 4.618, best accuracy: 0.275
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1763
# INFO:tensorflow:loss: 4.426, best accuracy: 0.290
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1763
# INFO:tensorflow:loss: 4.426, best accuracy: 0.290
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1858
# INFO:tensorflow:loss: 4.293, best accuracy: 0.299
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1953
# INFO:tensorflow:loss: 4.230, best accuracy: 0.294
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-1953
# INFO:tensorflow:loss: 4.230, best accuracy: 0.294
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-2051
# INFO:tensorflow:loss: 4.263, best accuracy: 0.295
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-2146
# INFO:tensorflow:loss: 4.325, best accuracy: 0.256
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-2146
# INFO:tensorflow:loss: 4.325, best accuracy: 0.256
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-2244
# INFO:tensorflow:loss: 3.901, best accuracy: 0.311
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-2338
# INFO:tensorflow:loss: 3.732, best accuracy: 0.333
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
# INFO:tensorflow:loss: 3.240, best accuracy: 0.538
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model/model.ckpt-20000
