# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar100_vgg_model2/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50#int(50000/batch_size)
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar100', '../../cifar/cifar100/test.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=100)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= eval_batch_count
        validation_accuracy /= eval_batch_count
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(5)
# Out:
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1
# INFO:tensorflow:loss: 7.165, best accuracy: 0.011
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-73
# INFO:tensorflow:loss: 6.923, best accuracy: 0.036
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-144
# INFO:tensorflow:loss: 6.728, best accuracy: 0.053
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-144
# INFO:tensorflow:loss: 6.745, best accuracy: 0.051
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-216
# INFO:tensorflow:loss: 6.531, best accuracy: 0.071
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-286
# INFO:tensorflow:loss: 6.435, best accuracy: 0.087
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-355
# INFO:tensorflow:loss: 6.334, best accuracy: 0.095
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-424
# INFO:tensorflow:loss: 6.254, best accuracy: 0.098
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-493
# INFO:tensorflow:loss: 6.127, best accuracy: 0.125
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-562
# INFO:tensorflow:loss: 6.036, best accuracy: 0.128
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-633
# INFO:tensorflow:loss: 5.961, best accuracy: 0.135
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-633
# INFO:tensorflow:loss: 5.955, best accuracy: 0.136
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-702
# INFO:tensorflow:loss: 5.870, best accuracy: 0.147
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-771
# INFO:tensorflow:loss: 5.742, best accuracy: 0.162
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-839
# INFO:tensorflow:loss: 5.691, best accuracy: 0.171
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-907
# INFO:tensorflow:loss: 5.623, best accuracy: 0.179
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-974
# INFO:tensorflow:loss: 5.542, best accuracy: 0.185
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1044
# INFO:tensorflow:loss: 5.442, best accuracy: 0.198
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1044
# INFO:tensorflow:loss: 5.434, best accuracy: 0.203
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1114
# INFO:tensorflow:loss: 5.363, best accuracy: 0.215
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1181
# INFO:tensorflow:loss: 5.294, best accuracy: 0.223
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1248
# INFO:tensorflow:loss: 5.213, best accuracy: 0.228
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1316
# INFO:tensorflow:loss: 5.155, best accuracy: 0.239
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1384
# INFO:tensorflow:loss: 5.074, best accuracy: 0.247
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1452
# INFO:tensorflow:loss: 5.047, best accuracy: 0.249
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1522
# INFO:tensorflow:loss: 4.959, best accuracy: 0.263
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1522
# INFO:tensorflow:loss: 4.962, best accuracy: 0.267
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1590
# INFO:tensorflow:loss: 4.917, best accuracy: 0.264
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1657
# INFO:tensorflow:loss: 4.845, best accuracy: 0.273
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1723
# INFO:tensorflow:loss: 4.801, best accuracy: 0.282
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1791
# INFO:tensorflow:loss: 4.751, best accuracy: 0.286
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1858
# INFO:tensorflow:loss: 4.711, best accuracy: 0.292
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1927
# INFO:tensorflow:loss: 4.700, best accuracy: 0.287
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1927
# INFO:tensorflow:loss: 4.702, best accuracy: 0.285
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-1996
# INFO:tensorflow:loss: 4.668, best accuracy: 0.295
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2063
# INFO:tensorflow:loss: 4.619, best accuracy: 0.297
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2129
# INFO:tensorflow:loss: 4.538, best accuracy: 0.310
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2196
# INFO:tensorflow:loss: 4.485, best accuracy: 0.320
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2263
# INFO:tensorflow:loss: 4.469, best accuracy: 0.318
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2330
# INFO:tensorflow:loss: 4.413, best accuracy: 0.320
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2330
# INFO:tensorflow:loss: 4.418, best accuracy: 0.321
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2398
# INFO:tensorflow:loss: 4.391, best accuracy: 0.333
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2464
# INFO:tensorflow:loss: 4.343, best accuracy: 0.332
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2530
# INFO:tensorflow:loss: 4.308, best accuracy: 0.340
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2596
# INFO:tensorflow:loss: 4.247, best accuracy: 0.350
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2662
# INFO:tensorflow:loss: 4.237, best accuracy: 0.352
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2728
# INFO:tensorflow:loss: 4.232, best accuracy: 0.350
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2796
# INFO:tensorflow:loss: 4.154, best accuracy: 0.363
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2796
# INFO:tensorflow:loss: 4.153, best accuracy: 0.364
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2862
# INFO:tensorflow:loss: 4.129, best accuracy: 0.362
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2928
# INFO:tensorflow:loss: 4.122, best accuracy: 0.360
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-2994
# INFO:tensorflow:loss: 4.063, best accuracy: 0.371
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3060
# INFO:tensorflow:loss: 4.050, best accuracy: 0.367
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3126
# INFO:tensorflow:loss: 4.016, best accuracy: 0.369
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3194
# INFO:tensorflow:loss: 3.960, best accuracy: 0.381
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3194
# INFO:tensorflow:loss: 3.957, best accuracy: 0.378
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3260
# INFO:tensorflow:loss: 3.953, best accuracy: 0.379
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3326
# INFO:tensorflow:loss: 3.922, best accuracy: 0.379
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3392
# INFO:tensorflow:loss: 3.876, best accuracy: 0.394
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3457
# INFO:tensorflow:loss: 3.873, best accuracy: 0.387
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3523
# INFO:tensorflow:loss: 3.827, best accuracy: 0.391
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3589
# INFO:tensorflow:loss: 3.817, best accuracy: 0.390
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3655
# INFO:tensorflow:loss: 3.813, best accuracy: 0.397
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3655
# INFO:tensorflow:loss: 3.824, best accuracy: 0.395
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3720
# INFO:tensorflow:loss: 3.768, best accuracy: 0.402
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3786
# INFO:tensorflow:loss: 3.726, best accuracy: 0.408
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3851
# INFO:tensorflow:loss: 3.714, best accuracy: 0.400
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3917
# INFO:tensorflow:loss: 3.699, best accuracy: 0.410
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-3981
# INFO:tensorflow:loss: 3.641, best accuracy: 0.412
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4046
# INFO:tensorflow:loss: 3.637, best accuracy: 0.425
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4111
# INFO:tensorflow:loss: 3.612, best accuracy: 0.416
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4178
# INFO:tensorflow:loss: 3.580, best accuracy: 0.423
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4178
# INFO:tensorflow:loss: 3.598, best accuracy: 0.423
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4242
# INFO:tensorflow:loss: 3.587, best accuracy: 0.417
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4307
# INFO:tensorflow:loss: 3.526, best accuracy: 0.430
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4371
# INFO:tensorflow:loss: 3.510, best accuracy: 0.431
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4434
# INFO:tensorflow:loss: 3.488, best accuracy: 0.428
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4498
# INFO:tensorflow:loss: 3.449, best accuracy: 0.429
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4562
# INFO:tensorflow:loss: 3.441, best accuracy: 0.435
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4628
# INFO:tensorflow:loss: 3.448, best accuracy: 0.433
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4628
# INFO:tensorflow:loss: 3.443, best accuracy: 0.434
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4693
# INFO:tensorflow:loss: 3.386, best accuracy: 0.449
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4757
# INFO:tensorflow:loss: 3.388, best accuracy: 0.437
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4820
# INFO:tensorflow:loss: 3.376, best accuracy: 0.443
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4883
# INFO:tensorflow:loss: 3.372, best accuracy: 0.438
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-4946
# INFO:tensorflow:loss: 3.358, best accuracy: 0.442
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5010
# INFO:tensorflow:loss: 3.318, best accuracy: 0.450
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5076
# INFO:tensorflow:loss: 3.297, best accuracy: 0.447
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5141
# INFO:tensorflow:loss: 3.277, best accuracy: 0.453
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5205
# INFO:tensorflow:loss: 3.271, best accuracy: 0.453
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5205
# INFO:tensorflow:loss: 3.285, best accuracy: 0.448
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5270
# INFO:tensorflow:loss: 3.220, best accuracy: 0.458
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5333
# INFO:tensorflow:loss: 3.222, best accuracy: 0.461
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5397
# INFO:tensorflow:loss: 3.212, best accuracy: 0.455
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5460
# INFO:tensorflow:loss: 3.173, best accuracy: 0.463
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5524
# INFO:tensorflow:loss: 3.201, best accuracy: 0.457
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5587
# INFO:tensorflow:loss: 3.175, best accuracy: 0.453
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5651
# INFO:tensorflow:loss: 3.149, best accuracy: 0.459
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5714
# INFO:tensorflow:loss: 3.153, best accuracy: 0.458
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5779
# INFO:tensorflow:loss: 3.126, best accuracy: 0.459
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5779
# INFO:tensorflow:loss: 3.119, best accuracy: 0.464
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5843
# INFO:tensorflow:loss: 3.116, best accuracy: 0.464
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5906
# INFO:tensorflow:loss: 3.098, best accuracy: 0.461
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-5968
# INFO:tensorflow:loss: 3.079, best accuracy: 0.468
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6031
# INFO:tensorflow:loss: 3.069, best accuracy: 0.466
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6096
# INFO:tensorflow:loss: 3.039, best accuracy: 0.469
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6160
# INFO:tensorflow:loss: 3.020, best accuracy: 0.481
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6223
# INFO:tensorflow:loss: 3.005, best accuracy: 0.474
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6286
# INFO:tensorflow:loss: 3.024, best accuracy: 0.471
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6350
# INFO:tensorflow:loss: 2.989, best accuracy: 0.478
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6413
# INFO:tensorflow:loss: 2.948, best accuracy: 0.486
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6478
# INFO:tensorflow:loss: 2.953, best accuracy: 0.482
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6478
# INFO:tensorflow:loss: 2.961, best accuracy: 0.477
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6542
# INFO:tensorflow:loss: 2.952, best accuracy: 0.482
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6605
# INFO:tensorflow:loss: 2.942, best accuracy: 0.479
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6670
# INFO:tensorflow:loss: 2.939, best accuracy: 0.481
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6733
# INFO:tensorflow:loss: 2.887, best accuracy: 0.489
# INFO:tensorflow:Loading checkpoint cifar100_vgg_model2/model.ckpt-6796
