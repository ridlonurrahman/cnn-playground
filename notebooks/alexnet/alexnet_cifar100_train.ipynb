# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from datetime import datetime
from train import *
from loss import *
from accuracy import *
from model import *

import cifar_input
import os.path
import time
import numpy as np
import tensorflow as tf

# %%
max_steps = 20000
train_dir = 'cifar100_alexnet_model/'
batch_size = 128
log_device_placement = False

# %%
with tf.Graph().as_default():
    global_step = tf.contrib.framework.get_or_create_global_step()
    
    # Generating images and its labels
    # build_inputs('cifar10/cifar100', cifar dataset dir, batch size, mode)
    images, labels = cifar_input.build_input('cifar100', '../../cifar/cifar100/train.bin', batch_size, 'train')
    
    # Creating graph. NUM_CLASESS=10 (CIFAR-10) or NUM_CLASESS=100 (CIFAR-100)
    logits = inference(images, NUM_CLASSES=100)
    
    # Loss/Error and Accuracy
    losses = loss(logits, labels)
    accuracies = accuracy(logits, labels)
    
    # Our train_op (Only minimizing loss)
    train_op = train(losses, global_step, batch_size)
    
    
    # SessionRunHook. Logging will be done each x steps.
    class _LoggerHook(tf.train.SessionRunHook):
        
      def begin(self):
        self._step = -1
        # Creating train_dir if it does not exist and writing to log file
        if not os.path.exists(train_dir):
            os.makedirs(train_dir)
        open(train_dir+'training_data.csv', 'w').close()
        f = open(train_dir+"log.txt",'ab')
        f.write('\n\n==== Run ===\nInfo: Alexnet\n')
        f.close()

      def before_run(self, run_context):
        # Increment step, reset start_time, and asking for loss and accuracy tensor
        self._step += 1
        self._start_time = time.time()
        return tf.train.SessionRunArgs([losses, accuracies])

      def after_run(self, run_context, run_values):
        duration = time.time() - self._start_time # Calculating time
        loss_value = run_values.results[0]
        accuracy_value = run_values.results[1]
        # Printing log, accuracy, and loss
        if self._step % 10 == 0:
          print("{0}: step {1}, error = {2:.4f}, accuracy = {3:.4f}. ({4:.3f} sec/step)\n".format(
              datetime.now(), self._step, loss_value, accuracy_value, float(duration)))
                
          f = open(train_dir+"log.txt",'ab')
          f.write("{0}: step {1}, error = {2:.4f}, accuracy = {3:.4f}. ({4:.3f} sec/step)\n".format(
              datetime.now(), self._step, loss_value, accuracy_value, float(duration)))
          f.close()
                
          f = open(train_dir+"training_data.csv",'ab')
          f.write('{0},{1},{2}\n'.format(self._step, loss_value, accuracy_value))
          f.close()
            
    with tf.train.MonitoredTrainingSession(checkpoint_dir=train_dir,
                                           hooks=[tf.train.StopAtStepHook(last_step=max_steps),
                                                  tf.train.NanTensorHook(losses),
                                                  _LoggerHook()],save_checkpoint_secs=30, 
                                           config=tf.ConfigProto(
                                               log_device_placement=log_device_placement)) as mon_sess:
        while not mon_sess.should_stop():
            mon_sess.run(train_op)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:27:48.033402: step 0, error = 8.6898, accuracy = 0.0078. (2.223 sec/step)
#
# 2017-03-11 20:27:50.225919: step 10, error = 8.6442, accuracy = 0.0156. (0.238 sec/step)
#
# 2017-03-11 20:27:52.620549: step 20, error = 8.5897, accuracy = 0.0469. (0.235 sec/step)
#
# 2017-03-11 20:27:54.999509: step 30, error = 8.5447, accuracy = 0.0469. (0.239 sec/step)
#
# 2017-03-11 20:27:57.372246: step 40, error = 8.4984, accuracy = 0.0312. (0.241 sec/step)
#
# 2017-03-11 20:27:59.703830: step 50, error = 8.4414, accuracy = 0.0156. (0.248 sec/step)
#
# 2017-03-11 20:28:02.029446: step 60, error = 8.3400, accuracy = 0.0000. (0.224 sec/step)
#
# 2017-03-11 20:28:04.348430: step 70, error = 8.2531, accuracy = 0.0312. (0.226 sec/step)
#
# 2017-03-11 20:28:06.469661: step 80, error = 8.1410, accuracy = 0.0391. (0.228 sec/step)
#
# 2017-03-11 20:28:08.526651: step 90, error = 8.1104, accuracy = 0.0469. (0.213 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.3734
# 2017-03-11 20:28:10.773331: step 100, error = 8.0920, accuracy = 0.0391. (0.230 sec/step)
#
# 2017-03-11 20:28:13.149988: step 110, error = 7.8787, accuracy = 0.0703. (0.251 sec/step)
#
# 2017-03-11 20:28:15.498531: step 120, error = 7.9101, accuracy = 0.0625. (0.228 sec/step)
#
# 2017-03-11 20:28:17.855210: step 130, error = 7.7290, accuracy = 0.0938. (0.245 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 132 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:28:20.217810: step 140, error = 7.7648, accuracy = 0.0938. (0.244 sec/step)
#
# 2017-03-11 20:28:22.519030: step 150, error = 7.6218, accuracy = 0.0625. (0.239 sec/step)
#
# 2017-03-11 20:28:24.677065: step 160, error = 7.5902, accuracy = 0.0703. (0.208 sec/step)
#
# 2017-03-11 20:28:26.763535: step 170, error = 7.7039, accuracy = 0.0859. (0.222 sec/step)
#
# 2017-03-11 20:28:28.928841: step 180, error = 7.6370, accuracy = 0.0469. (0.230 sec/step)
#
# 2017-03-11 20:28:31.271366: step 190, error = 7.5210, accuracy = 0.0703. (0.221 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.36937
# 2017-03-11 20:28:33.658719: step 200, error = 7.2837, accuracy = 0.1094. (0.222 sec/step)
#
# 2017-03-11 20:28:36.015637: step 210, error = 7.3110, accuracy = 0.1016. (0.253 sec/step)
#
# 2017-03-11 20:28:38.336034: step 220, error = 7.3533, accuracy = 0.1328. (0.232 sec/step)
#
# 2017-03-11 20:28:40.658137: step 230, error = 7.2459, accuracy = 0.1094. (0.223 sec/step)
#
# 2017-03-11 20:28:42.931812: step 240, error = 7.1497, accuracy = 0.0781. (0.211 sec/step)
#
# 2017-03-11 20:28:45.002372: step 250, error = 7.5582, accuracy = 0.0625. (0.208 sec/step)
#
# 2017-03-11 20:28:47.156350: step 260, error = 7.4104, accuracy = 0.0938. (0.246 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 265 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:28:49.548384: step 270, error = 7.2349, accuracy = 0.1172. (0.225 sec/step)
#
# 2017-03-11 20:28:51.896528: step 280, error = 7.0082, accuracy = 0.1484. (0.232 sec/step)
#
# 2017-03-11 20:28:54.259670: step 290, error = 7.0817, accuracy = 0.1250. (0.244 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35798
# 2017-03-11 20:28:56.606927: step 300, error = 6.9729, accuracy = 0.1172. (0.239 sec/step)
#
# 2017-03-11 20:28:58.914202: step 310, error = 6.9837, accuracy = 0.1562. (0.222 sec/step)
#
# 2017-03-11 20:29:01.217180: step 320, error = 7.1658, accuracy = 0.0938. (0.200 sec/step)
#
# 2017-03-11 20:29:03.293168: step 330, error = 6.8197, accuracy = 0.1094. (0.211 sec/step)
#
# 2017-03-11 20:29:05.366330: step 340, error = 7.0238, accuracy = 0.1250. (0.219 sec/step)
#
# 2017-03-11 20:29:07.729119: step 350, error = 7.0464, accuracy = 0.0781. (0.210 sec/step)
#
# 2017-03-11 20:29:10.075424: step 360, error = 6.9060, accuracy = 0.1250. (0.241 sec/step)
#
# 2017-03-11 20:29:12.401812: step 370, error = 6.8878, accuracy = 0.0938. (0.231 sec/step)
#
# 2017-03-11 20:29:14.732484: step 380, error = 6.6272, accuracy = 0.1719. (0.227 sec/step)
#
# 2017-03-11 20:29:17.066912: step 390, error = 6.9759, accuracy = 0.1328. (0.242 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 396 into cifar100_alexnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.3862
# 2017-03-11 20:29:19.404067: step 400, error = 6.6301, accuracy = 0.1016. (0.229 sec/step)
#
# 2017-03-11 20:29:21.514125: step 410, error = 6.4326, accuracy = 0.2031. (0.218 sec/step)
#
# 2017-03-11 20:29:23.576931: step 420, error = 6.6896, accuracy = 0.1719. (0.203 sec/step)
#
# 2017-03-11 20:29:25.835588: step 430, error = 6.5419, accuracy = 0.1641. (0.225 sec/step)
#
# 2017-03-11 20:29:28.212006: step 440, error = 6.3846, accuracy = 0.1328. (0.259 sec/step)
#
# 2017-03-11 20:29:30.554140: step 450, error = 6.4750, accuracy = 0.1094. (0.240 sec/step)
#
# 2017-03-11 20:29:32.916546: step 460, error = 6.5348, accuracy = 0.0859. (0.222 sec/step)
#
# 2017-03-11 20:29:35.227437: step 470, error = 6.3338, accuracy = 0.1641. (0.245 sec/step)
#
# 2017-03-11 20:29:37.598253: step 480, error = 6.3490, accuracy = 0.1484. (0.233 sec/step)
#
# 2017-03-11 20:29:39.753964: step 490, error = 6.2255, accuracy = 0.1797. (0.205 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.4539
# 2017-03-11 20:29:41.855950: step 500, error = 6.2992, accuracy = 0.1484. (0.207 sec/step)
#
# 2017-03-11 20:29:44.129937: step 510, error = 6.2339, accuracy = 0.1797. (0.253 sec/step)
#
# 2017-03-11 20:29:46.513534: step 520, error = 6.2900, accuracy = 0.1562. (0.247 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 529 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:29:48.895285: step 530, error = 6.5280, accuracy = 0.1250. (0.236 sec/step)
#
# 2017-03-11 20:29:51.297960: step 540, error = 6.2469, accuracy = 0.1172. (0.266 sec/step)
#
# 2017-03-11 20:29:53.620680: step 550, error = 6.2215, accuracy = 0.1406. (0.232 sec/step)
#
# 2017-03-11 20:29:55.977277: step 560, error = 6.0908, accuracy = 0.1406. (0.251 sec/step)
#
# 2017-03-11 20:29:58.190634: step 570, error = 6.2722, accuracy = 0.2422. (0.212 sec/step)
#
# 2017-03-11 20:30:00.275199: step 580, error = 5.8735, accuracy = 0.2109. (0.207 sec/step)
#
# 2017-03-11 20:30:02.476692: step 590, error = 6.2718, accuracy = 0.1172. (0.233 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35454
# 2017-03-11 20:30:04.822385: step 600, error = 5.7810, accuracy = 0.2188. (0.257 sec/step)
#
# 2017-03-11 20:30:07.190217: step 610, error = 6.2418, accuracy = 0.1094. (0.232 sec/step)
#
# 2017-03-11 20:30:09.566321: step 620, error = 6.1482, accuracy = 0.1797. (0.243 sec/step)
#
# 2017-03-11 20:30:11.849871: step 630, error = 5.9138, accuracy = 0.1641. (0.232 sec/step)
#
# 2017-03-11 20:30:14.254862: step 640, error = 5.9870, accuracy = 0.1641. (0.207 sec/step)
#
# 2017-03-11 20:30:16.540451: step 650, error = 5.7301, accuracy = 0.1406. (0.198 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 660 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:30:18.667042: step 660, error = 5.8202, accuracy = 0.2109. (0.090 sec/step)
#
# 2017-03-11 20:30:20.826198: step 670, error = 5.9492, accuracy = 0.1875. (0.258 sec/step)
#
# 2017-03-11 20:30:23.203043: step 680, error = 5.7941, accuracy = 0.1953. (0.234 sec/step)
#
# 2017-03-11 20:30:25.582575: step 690, error = 5.9879, accuracy = 0.1016. (0.248 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.31576
# 2017-03-11 20:30:27.993120: step 700, error = 5.9408, accuracy = 0.1328. (0.242 sec/step)
#
# 2017-03-11 20:30:30.389750: step 710, error = 5.8064, accuracy = 0.1797. (0.248 sec/step)
#
# 2017-03-11 20:30:32.790622: step 720, error = 5.6878, accuracy = 0.1641. (0.262 sec/step)
#
# 2017-03-11 20:30:35.091510: step 730, error = 5.7283, accuracy = 0.1641. (0.230 sec/step)
#
# 2017-03-11 20:30:37.160875: step 740, error = 5.7835, accuracy = 0.1797. (0.201 sec/step)
#
# 2017-03-11 20:30:39.320497: step 750, error = 5.6445, accuracy = 0.1562. (0.226 sec/step)
#
# 2017-03-11 20:30:41.703797: step 760, error = 5.5148, accuracy = 0.2422. (0.244 sec/step)
#
# 2017-03-11 20:30:44.053935: step 770, error = 5.4362, accuracy = 0.2266. (0.242 sec/step)
#
# 2017-03-11 20:30:46.423301: step 780, error = 5.8863, accuracy = 0.1484. (0.248 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 790 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:30:48.746007: step 790, error = 5.7299, accuracy = 0.1094. (0.092 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.31872
# 2017-03-11 20:30:51.146729: step 800, error = 5.5762, accuracy = 0.1953. (0.238 sec/step)
#
# 2017-03-11 20:30:53.438956: step 810, error = 5.5209, accuracy = 0.1875. (0.216 sec/step)
#
# 2017-03-11 20:30:55.540458: step 820, error = 5.4674, accuracy = 0.2188. (0.207 sec/step)
#
# 2017-03-11 20:30:57.646612: step 830, error = 5.6669, accuracy = 0.1875. (0.207 sec/step)
#
# 2017-03-11 20:30:59.992398: step 840, error = 5.4565, accuracy = 0.1562. (0.241 sec/step)
#
# 2017-03-11 20:31:02.373672: step 850, error = 5.2931, accuracy = 0.2266. (0.237 sec/step)
#
# 2017-03-11 20:31:04.677403: step 860, error = 5.3010, accuracy = 0.2188. (0.238 sec/step)
#
# 2017-03-11 20:31:07.043017: step 870, error = 5.3125, accuracy = 0.1875. (0.247 sec/step)
#
# 2017-03-11 20:31:09.354206: step 880, error = 5.4815, accuracy = 0.1797. (0.212 sec/step)
#
# 2017-03-11 20:31:11.675708: step 890, error = 5.4488, accuracy = 0.1875. (0.236 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.40841
# 2017-03-11 20:31:13.830764: step 900, error = 5.4120, accuracy = 0.2188. (0.211 sec/step)
#
# 2017-03-11 20:31:15.923360: step 910, error = 5.5093, accuracy = 0.1797. (0.201 sec/step)
#
# 2017-03-11 20:31:18.163935: step 920, error = 5.3664, accuracy = 0.2109. (0.221 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 923 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:31:20.652437: step 930, error = 5.1483, accuracy = 0.2188. (0.213 sec/step)
#
# 2017-03-11 20:31:23.008280: step 940, error = 4.9490, accuracy = 0.2891. (0.220 sec/step)
#
# 2017-03-11 20:31:25.328404: step 950, error = 5.1842, accuracy = 0.1953. (0.248 sec/step)
#
# 2017-03-11 20:31:27.656326: step 960, error = 5.3491, accuracy = 0.1719. (0.240 sec/step)
#
# 2017-03-11 20:31:30.016942: step 970, error = 5.4060, accuracy = 0.1328. (0.239 sec/step)
#
# 2017-03-11 20:31:32.194434: step 980, error = 5.0255, accuracy = 0.2969. (0.206 sec/step)
#
# 2017-03-11 20:31:34.297468: step 990, error = 5.2719, accuracy = 0.2031. (0.217 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.40937
# 2017-03-11 20:31:36.509194: step 1000, error = 5.4429, accuracy = 0.1562. (0.233 sec/step)
#
# 2017-03-11 20:31:38.843677: step 1010, error = 5.1895, accuracy = 0.1797. (0.236 sec/step)
#
# 2017-03-11 20:31:41.153612: step 1020, error = 5.0707, accuracy = 0.2578. (0.234 sec/step)
#
# 2017-03-11 20:31:43.459127: step 1030, error = 4.9742, accuracy = 0.2109. (0.208 sec/step)
#
# 2017-03-11 20:31:45.788919: step 1040, error = 5.0978, accuracy = 0.2188. (0.243 sec/step)
#
# 2017-03-11 20:31:48.082938: step 1050, error = 4.9800, accuracy = 0.2500. (0.207 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1054 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:31:50.449062: step 1060, error = 5.0070, accuracy = 0.2578. (0.211 sec/step)
#
# 2017-03-11 20:31:52.543022: step 1070, error = 4.9891, accuracy = 0.2344. (0.199 sec/step)
#
# 2017-03-11 20:31:54.636396: step 1080, error = 4.9051, accuracy = 0.2188. (0.206 sec/step)
#
# 2017-03-11 20:31:57.038274: step 1090, error = 4.8829, accuracy = 0.1719. (0.229 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.36821
# 2017-03-11 20:31:59.401750: step 1100, error = 5.0439, accuracy = 0.2188. (0.249 sec/step)
#
# 2017-03-11 20:32:01.733073: step 1110, error = 5.1955, accuracy = 0.2188. (0.215 sec/step)
#
# 2017-03-11 20:32:04.129181: step 1120, error = 4.6200, accuracy = 0.3047. (0.240 sec/step)
#
# 2017-03-11 20:32:06.473966: step 1130, error = 4.6474, accuracy = 0.2891. (0.250 sec/step)
#
# 2017-03-11 20:32:08.787100: step 1140, error = 4.8668, accuracy = 0.2422. (0.217 sec/step)
#
# 2017-03-11 20:32:10.920871: step 1150, error = 4.8711, accuracy = 0.2578. (0.199 sec/step)
#
# 2017-03-11 20:32:13.012367: step 1160, error = 4.9515, accuracy = 0.1641. (0.202 sec/step)
#
# 2017-03-11 20:32:15.262548: step 1170, error = 4.9210, accuracy = 0.2344. (0.235 sec/step)
#
# 2017-03-11 20:32:17.604211: step 1180, error = 4.6724, accuracy = 0.2656. (0.245 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1187 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:32:19.995275: step 1190, error = 4.6600, accuracy = 0.2188. (0.257 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35988
# 2017-03-11 20:32:22.338394: step 1200, error = 4.8986, accuracy = 0.2578. (0.260 sec/step)
#
# 2017-03-11 20:32:24.678215: step 1210, error = 4.8587, accuracy = 0.1953. (0.244 sec/step)
#
# 2017-03-11 20:32:27.009141: step 1220, error = 4.9707, accuracy = 0.2344. (0.230 sec/step)
#
# 2017-03-11 20:32:29.206646: step 1230, error = 4.4339, accuracy = 0.2734. (0.214 sec/step)
#
# 2017-03-11 20:32:31.313005: step 1240, error = 5.0178, accuracy = 0.1719. (0.217 sec/step)
#
# 2017-03-11 20:32:33.528150: step 1250, error = 4.6036, accuracy = 0.2109. (0.252 sec/step)
#
# 2017-03-11 20:32:35.879704: step 1260, error = 4.5478, accuracy = 0.2656. (0.232 sec/step)
#
# 2017-03-11 20:32:38.225578: step 1270, error = 4.7109, accuracy = 0.1875. (0.235 sec/step)
#
# 2017-03-11 20:32:40.555160: step 1280, error = 4.6602, accuracy = 0.2422. (0.244 sec/step)
#
# 2017-03-11 20:32:42.931438: step 1290, error = 4.5844, accuracy = 0.2266. (0.246 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35559
# 2017-03-11 20:32:45.299225: step 1300, error = 4.8237, accuracy = 0.2188. (0.251 sec/step)
#
# 2017-03-11 20:32:47.553567: step 1310, error = 4.3952, accuracy = 0.2812. (0.211 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1318 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:32:49.662213: step 1320, error = 4.5383, accuracy = 0.2656. (0.200 sec/step)
#
# 2017-03-11 20:32:51.774784: step 1330, error = 4.3356, accuracy = 0.2891. (0.219 sec/step)
#
# 2017-03-11 20:32:54.165998: step 1340, error = 4.7493, accuracy = 0.2344. (0.228 sec/step)
#
# 2017-03-11 20:32:56.530872: step 1350, error = 4.5733, accuracy = 0.2969. (0.229 sec/step)
#
# 2017-03-11 20:32:58.868007: step 1360, error = 4.3858, accuracy = 0.2812. (0.225 sec/step)
#
# 2017-03-11 20:33:01.232173: step 1370, error = 4.3841, accuracy = 0.2188. (0.246 sec/step)
#
# 2017-03-11 20:33:03.523603: step 1380, error = 4.3421, accuracy = 0.2500. (0.246 sec/step)
#
# 2017-03-11 20:33:05.786985: step 1390, error = 4.5816, accuracy = 0.2578. (0.228 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.42172
# 2017-03-11 20:33:07.913268: step 1400, error = 4.2282, accuracy = 0.3047. (0.209 sec/step)
#
# 2017-03-11 20:33:10.006415: step 1410, error = 4.7207, accuracy = 0.2109. (0.215 sec/step)
#
# 2017-03-11 20:33:12.288683: step 1420, error = 4.4865, accuracy = 0.2578. (0.222 sec/step)
#
# 2017-03-11 20:33:14.674809: step 1430, error = 4.5100, accuracy = 0.2266. (0.242 sec/step)
#
# 2017-03-11 20:33:17.085529: step 1440, error = 4.2657, accuracy = 0.2812. (0.230 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1450 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:33:19.468082: step 1450, error = 4.5453, accuracy = 0.2500. (0.106 sec/step)
#
# 2017-03-11 20:33:21.847013: step 1460, error = 4.3594, accuracy = 0.3203. (0.232 sec/step)
#
# 2017-03-11 20:33:24.194857: step 1470, error = 4.4787, accuracy = 0.2266. (0.227 sec/step)
#
# 2017-03-11 20:33:26.381306: step 1480, error = 4.3039, accuracy = 0.2812. (0.212 sec/step)
#
# 2017-03-11 20:33:28.496979: step 1490, error = 4.4011, accuracy = 0.2656. (0.206 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.37158
# 2017-03-11 20:33:30.787992: step 1500, error = 4.0306, accuracy = 0.3047. (0.261 sec/step)
#
# 2017-03-11 20:33:33.179320: step 1510, error = 4.3247, accuracy = 0.2344. (0.244 sec/step)
#
# 2017-03-11 20:33:35.541151: step 1520, error = 4.1960, accuracy = 0.3203. (0.191 sec/step)
#
# 2017-03-11 20:33:37.927405: step 1530, error = 4.3938, accuracy = 0.2734. (0.256 sec/step)
#
# 2017-03-11 20:33:40.240710: step 1540, error = 4.3186, accuracy = 0.2500. (0.228 sec/step)
#
# 2017-03-11 20:33:42.566303: step 1550, error = 3.9949, accuracy = 0.3203. (0.219 sec/step)
#
# 2017-03-11 20:33:44.819944: step 1560, error = 4.1505, accuracy = 0.3281. (0.216 sec/step)
#
# 2017-03-11 20:33:46.936310: step 1570, error = 3.8665, accuracy = 0.3359. (0.214 sec/step)
#
# 2017-03-11 20:33:49.094011: step 1580, error = 4.1647, accuracy = 0.2656. (0.234 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1582 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:33:51.477213: step 1590, error = 4.3321, accuracy = 0.2109. (0.225 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.33356
# 2017-03-11 20:33:53.863802: step 1600, error = 4.1128, accuracy = 0.2891. (0.249 sec/step)
#
# 2017-03-11 20:33:56.159257: step 1610, error = 4.2969, accuracy = 0.2422. (0.246 sec/step)
#
# 2017-03-11 20:33:58.514449: step 1620, error = 4.0507, accuracy = 0.3125. (0.243 sec/step)
#
# 2017-03-11 20:34:00.798043: step 1630, error = 4.0218, accuracy = 0.3047. (0.240 sec/step)
#
# 2017-03-11 20:34:03.120524: step 1640, error = 4.1254, accuracy = 0.2812. (0.207 sec/step)
#
# 2017-03-11 20:34:05.248096: step 1650, error = 3.8808, accuracy = 0.2969. (0.211 sec/step)
#
# 2017-03-11 20:34:07.364723: step 1660, error = 4.0279, accuracy = 0.3359. (0.213 sec/step)
#
# 2017-03-11 20:34:09.725778: step 1670, error = 4.0753, accuracy = 0.2812. (0.246 sec/step)
#
# 2017-03-11 20:34:12.032144: step 1680, error = 3.7589, accuracy = 0.3516. (0.249 sec/step)
#
# 2017-03-11 20:34:14.383501: step 1690, error = 4.1977, accuracy = 0.2500. (0.234 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.37002
# 2017-03-11 20:34:16.748911: step 1700, error = 4.4130, accuracy = 0.2188. (0.230 sec/step)
#
# 2017-03-11 20:34:19.092440: step 1710, error = 3.9469, accuracy = 0.2969. (0.208 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1713 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:34:21.417265: step 1720, error = 4.0532, accuracy = 0.3047. (0.226 sec/step)
#
# 2017-03-11 20:34:23.609372: step 1730, error = 4.0915, accuracy = 0.2344. (0.209 sec/step)
#
# 2017-03-11 20:34:25.738142: step 1740, error = 3.9342, accuracy = 0.3047. (0.210 sec/step)
#
# 2017-03-11 20:34:28.021462: step 1750, error = 4.1878, accuracy = 0.2656. (0.242 sec/step)
#
# 2017-03-11 20:34:30.406336: step 1760, error = 4.1497, accuracy = 0.3125. (0.241 sec/step)
#
# 2017-03-11 20:34:32.763631: step 1770, error = 3.9505, accuracy = 0.3125. (0.243 sec/step)
#
# 2017-03-11 20:34:35.099412: step 1780, error = 3.8186, accuracy = 0.2891. (0.219 sec/step)
#
# 2017-03-11 20:34:37.396864: step 1790, error = 3.6953, accuracy = 0.3750. (0.216 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35151
# 2017-03-11 20:34:39.730046: step 1800, error = 3.8695, accuracy = 0.3047. (0.248 sec/step)
#
# 2017-03-11 20:34:42.016783: step 1810, error = 3.4131, accuracy = 0.3750. (0.219 sec/step)
#
# 2017-03-11 20:34:44.122006: step 1820, error = 3.9105, accuracy = 0.2969. (0.207 sec/step)
#
# 2017-03-11 20:34:46.281263: step 1830, error = 4.0364, accuracy = 0.2578. (0.246 sec/step)
#
# 2017-03-11 20:34:48.647849: step 1840, error = 3.7812, accuracy = 0.3203. (0.217 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1845 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:34:51.028768: step 1850, error = 4.1345, accuracy = 0.2031. (0.242 sec/step)
#
# 2017-03-11 20:34:53.369435: step 1860, error = 4.0256, accuracy = 0.2578. (0.250 sec/step)
#
# 2017-03-11 20:34:55.740006: step 1870, error = 3.5819, accuracy = 0.3438. (0.224 sec/step)
#
# 2017-03-11 20:34:58.112873: step 1880, error = 3.8116, accuracy = 0.2812. (0.246 sec/step)
#
# 2017-03-11 20:35:00.421160: step 1890, error = 3.9923, accuracy = 0.2266. (0.225 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.37929
# 2017-03-11 20:35:02.562220: step 1900, error = 3.5285, accuracy = 0.3672. (0.228 sec/step)
#
# 2017-03-11 20:35:04.685032: step 1910, error = 3.6460, accuracy = 0.3281. (0.226 sec/step)
#
# 2017-03-11 20:35:06.990603: step 1920, error = 3.9514, accuracy = 0.2500. (0.235 sec/step)
#
# 2017-03-11 20:35:09.421364: step 1930, error = 3.7763, accuracy = 0.3516. (0.254 sec/step)
#
# 2017-03-11 20:35:11.773691: step 1940, error = 3.8518, accuracy = 0.3281. (0.207 sec/step)
#
# 2017-03-11 20:35:14.153087: step 1950, error = 3.8909, accuracy = 0.2812. (0.261 sec/step)
#
# 2017-03-11 20:35:16.506680: step 1960, error = 3.8975, accuracy = 0.2578. (0.238 sec/step)
#
# 2017-03-11 20:35:18.841960: step 1970, error = 3.7894, accuracy = 0.3125. (0.227 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 1975 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:35:21.026251: step 1980, error = 3.5892, accuracy = 0.3438. (0.213 sec/step)
#
# 2017-03-11 20:35:23.177380: step 1990, error = 3.8410, accuracy = 0.3281. (0.223 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35939
# 2017-03-11 20:35:25.503255: step 2000, error = 3.6637, accuracy = 0.2812. (0.249 sec/step)
#
# 2017-03-11 20:35:27.794017: step 2010, error = 3.7474, accuracy = 0.2656. (0.237 sec/step)
#
# 2017-03-11 20:35:30.118507: step 2020, error = 3.8334, accuracy = 0.2812. (0.233 sec/step)
#
# 2017-03-11 20:35:32.491995: step 2030, error = 3.7787, accuracy = 0.2812. (0.234 sec/step)
#
# 2017-03-11 20:35:34.863757: step 2040, error = 3.8657, accuracy = 0.3047. (0.237 sec/step)
#
# 2017-03-11 20:35:37.251242: step 2050, error = 3.8443, accuracy = 0.2422. (0.246 sec/step)
#
# 2017-03-11 20:35:39.489139: step 2060, error = 3.8846, accuracy = 0.2344. (0.212 sec/step)
#
# 2017-03-11 20:35:41.605364: step 2070, error = 3.9777, accuracy = 0.2734. (0.214 sec/step)
#
# 2017-03-11 20:35:43.813925: step 2080, error = 3.5962, accuracy = 0.2969. (0.238 sec/step)
#
# 2017-03-11 20:35:46.106880: step 2090, error = 3.6908, accuracy = 0.2734. (0.237 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.34559
# 2017-03-11 20:35:48.514906: step 2100, error = 3.5235, accuracy = 0.3516. (0.256 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2107 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:35:50.983629: step 2110, error = 3.6303, accuracy = 0.3281. (0.251 sec/step)
#
# 2017-03-11 20:35:53.345572: step 2120, error = 3.7035, accuracy = 0.2812. (0.262 sec/step)
#
# 2017-03-11 20:35:55.719397: step 2130, error = 3.6367, accuracy = 0.3047. (0.232 sec/step)
#
# 2017-03-11 20:35:58.038620: step 2140, error = 3.5929, accuracy = 0.3359. (0.213 sec/step)
#
# 2017-03-11 20:36:00.164858: step 2150, error = 3.7806, accuracy = 0.2656. (0.218 sec/step)
#
# 2017-03-11 20:36:02.339399: step 2160, error = 3.5516, accuracy = 0.3125. (0.244 sec/step)
#
# 2017-03-11 20:36:04.720370: step 2170, error = 3.4891, accuracy = 0.3359. (0.251 sec/step)
#
# 2017-03-11 20:36:07.129026: step 2180, error = 3.6255, accuracy = 0.2812. (0.223 sec/step)
#
# 2017-03-11 20:36:09.522907: step 2190, error = 3.7798, accuracy = 0.2578. (0.248 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.27612
# 2017-03-11 20:36:11.899159: step 2200, error = 3.8107, accuracy = 0.2578. (0.234 sec/step)
#
# 2017-03-11 20:36:14.256491: step 2210, error = 3.6056, accuracy = 0.3438. (0.207 sec/step)
#
# 2017-03-11 20:36:16.604192: step 2220, error = 3.6124, accuracy = 0.3516. (0.214 sec/step)
#
# 2017-03-11 20:36:18.747624: step 2230, error = 3.6151, accuracy = 0.3047. (0.227 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2237 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:36:20.905629: step 2240, error = 3.4524, accuracy = 0.3125. (0.217 sec/step)
#
# 2017-03-11 20:36:23.334154: step 2250, error = 3.6054, accuracy = 0.3203. (0.258 sec/step)
#
# 2017-03-11 20:36:25.709617: step 2260, error = 3.5330, accuracy = 0.2891. (0.243 sec/step)
#
# 2017-03-11 20:36:28.089084: step 2270, error = 3.3623, accuracy = 0.3359. (0.219 sec/step)
#
# 2017-03-11 20:36:30.504411: step 2280, error = 3.4450, accuracy = 0.3281. (0.215 sec/step)
#
# 2017-03-11 20:36:32.883063: step 2290, error = 3.5486, accuracy = 0.3281. (0.246 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.27609
# 2017-03-11 20:36:35.284754: step 2300, error = 3.1300, accuracy = 0.3906. (0.232 sec/step)
#
# 2017-03-11 20:36:37.430765: step 2310, error = 3.6066, accuracy = 0.2656. (0.232 sec/step)
#
# 2017-03-11 20:36:39.573051: step 2320, error = 3.4681, accuracy = 0.2891. (0.225 sec/step)
#
# 2017-03-11 20:36:41.889676: step 2330, error = 3.6058, accuracy = 0.3438. (0.261 sec/step)
#
# 2017-03-11 20:36:44.274865: step 2340, error = 3.5503, accuracy = 0.3203. (0.230 sec/step)
#
# 2017-03-11 20:36:46.671548: step 2350, error = 3.5285, accuracy = 0.2969. (0.234 sec/step)
#
# 2017-03-11 20:36:49.130188: step 2360, error = 3.4034, accuracy = 0.3672. (0.252 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2365 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:36:51.571268: step 2370, error = 3.2714, accuracy = 0.3594. (0.218 sec/step)
#
# 2017-03-11 20:36:53.960252: step 2380, error = 3.6679, accuracy = 0.2734. (0.259 sec/step)
#
# 2017-03-11 20:36:56.114071: step 2390, error = 3.4713, accuracy = 0.2812. (0.218 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.35526
# 2017-03-11 20:36:58.245683: step 2400, error = 3.3440, accuracy = 0.3438. (0.204 sec/step)
#
# 2017-03-11 20:37:00.566643: step 2410, error = 3.3375, accuracy = 0.3594. (0.243 sec/step)
#
# 2017-03-11 20:37:02.947967: step 2420, error = 3.4555, accuracy = 0.3203. (0.235 sec/step)
#
# 2017-03-11 20:37:05.355247: step 2430, error = 3.3393, accuracy = 0.3672. (0.205 sec/step)
#
# 2017-03-11 20:37:07.745560: step 2440, error = 3.5388, accuracy = 0.3516. (0.238 sec/step)
#
# 2017-03-11 20:37:10.150411: step 2450, error = 3.5647, accuracy = 0.2891. (0.243 sec/step)
#
# 2017-03-11 20:37:12.589118: step 2460, error = 3.0792, accuracy = 0.3750. (0.261 sec/step)
#
# 2017-03-11 20:37:14.771580: step 2470, error = 3.4021, accuracy = 0.3594. (0.211 sec/step)
#
# 2017-03-11 20:37:16.922035: step 2480, error = 3.5477, accuracy = 0.3359. (0.215 sec/step)
#
# 2017-03-11 20:37:19.217478: step 2490, error = 3.4257, accuracy = 0.3281. (0.251 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2495 into cifar100_alexnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.27501
# 2017-03-11 20:37:21.637503: step 2500, error = 3.4688, accuracy = 0.3047. (0.237 sec/step)
#
# 2017-03-11 20:37:24.079457: step 2510, error = 3.4615, accuracy = 0.3203. (0.272 sec/step)
#
# 2017-03-11 20:37:26.485229: step 2520, error = 3.5781, accuracy = 0.2656. (0.257 sec/step)
#
# 2017-03-11 20:37:28.933174: step 2530, error = 3.4679, accuracy = 0.2891. (0.254 sec/step)
#
# 2017-03-11 20:37:31.331034: step 2540, error = 3.2013, accuracy = 0.3750. (0.248 sec/step)
#
# 2017-03-11 20:37:33.533146: step 2550, error = 3.0252, accuracy = 0.3984. (0.212 sec/step)
#
# 2017-03-11 20:37:35.656441: step 2560, error = 3.0823, accuracy = 0.3828. (0.212 sec/step)
#
# 2017-03-11 20:37:37.942843: step 2570, error = 3.1521, accuracy = 0.3516. (0.227 sec/step)
#
# 2017-03-11 20:37:40.360894: step 2580, error = 3.2886, accuracy = 0.3750. (0.252 sec/step)
#
# 2017-03-11 20:37:42.705334: step 2590, error = 3.1238, accuracy = 0.3594. (0.244 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.24094
# 2017-03-11 20:37:45.218916: step 2600, error = 3.4206, accuracy = 0.3125. (0.263 sec/step)
#
# 2017-03-11 20:37:47.594966: step 2610, error = 3.4433, accuracy = 0.3438. (0.214 sec/step)
#
# 2017-03-11 20:37:50.022928: step 2620, error = 3.4744, accuracy = 0.3047. (0.234 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2622 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:37:52.288309: step 2630, error = 3.2662, accuracy = 0.3438. (0.212 sec/step)
#
# 2017-03-11 20:37:54.448283: step 2640, error = 3.0242, accuracy = 0.3984. (0.234 sec/step)
#
# 2017-03-11 20:37:56.768475: step 2650, error = 3.0946, accuracy = 0.4141. (0.245 sec/step)
#
# 2017-03-11 20:37:59.242772: step 2660, error = 2.9387, accuracy = 0.4844. (0.267 sec/step)
#
# 2017-03-11 20:38:01.655646: step 2670, error = 3.4826, accuracy = 0.2500. (0.230 sec/step)
#
# 2017-03-11 20:38:03.998924: step 2680, error = 3.1370, accuracy = 0.3516. (0.209 sec/step)
#
# 2017-03-11 20:38:06.448732: step 2690, error = 3.2692, accuracy = 0.2969. (0.266 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.22534
# 2017-03-11 20:38:08.883418: step 2700, error = 3.1165, accuracy = 0.3750. (0.257 sec/step)
#
# 2017-03-11 20:38:11.108473: step 2710, error = 2.9437, accuracy = 0.3984. (0.216 sec/step)
#
# 2017-03-11 20:38:13.244409: step 2720, error = 3.4656, accuracy = 0.3125. (0.212 sec/step)
#
# 2017-03-11 20:38:15.611916: step 2730, error = 3.2110, accuracy = 0.3750. (0.256 sec/step)
#
# 2017-03-11 20:38:18.028536: step 2740, error = 3.3150, accuracy = 0.3594. (0.252 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2751 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:38:20.640706: step 2750, error = 3.0562, accuracy = 0.3906. (0.404 sec/step)
#
# 2017-03-11 20:38:22.904679: step 2760, error = 3.2340, accuracy = 0.3516. (0.227 sec/step)
#
# 2017-03-11 20:38:25.352764: step 2770, error = 3.0195, accuracy = 0.3438. (0.277 sec/step)
#
# 2017-03-11 20:38:27.770065: step 2780, error = 2.8732, accuracy = 0.4453. (0.250 sec/step)
#
# 2017-03-11 20:38:29.968396: step 2790, error = 3.3828, accuracy = 0.3516. (0.203 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.30634
# 2017-03-11 20:38:32.104922: step 2800, error = 3.2974, accuracy = 0.3281. (0.220 sec/step)
#
# 2017-03-11 20:38:34.424488: step 2810, error = 2.9177, accuracy = 0.4297. (0.247 sec/step)
#
# 2017-03-11 20:38:36.907361: step 2820, error = 3.0588, accuracy = 0.3750. (0.247 sec/step)
#
# 2017-03-11 20:38:39.320678: step 2830, error = 3.4752, accuracy = 0.3125. (0.253 sec/step)
#
# 2017-03-11 20:38:41.733682: step 2840, error = 3.1494, accuracy = 0.3750. (0.272 sec/step)
#
# 2017-03-11 20:38:44.079574: step 2850, error = 3.1220, accuracy = 0.3828. (0.243 sec/step)
#
# 2017-03-11 20:38:46.534573: step 2860, error = 2.8604, accuracy = 0.3828. (0.227 sec/step)
#
# 2017-03-11 20:38:48.748385: step 2870, error = 3.3516, accuracy = 0.3281. (0.211 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 2880 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:38:50.915758: step 2880, error = 3.3301, accuracy = 0.3594. (0.086 sec/step)
#
# 2017-03-11 20:38:53.255386: step 2890, error = 3.1233, accuracy = 0.3594. (0.217 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.23588
# 2017-03-11 20:38:55.712917: step 2900, error = 3.2131, accuracy = 0.3359. (0.237 sec/step)
#
# 2017-03-11 20:38:58.166170: step 2910, error = 3.0783, accuracy = 0.3750. (0.260 sec/step)
#
# 2017-03-11 20:39:00.616720: step 2920, error = 3.0164, accuracy = 0.3672. (0.258 sec/step)
#
# 2017-03-11 20:39:03.084463: step 2930, error = 3.1674, accuracy = 0.3203. (0.262 sec/step)
#
# 2017-03-11 20:39:05.511741: step 2940, error = 2.9556, accuracy = 0.3359. (0.243 sec/step)
#
# 2017-03-11 20:39:07.705714: step 2950, error = 3.0461, accuracy = 0.3516. (0.222 sec/step)
#
# 2017-03-11 20:39:09.877588: step 2960, error = 2.9219, accuracy = 0.3984. (0.225 sec/step)
#
# 2017-03-11 20:39:12.257740: step 2970, error = 2.9146, accuracy = 0.4219. (0.254 sec/step)
#
# 2017-03-11 20:39:14.712074: step 2980, error = 2.9054, accuracy = 0.4688. (0.248 sec/step)
#
# 2017-03-11 20:39:17.166739: step 2990, error = 2.9934, accuracy = 0.3906. (0.235 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.18286
# 2017-03-11 20:39:19.620443: step 3000, error = 2.9199, accuracy = 0.3828. (0.247 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3006 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:39:22.109624: step 3010, error = 2.9601, accuracy = 0.4219. (0.247 sec/step)
#
# 2017-03-11 20:39:24.573416: step 3020, error = 3.1098, accuracy = 0.3438. (0.248 sec/step)
#
# 2017-03-11 20:39:26.727456: step 3030, error = 2.8803, accuracy = 0.4375. (0.220 sec/step)
#
# 2017-03-11 20:39:28.867748: step 3040, error = 3.2155, accuracy = 0.3125. (0.219 sec/step)
#
# 2017-03-11 20:39:31.298603: step 3050, error = 3.0857, accuracy = 0.3281. (0.242 sec/step)
#
# 2017-03-11 20:39:33.758729: step 3060, error = 3.1566, accuracy = 0.3984. (0.268 sec/step)
#
# 2017-03-11 20:39:36.184707: step 3070, error = 3.1344, accuracy = 0.3750. (0.261 sec/step)
#
# 2017-03-11 20:39:38.636862: step 3080, error = 3.0637, accuracy = 0.3516. (0.246 sec/step)
#
# 2017-03-11 20:39:41.065636: step 3090, error = 3.2225, accuracy = 0.3047. (0.248 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.18836
# 2017-03-11 20:39:43.495900: step 3100, error = 2.9006, accuracy = 0.3750. (0.212 sec/step)
#
# 2017-03-11 20:39:45.643999: step 3110, error = 2.8873, accuracy = 0.4375. (0.200 sec/step)
#
# 2017-03-11 20:39:47.797483: step 3120, error = 2.9252, accuracy = 0.3828. (0.224 sec/step)
#
# 2017-03-11 20:39:50.270929: step 3130, error = 3.1408, accuracy = 0.3516. (0.239 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3134 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:39:52.793040: step 3140, error = 2.9713, accuracy = 0.3516. (0.244 sec/step)
#
# 2017-03-11 20:39:55.287932: step 3150, error = 3.2973, accuracy = 0.3359. (0.281 sec/step)
#
# 2017-03-11 20:39:57.718595: step 3160, error = 2.9024, accuracy = 0.3906. (0.244 sec/step)
#
# 2017-03-11 20:40:00.181055: step 3170, error = 3.0083, accuracy = 0.3906. (0.246 sec/step)
#
# 2017-03-11 20:40:02.489902: step 3180, error = 2.7840, accuracy = 0.4375. (0.212 sec/step)
#
# 2017-03-11 20:40:04.639420: step 3190, error = 2.9144, accuracy = 0.4062. (0.205 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.26274
# 2017-03-11 20:40:06.954507: step 3200, error = 2.7259, accuracy = 0.3672. (0.268 sec/step)
#
# 2017-03-11 20:40:09.422748: step 3210, error = 2.9980, accuracy = 0.3672. (0.248 sec/step)
#
# 2017-03-11 20:40:11.939954: step 3220, error = 3.1347, accuracy = 0.3125. (0.246 sec/step)
#
# 2017-03-11 20:40:14.447070: step 3230, error = 3.0634, accuracy = 0.3828. (0.286 sec/step)
#
# 2017-03-11 20:40:16.894380: step 3240, error = 3.0976, accuracy = 0.3359. (0.258 sec/step)
#
# 2017-03-11 20:40:19.323338: step 3250, error = 2.9009, accuracy = 0.3828. (0.233 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3259 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:40:21.645841: step 3260, error = 2.9312, accuracy = 0.3594. (0.206 sec/step)
#
# 2017-03-11 20:40:23.783678: step 3270, error = 3.0707, accuracy = 0.3281. (0.212 sec/step)
#
# 2017-03-11 20:40:26.121027: step 3280, error = 3.1132, accuracy = 0.3594. (0.265 sec/step)
#
# 2017-03-11 20:40:28.521103: step 3290, error = 2.8813, accuracy = 0.4141. (0.242 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.15357
# 2017-03-11 20:40:31.030825: step 3300, error = 2.8654, accuracy = 0.3516. (0.266 sec/step)
#
# 2017-03-11 20:40:33.463098: step 3310, error = 2.9602, accuracy = 0.4141. (0.244 sec/step)
#
# 2017-03-11 20:40:35.852015: step 3320, error = 3.2769, accuracy = 0.3438. (0.207 sec/step)
#
# 2017-03-11 20:40:38.326012: step 3330, error = 3.0947, accuracy = 0.3594. (0.253 sec/step)
#
# 2017-03-11 20:40:40.561399: step 3340, error = 3.0809, accuracy = 0.3594. (0.211 sec/step)
#
# 2017-03-11 20:40:42.700543: step 3350, error = 2.9031, accuracy = 0.3594. (0.209 sec/step)
#
# 2017-03-11 20:40:45.029136: step 3360, error = 2.8740, accuracy = 0.3672. (0.243 sec/step)
#
# 2017-03-11 20:40:47.481130: step 3370, error = 2.9241, accuracy = 0.3828. (0.249 sec/step)
#
# 2017-03-11 20:40:49.968187: step 3380, error = 2.9384, accuracy = 0.3750. (0.259 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3386 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:40:52.484680: step 3390, error = 3.0447, accuracy = 0.3438. (0.253 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.19263
# 2017-03-11 20:40:54.881662: step 3400, error = 2.8836, accuracy = 0.3203. (0.230 sec/step)
#
# 2017-03-11 20:40:57.377192: step 3410, error = 2.6559, accuracy = 0.4375. (0.264 sec/step)
#
# 2017-03-11 20:40:59.560691: step 3420, error = 2.8711, accuracy = 0.4062. (0.229 sec/step)
#
# 2017-03-11 20:41:01.735551: step 3430, error = 3.2482, accuracy = 0.3281. (0.221 sec/step)
#
# 2017-03-11 20:41:04.134009: step 3440, error = 2.8365, accuracy = 0.4453. (0.253 sec/step)
#
# 2017-03-11 20:41:06.620423: step 3450, error = 2.9562, accuracy = 0.3984. (0.250 sec/step)
#
# 2017-03-11 20:41:09.024456: step 3460, error = 3.0653, accuracy = 0.3516. (0.239 sec/step)
#
# 2017-03-11 20:41:11.505258: step 3470, error = 3.0287, accuracy = 0.3281. (0.240 sec/step)
#
# 2017-03-11 20:41:13.927123: step 3480, error = 3.1634, accuracy = 0.3750. (0.245 sec/step)
#
# 2017-03-11 20:41:16.346915: step 3490, error = 2.7101, accuracy = 0.3828. (0.241 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.22462
# 2017-03-11 20:41:18.553033: step 3500, error = 3.0007, accuracy = 0.3672. (0.228 sec/step)
#
# 2017-03-11 20:41:20.691235: step 3510, error = 2.8940, accuracy = 0.4141. (0.211 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3514 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:41:23.071852: step 3520, error = 2.9150, accuracy = 0.3438. (0.232 sec/step)
#
# 2017-03-11 20:41:25.554470: step 3530, error = 2.7661, accuracy = 0.4062. (0.250 sec/step)
#
# 2017-03-11 20:41:28.013065: step 3540, error = 2.7841, accuracy = 0.4062. (0.244 sec/step)
#
# 2017-03-11 20:41:30.491306: step 3550, error = 2.7739, accuracy = 0.3906. (0.255 sec/step)
#
# 2017-03-11 20:41:32.931858: step 3560, error = 2.8613, accuracy = 0.4219. (0.240 sec/step)
#
# 2017-03-11 20:41:35.406899: step 3570, error = 3.0844, accuracy = 0.3359. (0.232 sec/step)
#
# 2017-03-11 20:41:37.627165: step 3580, error = 2.8160, accuracy = 0.3672. (0.218 sec/step)
#
# 2017-03-11 20:41:39.767279: step 3590, error = 2.7883, accuracy = 0.3438. (0.216 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.24047
# 2017-03-11 20:41:42.136505: step 3600, error = 2.5851, accuracy = 0.4141. (0.254 sec/step)
#
# 2017-03-11 20:41:44.604584: step 3610, error = 2.8797, accuracy = 0.4062. (0.241 sec/step)
#
# 2017-03-11 20:41:47.067995: step 3620, error = 2.7761, accuracy = 0.3984. (0.268 sec/step)
#
# 2017-03-11 20:41:49.536765: step 3630, error = 2.6729, accuracy = 0.3828. (0.256 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3639 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:41:52.046675: step 3640, error = 2.7679, accuracy = 0.4766. (0.229 sec/step)
#
# 2017-03-11 20:41:54.499964: step 3650, error = 2.7404, accuracy = 0.3984. (0.247 sec/step)
#
# 2017-03-11 20:41:56.655158: step 3660, error = 2.8674, accuracy = 0.3906. (0.210 sec/step)
#
# 2017-03-11 20:41:58.839860: step 3670, error = 2.9540, accuracy = 0.3750. (0.222 sec/step)
#
# 2017-03-11 20:42:01.209375: step 3680, error = 2.6418, accuracy = 0.4141. (0.230 sec/step)
#
# 2017-03-11 20:42:03.680266: step 3690, error = 3.0554, accuracy = 0.2812. (0.245 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.16504
# 2017-03-11 20:42:06.146535: step 3700, error = 2.7414, accuracy = 0.3750. (0.244 sec/step)
#
# 2017-03-11 20:42:08.580705: step 3710, error = 2.8184, accuracy = 0.3516. (0.236 sec/step)
#
# 2017-03-11 20:42:11.019590: step 3720, error = 2.6013, accuracy = 0.4531. (0.251 sec/step)
#
# 2017-03-11 20:42:13.481072: step 3730, error = 2.6666, accuracy = 0.4609. (0.222 sec/step)
#
# 2017-03-11 20:42:15.647499: step 3740, error = 2.7235, accuracy = 0.3906. (0.211 sec/step)
#
# 2017-03-11 20:42:17.815172: step 3750, error = 2.8954, accuracy = 0.3516. (0.213 sec/step)
#
# 2017-03-11 20:42:20.251538: step 3760, error = 2.8376, accuracy = 0.4141. (0.247 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3767 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:42:22.778490: step 3770, error = 2.9867, accuracy = 0.3828. (0.245 sec/step)
#
# 2017-03-11 20:42:25.325349: step 3780, error = 2.9341, accuracy = 0.3594. (0.251 sec/step)
#
# 2017-03-11 20:42:27.783380: step 3790, error = 2.7364, accuracy = 0.4453. (0.234 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.15191
# 2017-03-11 20:42:30.229862: step 3800, error = 2.7320, accuracy = 0.4766. (0.239 sec/step)
#
# 2017-03-11 20:42:32.659489: step 3810, error = 2.8233, accuracy = 0.4297. (0.231 sec/step)
#
# 2017-03-11 20:42:34.836471: step 3820, error = 2.7170, accuracy = 0.4297. (0.226 sec/step)
#
# 2017-03-11 20:42:37.006696: step 3830, error = 2.6378, accuracy = 0.4141. (0.233 sec/step)
#
# 2017-03-11 20:42:39.443649: step 3840, error = 2.8200, accuracy = 0.4062. (0.264 sec/step)
#
# 2017-03-11 20:42:41.899357: step 3850, error = 2.6293, accuracy = 0.4453. (0.237 sec/step)
#
# 2017-03-11 20:42:44.376645: step 3860, error = 2.9312, accuracy = 0.3672. (0.259 sec/step)
#
# 2017-03-11 20:42:46.826148: step 3870, error = 2.7674, accuracy = 0.3594. (0.245 sec/step)
#
# 2017-03-11 20:42:49.302355: step 3880, error = 3.0106, accuracy = 0.2734. (0.225 sec/step)
#
# 2017-03-11 20:42:51.674676: step 3890, error = 2.4183, accuracy = 0.4766. (0.220 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 3892 into cifar100_alexnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.2365
# 2017-03-11 20:42:53.834441: step 3900, error = 2.7956, accuracy = 0.3984. (0.214 sec/step)
#
# 2017-03-11 20:42:56.071762: step 3910, error = 2.6891, accuracy = 0.4219. (0.266 sec/step)
#
# 2017-03-11 20:42:58.628704: step 3920, error = 2.7887, accuracy = 0.4141. (0.263 sec/step)
#
# 2017-03-11 20:43:01.052043: step 3930, error = 3.0451, accuracy = 0.2812. (0.206 sec/step)
#
# 2017-03-11 20:43:03.577769: step 3940, error = 2.5899, accuracy = 0.4609. (0.266 sec/step)
#
# 2017-03-11 20:43:06.073817: step 3950, error = 2.5448, accuracy = 0.4297. (0.231 sec/step)
#
# 2017-03-11 20:43:08.519042: step 3960, error = 2.8579, accuracy = 0.3672. (0.257 sec/step)
#
# 2017-03-11 20:43:10.845658: step 3970, error = 2.6898, accuracy = 0.4062. (0.215 sec/step)
#
# 2017-03-11 20:43:13.018251: step 3980, error = 2.6463, accuracy = 0.4688. (0.221 sec/step)
#
# 2017-03-11 20:43:15.242099: step 3990, error = 2.7418, accuracy = 0.4453. (0.229 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.18255
# 2017-03-11 20:43:17.744121: step 4000, error = 2.8921, accuracy = 0.3516. (0.261 sec/step)
#
# 2017-03-11 20:43:20.245112: step 4010, error = 2.8387, accuracy = 0.4141. (0.243 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4018 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:43:22.790455: step 4020, error = 3.0364, accuracy = 0.3516. (0.270 sec/step)
#
# 2017-03-11 20:43:25.256656: step 4030, error = 2.4793, accuracy = 0.4688. (0.252 sec/step)
#
# 2017-03-11 20:43:27.729591: step 4040, error = 2.5475, accuracy = 0.4375. (0.250 sec/step)
#
# 2017-03-11 20:43:30.020152: step 4050, error = 2.6966, accuracy = 0.4297. (0.225 sec/step)
#
# 2017-03-11 20:43:32.194550: step 4060, error = 2.4801, accuracy = 0.4844. (0.207 sec/step)
#
# 2017-03-11 20:43:34.528123: step 4070, error = 2.8495, accuracy = 0.3984. (0.256 sec/step)
#
# 2017-03-11 20:43:37.027797: step 4080, error = 2.8064, accuracy = 0.4375. (0.255 sec/step)
#
# 2017-03-11 20:43:39.520358: step 4090, error = 2.6677, accuracy = 0.4219. (0.262 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.12625
# 2017-03-11 20:43:41.979731: step 4100, error = 2.4446, accuracy = 0.4766. (0.264 sec/step)
#
# 2017-03-11 20:43:44.476172: step 4110, error = 2.8078, accuracy = 0.3984. (0.238 sec/step)
#
# 2017-03-11 20:43:46.939574: step 4120, error = 2.7294, accuracy = 0.3750. (0.237 sec/step)
#
# 2017-03-11 20:43:49.142514: step 4130, error = 2.6940, accuracy = 0.3984. (0.210 sec/step)
#
# 2017-03-11 20:43:51.333020: step 4140, error = 2.5408, accuracy = 0.4609. (0.217 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4145 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:43:53.792798: step 4150, error = 2.8396, accuracy = 0.3672. (0.252 sec/step)
#
# 2017-03-11 20:43:56.208061: step 4160, error = 2.6025, accuracy = 0.4531. (0.223 sec/step)
#
# 2017-03-11 20:43:58.712961: step 4170, error = 2.6297, accuracy = 0.4141. (0.251 sec/step)
#
# 2017-03-11 20:44:01.206004: step 4180, error = 2.6087, accuracy = 0.4609. (0.231 sec/step)
#
# 2017-03-11 20:44:03.720883: step 4190, error = 2.6791, accuracy = 0.4062. (0.238 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.12988
# 2017-03-11 20:44:06.192035: step 4200, error = 2.3486, accuracy = 0.5000. (0.249 sec/step)
#
# 2017-03-11 20:44:08.382911: step 4210, error = 2.8500, accuracy = 0.3906. (0.221 sec/step)
#
# 2017-03-11 20:44:10.562061: step 4220, error = 2.6577, accuracy = 0.3750. (0.227 sec/step)
#
# 2017-03-11 20:44:13.049471: step 4230, error = 2.7377, accuracy = 0.4141. (0.269 sec/step)
#
# 2017-03-11 20:44:15.497698: step 4240, error = 2.6633, accuracy = 0.4141. (0.245 sec/step)
#
# 2017-03-11 20:44:17.977265: step 4250, error = 2.6265, accuracy = 0.4609. (0.244 sec/step)
#
# 2017-03-11 20:44:20.448852: step 4260, error = 2.7927, accuracy = 0.4062. (0.225 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4269 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:44:22.930046: step 4270, error = 2.8342, accuracy = 0.3672. (0.258 sec/step)
#
# 2017-03-11 20:44:25.358494: step 4280, error = 2.5572, accuracy = 0.4609. (0.216 sec/step)
#
# 2017-03-11 20:44:27.522755: step 4290, error = 2.5420, accuracy = 0.4453. (0.226 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.24154
# 2017-03-11 20:44:29.768040: step 4300, error = 2.6410, accuracy = 0.3906. (0.252 sec/step)
#
# 2017-03-11 20:44:32.240497: step 4310, error = 2.3565, accuracy = 0.5000. (0.269 sec/step)
#
# 2017-03-11 20:44:34.773687: step 4320, error = 2.4346, accuracy = 0.4609. (0.241 sec/step)
#
# 2017-03-11 20:44:37.247516: step 4330, error = 2.5314, accuracy = 0.4062. (0.271 sec/step)
#
# 2017-03-11 20:44:39.718918: step 4340, error = 2.5395, accuracy = 0.4766. (0.240 sec/step)
#
# 2017-03-11 20:44:42.248962: step 4350, error = 2.7055, accuracy = 0.3516. (0.247 sec/step)
#
# 2017-03-11 20:44:44.538833: step 4360, error = 2.5270, accuracy = 0.4297. (0.222 sec/step)
#
# 2017-03-11 20:44:46.715263: step 4370, error = 2.5510, accuracy = 0.4844. (0.221 sec/step)
#
# 2017-03-11 20:44:49.085170: step 4380, error = 2.4590, accuracy = 0.4531. (0.273 sec/step)
#
# 2017-03-11 20:44:51.541538: step 4390, error = 2.6492, accuracy = 0.4453. (0.245 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4395 into cifar100_alexnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.09975
# 2017-03-11 20:44:54.159709: step 4400, error = 2.7594, accuracy = 0.3906. (0.265 sec/step)
#
# 2017-03-11 20:44:56.698297: step 4410, error = 2.5049, accuracy = 0.4141. (0.250 sec/step)
#
# 2017-03-11 20:44:59.232810: step 4420, error = 2.3244, accuracy = 0.5000. (0.275 sec/step)
#
# 2017-03-11 20:45:01.742766: step 4430, error = 2.8391, accuracy = 0.3516. (0.249 sec/step)
#
# 2017-03-11 20:45:03.991373: step 4440, error = 2.5250, accuracy = 0.3750. (0.227 sec/step)
#
# 2017-03-11 20:45:06.156051: step 4450, error = 2.6898, accuracy = 0.3750. (0.215 sec/step)
#
# 2017-03-11 20:45:08.566662: step 4460, error = 2.3222, accuracy = 0.4844. (0.259 sec/step)
#
# 2017-03-11 20:45:11.089123: step 4470, error = 2.6398, accuracy = 0.3984. (0.256 sec/step)
#
# 2017-03-11 20:45:13.659838: step 4480, error = 2.6493, accuracy = 0.4219. (0.274 sec/step)
#
# 2017-03-11 20:45:16.181676: step 4490, error = 2.8805, accuracy = 0.3750. (0.251 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.06777
# 2017-03-11 20:45:18.743116: step 4500, error = 2.5374, accuracy = 0.4766. (0.245 sec/step)
#
# 2017-03-11 20:45:21.154081: step 4510, error = 2.7109, accuracy = 0.3984. (0.213 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4518 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:45:23.353356: step 4520, error = 2.7792, accuracy = 0.4141. (0.216 sec/step)
#
# 2017-03-11 20:45:25.598316: step 4530, error = 2.5162, accuracy = 0.4609. (0.249 sec/step)
#
# 2017-03-11 20:45:28.030065: step 4540, error = 2.6850, accuracy = 0.4375. (0.242 sec/step)
#
# 2017-03-11 20:45:30.518829: step 4550, error = 2.8286, accuracy = 0.3984. (0.240 sec/step)
#
# 2017-03-11 20:45:33.078508: step 4560, error = 2.6735, accuracy = 0.4141. (0.257 sec/step)
#
# 2017-03-11 20:45:35.594040: step 4570, error = 2.7121, accuracy = 0.3984. (0.253 sec/step)
#
# 2017-03-11 20:45:38.105414: step 4580, error = 2.4984, accuracy = 0.4453. (0.253 sec/step)
#
# 2017-03-11 20:45:40.474848: step 4590, error = 2.4987, accuracy = 0.4219. (0.218 sec/step)
#
# INFO:tensorflow:global_step/sec: 4.17895
# 2017-03-11 20:45:42.674672: step 4600, error = 2.6568, accuracy = 0.4375. (0.226 sec/step)
#
# 2017-03-11 20:45:45.016082: step 4610, error = 2.5573, accuracy = 0.4297. (0.228 sec/step)
#
# 2017-03-11 20:45:47.557460: step 4620, error = 2.4753, accuracy = 0.4453. (0.276 sec/step)
#
# 2017-03-11 20:45:50.037971: step 4630, error = 2.7690, accuracy = 0.3594. (0.219 sec/step)
#
# 2017-03-11 20:45:52.502326: step 4640, error = 2.6770, accuracy = 0.4062. (0.217 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 4642 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 20:45:55.049073: step 4650, error = 2.6084, accuracy = 0.4141. (0.259 sec/step)
#
# 2017-03-11 20:45:57.573590: step 4660, error = 2.8960, accuracy = 0.3750. (0.240 sec/step)
#
# 2017-03-11 20:45:59.802045: step 4670, error = 2.5972, accuracy = 0.4531. (0.218 sec/step)
#
# ...
#
# 2017-03-11 21:11:14.364018: step 10590, error = 2.0714, accuracy = 0.5312. (0.284 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.65134
# 2017-03-11 21:11:17.213633: step 10600, error = 2.0623, accuracy = 0.5938. (0.277 sec/step)
#
# 2017-03-11 21:11:19.961177: step 10610, error = 2.1775, accuracy = 0.5078. (0.261 sec/step)
#
# 2017-03-11 21:11:22.806861: step 10620, error = 2.2796, accuracy = 0.5469. (0.283 sec/step)
#
# 2017-03-11 21:11:25.088640: step 10630, error = 2.0940, accuracy = 0.5469. (0.231 sec/step)
#
# 2017-03-11 21:11:27.432826: step 10640, error = 2.3645, accuracy = 0.4688. (0.283 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 10647 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:11:30.401018: step 10650, error = 2.0334, accuracy = 0.6484. (0.283 sec/step)
#
# 2017-03-11 21:11:33.300690: step 10660, error = 2.1937, accuracy = 0.5391. (0.294 sec/step)
#
# 2017-03-11 21:11:36.194007: step 10670, error = 2.4954, accuracy = 0.4844. (0.269 sec/step)
#
# 2017-03-11 21:11:38.983326: step 10680, error = 2.3765, accuracy = 0.5312. (0.275 sec/step)
#
# 2017-03-11 21:11:41.743518: step 10690, error = 2.2118, accuracy = 0.5938. (0.232 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.72776
# 2017-03-11 21:11:44.039659: step 10700, error = 2.2550, accuracy = 0.5391. (0.225 sec/step)
#
# 2017-03-11 21:11:46.356955: step 10710, error = 2.0054, accuracy = 0.5781. (0.285 sec/step)
#
# 2017-03-11 21:11:49.135317: step 10720, error = 2.1860, accuracy = 0.6172. (0.281 sec/step)
#
# 2017-03-11 21:11:51.922064: step 10730, error = 2.2034, accuracy = 0.5156. (0.279 sec/step)
#
# 2017-03-11 21:11:54.664623: step 10740, error = 2.5756, accuracy = 0.5000. (0.245 sec/step)
#
# 2017-03-11 21:11:57.481936: step 10750, error = 1.9841, accuracy = 0.6562. (0.248 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 10758 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:12:00.336520: step 10760, error = 2.2113, accuracy = 0.6094. (0.273 sec/step)
#
# 2017-03-11 21:12:02.720045: step 10770, error = 2.1067, accuracy = 0.6250. (0.232 sec/step)
#
# 2017-03-11 21:12:05.072155: step 10780, error = 2.2029, accuracy = 0.5625. (0.245 sec/step)
#
# 2017-03-11 21:12:07.948292: step 10790, error = 2.3038, accuracy = 0.5469. (0.280 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.73316
# 2017-03-11 21:12:10.825681: step 10800, error = 2.0236, accuracy = 0.5859. (0.274 sec/step)
#
# 2017-03-11 21:12:13.726207: step 10810, error = 2.4244, accuracy = 0.4922. (0.256 sec/step)
#
# 2017-03-11 21:12:16.559280: step 10820, error = 2.0136, accuracy = 0.5938. (0.281 sec/step)
#
# 2017-03-11 21:12:19.353903: step 10830, error = 2.1198, accuracy = 0.5625. (0.252 sec/step)
#
# 2017-03-11 21:12:21.671136: step 10840, error = 2.3048, accuracy = 0.5391. (0.233 sec/step)
#
# 2017-03-11 21:12:23.952618: step 10850, error = 2.0542, accuracy = 0.5547. (0.225 sec/step)
#
# 2017-03-11 21:12:26.678558: step 10860, error = 2.3354, accuracy = 0.5234. (0.250 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 10871 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:12:29.919346: step 10870, error = 2.1644, accuracy = 0.6328. (0.632 sec/step)
#
# 2017-03-11 21:12:32.518223: step 10880, error = 2.1738, accuracy = 0.5469. (0.305 sec/step)
#
# 2017-03-11 21:12:35.482110: step 10890, error = 2.1249, accuracy = 0.5625. (0.280 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.62013
# 2017-03-11 21:12:38.449276: step 10900, error = 2.3002, accuracy = 0.5703. (0.300 sec/step)
#
# 2017-03-11 21:12:40.832104: step 10910, error = 2.2640, accuracy = 0.5156. (0.226 sec/step)
#
# 2017-03-11 21:12:43.129853: step 10920, error = 2.1888, accuracy = 0.5469. (0.244 sec/step)
#
# 2017-03-11 21:12:45.857704: step 10930, error = 2.3361, accuracy = 0.5156. (0.263 sec/step)
#
# 2017-03-11 21:12:48.680652: step 10940, error = 2.1329, accuracy = 0.5547. (0.282 sec/step)
#
# 2017-03-11 21:12:51.567488: step 10950, error = 2.3478, accuracy = 0.4922. (0.289 sec/step)
#
# 2017-03-11 21:12:54.442488: step 10960, error = 2.3109, accuracy = 0.5156. (0.240 sec/step)
#
# 2017-03-11 21:12:57.203336: step 10970, error = 1.9703, accuracy = 0.6172. (0.272 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 10981 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:12:59.830555: step 10980, error = 2.4662, accuracy = 0.5234. (0.402 sec/step)
#
# 2017-03-11 21:13:01.998245: step 10990, error = 2.1630, accuracy = 0.5703. (0.230 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.80096
# 2017-03-11 21:13:04.758660: step 11000, error = 2.0810, accuracy = 0.5781. (0.263 sec/step)
#
# 2017-03-11 21:13:07.582903: step 11010, error = 2.2502, accuracy = 0.5625. (0.316 sec/step)
#
# 2017-03-11 21:13:10.433404: step 11020, error = 2.2558, accuracy = 0.4766. (0.300 sec/step)
#
# 2017-03-11 21:13:13.387228: step 11030, error = 2.1554, accuracy = 0.5547. (0.281 sec/step)
#
# 2017-03-11 21:13:16.255228: step 11040, error = 2.1554, accuracy = 0.5469. (0.276 sec/step)
#
# 2017-03-11 21:13:18.712376: step 11050, error = 2.0588, accuracy = 0.6172. (0.234 sec/step)
#
# 2017-03-11 21:13:20.978966: step 11060, error = 2.2899, accuracy = 0.5312. (0.223 sec/step)
#
# 2017-03-11 21:13:23.696548: step 11070, error = 2.2413, accuracy = 0.5312. (0.276 sec/step)
#
# 2017-03-11 21:13:26.537587: step 11080, error = 2.0680, accuracy = 0.6016. (0.290 sec/step)
#
# 2017-03-11 21:13:29.400373: step 11090, error = 2.0845, accuracy = 0.5938. (0.283 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11092 into cifar100_alexnet_model/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.61975
# 2017-03-11 21:13:32.384898: step 11100, error = 2.0182, accuracy = 0.5781. (0.298 sec/step)
#
# 2017-03-11 21:13:35.256760: step 11110, error = 2.3523, accuracy = 0.5312. (0.265 sec/step)
#
# 2017-03-11 21:13:37.730218: step 11120, error = 2.0766, accuracy = 0.5938. (0.232 sec/step)
#
# 2017-03-11 21:13:40.010525: step 11130, error = 2.4698, accuracy = 0.5547. (0.237 sec/step)
#
# 2017-03-11 21:13:42.655560: step 11140, error = 1.9638, accuracy = 0.6094. (0.282 sec/step)
#
# 2017-03-11 21:13:45.455520: step 11150, error = 2.0388, accuracy = 0.5938. (0.277 sec/step)
#
# 2017-03-11 21:13:48.294018: step 11160, error = 2.4640, accuracy = 0.5000. (0.275 sec/step)
#
# 2017-03-11 21:13:51.200131: step 11170, error = 2.2100, accuracy = 0.5234. (0.290 sec/step)
#
# 2017-03-11 21:13:54.069507: step 11180, error = 2.1708, accuracy = 0.5391. (0.278 sec/step)
#
# 2017-03-11 21:13:56.594053: step 11190, error = 2.1022, accuracy = 0.5703. (0.236 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.77222
# 2017-03-11 21:13:58.893867: step 11200, error = 2.1406, accuracy = 0.5781. (0.238 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11205 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:14:01.598229: step 11210, error = 2.2844, accuracy = 0.5391. (0.276 sec/step)
#
# 2017-03-11 21:14:04.348894: step 11220, error = 2.2054, accuracy = 0.5859. (0.225 sec/step)
#
# 2017-03-11 21:14:07.176407: step 11230, error = 2.1424, accuracy = 0.5625. (0.306 sec/step)
#
# 2017-03-11 21:14:10.113805: step 11240, error = 2.4344, accuracy = 0.4688. (0.320 sec/step)
#
# 2017-03-11 21:14:13.012108: step 11250, error = 2.1768, accuracy = 0.5391. (0.289 sec/step)
#
# 2017-03-11 21:14:15.547533: step 11260, error = 2.2727, accuracy = 0.5469. (0.235 sec/step)
#
# 2017-03-11 21:14:17.853582: step 11270, error = 2.1550, accuracy = 0.5547. (0.234 sec/step)
#
# 2017-03-11 21:14:20.537907: step 11280, error = 2.2100, accuracy = 0.5391. (0.264 sec/step)
#
# 2017-03-11 21:14:23.512564: step 11290, error = 1.9791, accuracy = 0.5781. (0.319 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.64267
# 2017-03-11 21:14:26.346750: step 11300, error = 1.9489, accuracy = 0.6328. (0.296 sec/step)
#
# 2017-03-11 21:14:29.244165: step 11310, error = 2.1935, accuracy = 0.5469. (0.296 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11314 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:14:32.166259: step 11320, error = 2.4713, accuracy = 0.5312. (0.272 sec/step)
#
# 2017-03-11 21:14:34.680404: step 11330, error = 2.2291, accuracy = 0.4922. (0.232 sec/step)
#
# 2017-03-11 21:14:36.950516: step 11340, error = 2.0734, accuracy = 0.5625. (0.228 sec/step)
#
# 2017-03-11 21:14:39.575282: step 11350, error = 2.1698, accuracy = 0.5391. (0.290 sec/step)
#
# 2017-03-11 21:14:42.499003: step 11360, error = 2.2124, accuracy = 0.5234. (0.308 sec/step)
#
# 2017-03-11 21:14:45.391186: step 11370, error = 2.2002, accuracy = 0.5469. (0.310 sec/step)
#
# 2017-03-11 21:14:48.239229: step 11380, error = 1.9182, accuracy = 0.6250. (0.278 sec/step)
#
# 2017-03-11 21:14:51.154010: step 11390, error = 2.0897, accuracy = 0.6172. (0.296 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.63745
# 2017-03-11 21:14:53.838109: step 11400, error = 2.1357, accuracy = 0.5234. (0.228 sec/step)
#
# 2017-03-11 21:14:56.143250: step 11410, error = 2.1172, accuracy = 0.5547. (0.240 sec/step)
#
# 2017-03-11 21:14:58.674086: step 11420, error = 2.2428, accuracy = 0.5234. (0.281 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11426 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:15:01.586330: step 11430, error = 2.2469, accuracy = 0.5156. (0.302 sec/step)
#
# 2017-03-11 21:15:04.450911: step 11440, error = 2.2797, accuracy = 0.5391. (0.272 sec/step)
#
# 2017-03-11 21:15:07.381936: step 11450, error = 2.2236, accuracy = 0.5234. (0.293 sec/step)
#
# 2017-03-11 21:15:10.295548: step 11460, error = 1.9377, accuracy = 0.6094. (0.294 sec/step)
#
# 2017-03-11 21:15:12.888597: step 11470, error = 2.1336, accuracy = 0.5625. (0.219 sec/step)
#
# 2017-03-11 21:15:15.171029: step 11480, error = 2.2438, accuracy = 0.5938. (0.231 sec/step)
#
# 2017-03-11 21:15:17.666752: step 11490, error = 2.1194, accuracy = 0.5625. (0.255 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.73841
# 2017-03-11 21:15:20.587913: step 11500, error = 2.1389, accuracy = 0.5938. (0.285 sec/step)
#
# 2017-03-11 21:15:23.525413: step 11510, error = 2.3952, accuracy = 0.4766. (0.311 sec/step)
#
# 2017-03-11 21:15:26.317891: step 11520, error = 2.0312, accuracy = 0.6484. (0.264 sec/step)
#
# 2017-03-11 21:15:29.242429: step 11530, error = 2.2150, accuracy = 0.5625. (0.297 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11535 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:15:32.038792: step 11540, error = 2.1988, accuracy = 0.6016. (0.232 sec/step)
#
# 2017-03-11 21:15:34.357353: step 11550, error = 2.3750, accuracy = 0.5156. (0.247 sec/step)
#
# 2017-03-11 21:15:36.838792: step 11560, error = 2.0867, accuracy = 0.5547. (0.254 sec/step)
#
# 2017-03-11 21:15:39.725569: step 11570, error = 2.0966, accuracy = 0.6094. (0.315 sec/step)
#
# 2017-03-11 21:15:42.621289: step 11580, error = 2.4168, accuracy = 0.4688. (0.315 sec/step)
#
# 2017-03-11 21:15:45.486427: step 11590, error = 2.3343, accuracy = 0.5547. (0.288 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.59622
# 2017-03-11 21:15:48.394647: step 11600, error = 2.1595, accuracy = 0.5391. (0.297 sec/step)
#
# 2017-03-11 21:15:51.185709: step 11610, error = 2.2544, accuracy = 0.5078. (0.221 sec/step)
#
# 2017-03-11 21:15:53.481908: step 11620, error = 2.3479, accuracy = 0.4531. (0.232 sec/step)
#
# 2017-03-11 21:15:56.046196: step 11630, error = 2.1586, accuracy = 0.5547. (0.286 sec/step)
#
# 2017-03-11 21:15:58.928044: step 11640, error = 2.2838, accuracy = 0.5547. (0.285 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11647 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:16:01.818895: step 11650, error = 2.0685, accuracy = 0.5625. (0.294 sec/step)
#
# 2017-03-11 21:16:04.671319: step 11660, error = 2.2077, accuracy = 0.5703. (0.262 sec/step)
#
# 2017-03-11 21:16:07.519877: step 11670, error = 2.1430, accuracy = 0.5781. (0.313 sec/step)
#
# 2017-03-11 21:16:10.261096: step 11680, error = 2.0733, accuracy = 0.5938. (0.215 sec/step)
#
# 2017-03-11 21:16:12.551060: step 11690, error = 2.2727, accuracy = 0.5625. (0.233 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.75705
# 2017-03-11 21:16:15.013301: step 11700, error = 2.2668, accuracy = 0.5547. (0.292 sec/step)
#
# 2017-03-11 21:16:17.798835: step 11710, error = 1.9022, accuracy = 0.6172. (0.289 sec/step)
#
# 2017-03-11 21:16:20.685997: step 11720, error = 1.9996, accuracy = 0.5859. (0.309 sec/step)
#
# 2017-03-11 21:16:23.593755: step 11730, error = 2.0742, accuracy = 0.6016. (0.285 sec/step)
#
# 2017-03-11 21:16:26.416315: step 11740, error = 2.0462, accuracy = 0.5547. (0.301 sec/step)
#
# 2017-03-11 21:16:29.186896: step 11750, error = 2.0808, accuracy = 0.5078. (0.225 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11758 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:16:31.515003: step 11760, error = 2.4244, accuracy = 0.4609. (0.233 sec/step)
#
# 2017-03-11 21:16:33.910611: step 11770, error = 2.3042, accuracy = 0.5234. (0.270 sec/step)
#
# 2017-03-11 21:16:36.814972: step 11780, error = 2.2761, accuracy = 0.5391. (0.278 sec/step)
#
# 2017-03-11 21:16:39.769546: step 11790, error = 2.1732, accuracy = 0.5312. (0.286 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.60942
# 2017-03-11 21:16:42.716679: step 11800, error = 2.3147, accuracy = 0.5391. (0.298 sec/step)
#
# 2017-03-11 21:16:45.662830: step 11810, error = 2.4596, accuracy = 0.5469. (0.284 sec/step)
#
# 2017-03-11 21:16:48.435335: step 11820, error = 2.1853, accuracy = 0.5312. (0.240 sec/step)
#
# 2017-03-11 21:16:50.708853: step 11830, error = 1.9052, accuracy = 0.6094. (0.211 sec/step)
#
# 2017-03-11 21:16:53.298653: step 11840, error = 2.1814, accuracy = 0.5391. (0.287 sec/step)
#
# 2017-03-11 21:16:56.199946: step 11850, error = 2.1421, accuracy = 0.5859. (0.316 sec/step)
#
# 2017-03-11 21:16:59.071445: step 11860, error = 2.0615, accuracy = 0.5625. (0.285 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11867 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:17:02.070572: step 11870, error = 2.0409, accuracy = 0.6016. (0.284 sec/step)
#
# 2017-03-11 21:17:05.004424: step 11880, error = 1.9951, accuracy = 0.6641. (0.272 sec/step)
#
# 2017-03-11 21:17:07.672076: step 11890, error = 2.0543, accuracy = 0.5938. (0.234 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.67046
# 2017-03-11 21:17:09.960820: step 11900, error = 2.1345, accuracy = 0.5938. (0.229 sec/step)
#
# 2017-03-11 21:17:12.479004: step 11910, error = 2.0449, accuracy = 0.6406. (0.292 sec/step)
#
# 2017-03-11 21:17:15.407509: step 11920, error = 2.1424, accuracy = 0.5703. (0.285 sec/step)
#
# 2017-03-11 21:17:18.312457: step 11930, error = 2.1875, accuracy = 0.5391. (0.281 sec/step)
#
# 2017-03-11 21:17:21.226002: step 11940, error = 2.0684, accuracy = 0.6484. (0.278 sec/step)
#
# 2017-03-11 21:17:24.197977: step 11950, error = 2.5112, accuracy = 0.4844. (0.287 sec/step)
#
# 2017-03-11 21:17:26.908672: step 11960, error = 1.9501, accuracy = 0.6094. (0.241 sec/step)
#
# 2017-03-11 21:17:29.190114: step 11970, error = 2.0672, accuracy = 0.6016. (0.224 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 11978 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:17:31.772971: step 11980, error = 2.3531, accuracy = 0.4844. (0.278 sec/step)
#
# 2017-03-11 21:17:34.746694: step 11990, error = 2.2166, accuracy = 0.5234. (0.296 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.60964
# 2017-03-11 21:17:37.664990: step 12000, error = 2.2809, accuracy = 0.5312. (0.295 sec/step)
#
# 2017-03-11 21:17:40.546910: step 12010, error = 2.5166, accuracy = 0.5234. (0.268 sec/step)
#
# 2017-03-11 21:17:43.481668: step 12020, error = 2.2743, accuracy = 0.5234. (0.305 sec/step)
#
# 2017-03-11 21:17:46.123444: step 12030, error = 2.0492, accuracy = 0.6250. (0.227 sec/step)
#
# 2017-03-11 21:17:48.395180: step 12040, error = 2.1477, accuracy = 0.5781. (0.226 sec/step)
#
# 2017-03-11 21:17:50.999608: step 12050, error = 2.3603, accuracy = 0.5000. (0.274 sec/step)
#
# 2017-03-11 21:17:53.857163: step 12060, error = 2.0666, accuracy = 0.6094. (0.258 sec/step)
#
# 2017-03-11 21:17:56.683064: step 12070, error = 2.1820, accuracy = 0.5547. (0.261 sec/step)
#
# 2017-03-11 21:17:59.624207: step 12080, error = 2.3624, accuracy = 0.5547. (0.282 sec/step)
#
# INFO:tensorflow:Saving checkpoints for 12086 into cifar100_alexnet_model/model.ckpt.
# 2017-03-11 21:18:02.501828: step 12090, error = 2.1876, accuracy = 0.5391. (0.287 sec/step)
#
# INFO:tensorflow:global_step/sec: 3.6372
# 2017-03-11 21:18:05.158319: step 12100, error = 2.0006, accuracy = 0.5469. (0.231 sec/step)
