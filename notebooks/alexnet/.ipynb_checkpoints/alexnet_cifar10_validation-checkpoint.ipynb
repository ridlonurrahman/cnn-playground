# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar10_alexnet_model/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/test_batch.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=10)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= 50
        validation_accuracy /= 50
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(15)
# Out:
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1
# INFO:tensorflow:loss: 6.387, best accuracy: 0.097
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-134
# INFO:tensorflow:loss: 5.456, best accuracy: 0.343
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-270
# INFO:tensorflow:loss: 4.937, best accuracy: 0.383
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-405
# INFO:tensorflow:loss: 4.420, best accuracy: 0.486
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-540
# INFO:tensorflow:loss: 4.093, best accuracy: 0.475
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-676
# INFO:tensorflow:loss: 3.697, best accuracy: 0.552
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-812
# INFO:tensorflow:loss: 3.305, best accuracy: 0.601
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-812
# INFO:tensorflow:loss: 3.305, best accuracy: 0.601
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-946
# INFO:tensorflow:loss: 3.146, best accuracy: 0.573
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1081
# INFO:tensorflow:loss: 2.760, best accuracy: 0.658
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1215
# INFO:tensorflow:loss: 2.641, best accuracy: 0.644
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1350
# INFO:tensorflow:loss: 2.451, best accuracy: 0.656
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1483
# INFO:tensorflow:loss: 2.364, best accuracy: 0.647
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1617
# INFO:tensorflow:loss: 2.159, best accuracy: 0.667
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1751
# INFO:tensorflow:loss: 1.986, best accuracy: 0.697
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1885
# INFO:tensorflow:loss: 1.917, best accuracy: 0.688
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2019
# INFO:tensorflow:loss: 1.774, best accuracy: 0.695
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2154
# INFO:tensorflow:loss: 1.660, best accuracy: 0.712
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2287
# INFO:tensorflow:loss: 1.589, best accuracy: 0.710
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2421
# INFO:tensorflow:loss: 1.713, best accuracy: 0.666
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2554
# INFO:tensorflow:loss: 1.416, best accuracy: 0.731
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2688
# INFO:tensorflow:loss: 1.521, best accuracy: 0.696
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2821
# INFO:tensorflow:loss: 1.420, best accuracy: 0.708
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2955
# INFO:tensorflow:loss: 1.400, best accuracy: 0.701
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3088
# INFO:tensorflow:loss: 1.262, best accuracy: 0.730
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3221
# INFO:tensorflow:loss: 1.163, best accuracy: 0.753
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3353
# INFO:tensorflow:loss: 1.375, best accuracy: 0.688
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3485
# INFO:tensorflow:loss: 1.138, best accuracy: 0.750
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3617
# INFO:tensorflow:loss: 1.061, best accuracy: 0.763
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3750
# INFO:tensorflow:loss: 1.137, best accuracy: 0.732
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3750
# INFO:tensorflow:loss: 1.137, best accuracy: 0.732
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3882
# INFO:tensorflow:loss: 1.189, best accuracy: 0.718
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4013
# INFO:tensorflow:loss: 1.227, best accuracy: 0.698
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4145
# INFO:tensorflow:loss: 1.192, best accuracy: 0.712
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4276
# INFO:tensorflow:loss: 1.156, best accuracy: 0.725
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4407
# INFO:tensorflow:loss: 0.979, best accuracy: 0.769
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4537
# INFO:tensorflow:loss: 0.993, best accuracy: 0.759
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4668
# INFO:tensorflow:loss: 1.033, best accuracy: 0.742
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4798
# INFO:tensorflow:loss: 1.064, best accuracy: 0.749
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4929
# INFO:tensorflow:loss: 0.940, best accuracy: 0.773
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5058
# INFO:tensorflow:loss: 0.980, best accuracy: 0.759
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5187
# INFO:tensorflow:loss: 0.960, best accuracy: 0.754
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5316
# INFO:tensorflow:loss: 0.990, best accuracy: 0.751
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5446
# INFO:tensorflow:loss: 0.968, best accuracy: 0.758
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5576
# INFO:tensorflow:loss: 0.910, best accuracy: 0.774
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5706
# INFO:tensorflow:loss: 0.936, best accuracy: 0.765
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5836
# INFO:tensorflow:loss: 0.899, best accuracy: 0.775
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5966
# INFO:tensorflow:loss: 0.905, best accuracy: 0.775
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6095
# INFO:tensorflow:loss: 0.976, best accuracy: 0.761
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6224
# INFO:tensorflow:loss: 0.936, best accuracy: 0.769
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6353
# INFO:tensorflow:loss: 0.921, best accuracy: 0.772
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6482
# INFO:tensorflow:loss: 0.909, best accuracy: 0.775
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6611
# INFO:tensorflow:loss: 0.919, best accuracy: 0.768
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6611
# INFO:tensorflow:loss: 0.919, best accuracy: 0.768
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6739
# INFO:tensorflow:loss: 0.911, best accuracy: 0.779
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6868
# INFO:tensorflow:loss: 0.944, best accuracy: 0.774
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6995
# INFO:tensorflow:loss: 0.860, best accuracy: 0.790
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7123
# INFO:tensorflow:loss: 0.881, best accuracy: 0.783
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7250
# INFO:tensorflow:loss: 0.901, best accuracy: 0.781
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7377
# INFO:tensorflow:loss: 0.872, best accuracy: 0.791
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7502
# INFO:tensorflow:loss: 0.982, best accuracy: 0.764
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7629
# INFO:tensorflow:loss: 0.874, best accuracy: 0.782
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7755
# INFO:tensorflow:loss: 0.906, best accuracy: 0.783
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-7882
# INFO:tensorflow:loss: 0.883, best accuracy: 0.783
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8008
# INFO:tensorflow:loss: 0.936, best accuracy: 0.778
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8135
# INFO:tensorflow:loss: 0.957, best accuracy: 0.767
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8261
# INFO:tensorflow:loss: 0.912, best accuracy: 0.784
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8387
# INFO:tensorflow:loss: 0.852, best accuracy: 0.797
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8513
# INFO:tensorflow:loss: 0.901, best accuracy: 0.787
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8639
# INFO:tensorflow:loss: 0.916, best accuracy: 0.780
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8766
# INFO:tensorflow:loss: 0.893, best accuracy: 0.792
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-8891
# INFO:tensorflow:loss: 0.984, best accuracy: 0.769
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9017
# INFO:tensorflow:loss: 0.893, best accuracy: 0.793
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9017
# INFO:tensorflow:loss: 0.893, best accuracy: 0.793
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9143
# INFO:tensorflow:loss: 0.881, best accuracy: 0.794
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9269
# INFO:tensorflow:loss: 0.896, best accuracy: 0.786
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9393
# INFO:tensorflow:loss: 0.890, best accuracy: 0.792
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9518
# INFO:tensorflow:loss: 0.939, best accuracy: 0.779
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9642
# INFO:tensorflow:loss: 0.935, best accuracy: 0.793
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9766
# INFO:tensorflow:loss: 0.890, best accuracy: 0.796
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-9887
# INFO:tensorflow:loss: 0.908, best accuracy: 0.789
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10012
# INFO:tensorflow:loss: 0.902, best accuracy: 0.790
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10135
# INFO:tensorflow:loss: 0.947, best accuracy: 0.777
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10259
# INFO:tensorflow:loss: 0.905, best accuracy: 0.787
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10382
# INFO:tensorflow:loss: 0.889, best accuracy: 0.801
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10507
# INFO:tensorflow:loss: 0.915, best accuracy: 0.790
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10631
# INFO:tensorflow:loss: 0.921, best accuracy: 0.789
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10756
# INFO:tensorflow:loss: 0.918, best accuracy: 0.794
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-10880
# INFO:tensorflow:loss: 0.948, best accuracy: 0.782
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-11004
# INFO:tensorflow:loss: 0.935, best accuracy: 0.786
# INFO:tensorflow:loss: 0.927, best accuracy: 0.807
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-19315
# INFO:tensorflow:loss: 0.951, best accuracy: 0.796
