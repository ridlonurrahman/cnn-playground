# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time

import numpy as np
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

import cifar10, cifar_input

FLAGS = tf.app.flags.FLAGS

IMAGE_SIZE = 24

# Global constants describing the CIFAR-10 data set.
NUM_CLASSES = 10
NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN = 50000
NUM_EXAMPLES_PER_EPOCH_FOR_EVAL = 10000


# Constants describing the training process.
MOVING_AVERAGE_DECAY = 0.9999     # The decay to use for the moving average.
NUM_EPOCHS_PER_DECAY = 350.0      # Epochs after which learning rate decays.
LEARNING_RATE_DECAY_FACTOR = 0.1  # Learning rate decay factor.
INITIAL_LEARNING_RATE = 0.1       # Initial learning rate.

max_steps = 20000
train_dir = 'cifar10_trial_train/'
batch_size = 128
log_device_placement = False

# %%
def loss(logits, labels):
  """Add L2Loss to all the trainable variables.

  Add summary for "Loss" and "Loss/avg".
  Args:
    logits: Logits from inference().
    labels: Labels from distorted_inputs or inputs(). 1-D tensor
            of shape [batch_size]

  Returns:
    Loss tensor of type float.
  """
  # Calculate the average cross entropy loss across the batch.
  # labels = tf.cast(labels, tf.int64)
  cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
          logits=logits, labels=labels, name='cross_entropy_per_example')
  cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')
  tf.add_to_collection('losses', cross_entropy_mean)

  # The total loss is defined as the cross entropy loss plus all of the weight
  # decay terms (L2 loss).
  return tf.add_n(tf.get_collection('losses'), name='total_loss')

# %%
def accuracy(logits, labels):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1)), tf.float32))

# %%
def _add_loss_summaries(total_loss):
  """Add summaries for losses in CIFAR-10 model.

  Generates moving average for all losses and associated summaries for
  visualizing the performance of the network.

  Args:
    total_loss: Total loss from loss().
  Returns:
    loss_averages_op: op for generating moving averages of losses.
  """
  # Compute the moving average of all individual losses and the total loss.
  loss_averages = tf.train.ExponentialMovingAverage(0.9, name='avg')
  losses = tf.get_collection('losses')
  loss_averages_op = loss_averages.apply(losses + [total_loss])

  return loss_averages_op

def train(total_loss, global_step):
  """Train CIFAR-10 model.

  Create an optimizer and apply to all trainable variables. Add moving
  average for all trainable variables.

  Args:
    total_loss: Total loss from loss().
    global_step: Integer Variable counting the number of training steps
      processed.
  Returns:
    train_op: op for training.
  """
  # Variables that affect learning rate.
  num_batches_per_epoch = NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN / 128
  decay_steps = int(num_batches_per_epoch * NUM_EPOCHS_PER_DECAY)

  # Decay the learning rate exponentially based on the number of steps.
  lr = tf.train.exponential_decay(INITIAL_LEARNING_RATE,
                                  global_step,
                                  decay_steps,
                                  LEARNING_RATE_DECAY_FACTOR,
                                  staircase=True)

  # Generate moving averages of all losses and associated summaries.
  loss_averages_op = _add_loss_summaries(total_loss)

  # Compute gradients.
  with tf.control_dependencies([loss_averages_op]):
    opt = tf.train.GradientDescentOptimizer(lr)
    grads = opt.compute_gradients(total_loss)

  # Apply gradients.
  apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)

  # Track the moving averages of all trainable variables.
  variable_averages = tf.train.ExponentialMovingAverage(
      MOVING_AVERAGE_DECAY, global_step)
  variables_averages_op = variable_averages.apply(tf.trainable_variables())

  with tf.control_dependencies([apply_gradient_op, variables_averages_op]):
    train_op = tf.no_op(name='train')

  return train_op

# %%
def _variable_on_cpu(name, shape, initializer):
  """Helper to create a Variable stored on CPU memory.

  Args:
    name: name of the variable
    shape: list of ints
    initializer: initializer for Variable

  Returns:
    Variable Tensor
  """
  with tf.device('/cpu:0'):
    dtype = tf.float16 if 0 else tf.float32
    var = tf.get_variable(name, shape, initializer=initializer, dtype=dtype)
  return var


def _variable_with_weight_decay(name, shape, stddev, wd):
  """Helper to create an initialized Variable with weight decay.

  Note that the Variable is initialized with a truncated normal distribution.
  A weight decay is added only if one is specified.

  Args:
    name: name of the variable
    shape: list of ints
    stddev: standard deviation of a truncated Gaussian
    wd: add L2Loss weight decay multiplied by this float. If None, weight
        decay is not added for this Variable.

  Returns:
    Variable Tensor
  """
  dtype = tf.float16 if 0 else tf.float32
  var = _variable_on_cpu(
      name,
      shape,
      tf.truncated_normal_initializer(stddev=stddev, dtype=dtype))
  if wd is not None:
    weight_decay = tf.multiply(tf.nn.l2_loss(var), wd, name='weight_loss')
    tf.add_to_collection('losses', weight_decay)
  return var

def inference(images):
  """Build the CIFAR-10 model.

  Args:
    images: Images returned from distorted_inputs() or inputs().

  Returns:
    Logits.
  """
  # We instantiate all variables using tf.get_variable() instead of
  # tf.Variable() in order to share variables across multiple GPU training runs.
  # If we only ran this model on a single GPU, we could simplify this function
  # by replacing all instances of tf.get_variable() with tf.Variable().
  #
  # conv1
  with tf.variable_scope('conv1') as scope:
    kernel = _variable_with_weight_decay('weights',
                                         shape=[5, 5, 3, 64],
                                         stddev=5e-2,
                                         wd=0.0)
    conv = tf.nn.conv2d(images, kernel, [1, 1, 1, 1], padding='SAME')
    biases = _variable_on_cpu('biases', [64], tf.constant_initializer(0.0))
    pre_activation = tf.nn.bias_add(conv, biases)
    conv1 = tf.nn.relu(pre_activation, name=scope.name)
    #_activation_summary(conv1)

  # pool1
  pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1],
                         padding='SAME', name='pool1')
  # norm1
  norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm1')

  # conv2
  with tf.variable_scope('conv2') as scope:
    kernel = _variable_with_weight_decay('weights',
                                         shape=[5, 5, 64, 64],
                                         stddev=5e-2,
                                         wd=0.0)
    conv = tf.nn.conv2d(norm1, kernel, [1, 1, 1, 1], padding='SAME')
    biases = _variable_on_cpu('biases', [64], tf.constant_initializer(0.1))
    pre_activation = tf.nn.bias_add(conv, biases)
    conv2 = tf.nn.relu(pre_activation, name=scope.name)
    #_activation_summary(conv2)

  # norm2
  norm2 = tf.nn.lrn(conv2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm2')
  # pool2
  pool2 = tf.nn.max_pool(norm2, ksize=[1, 3, 3, 1],
                         strides=[1, 2, 2, 1], padding='SAME', name='pool2')

  # local3
  with tf.variable_scope('local3') as scope:
    # Move everything into depth so we can perform a single matrix multiply.
    reshape = tf.reshape(pool2, [128, -1])
    dim = reshape.get_shape()[1].value
    weights = _variable_with_weight_decay('weights', shape=[dim, 384],
                                          stddev=0.04, wd=0.004)
    biases = _variable_on_cpu('biases', [384], tf.constant_initializer(0.1))
    local3 = tf.nn.relu(tf.matmul(reshape, weights) + biases, name=scope.name)
    #_activation_summary(local3)

  # local4
  with tf.variable_scope('local4') as scope:
    weights = _variable_with_weight_decay('weights', shape=[384, 192],
                                          stddev=0.04, wd=0.004)
    biases = _variable_on_cpu('biases', [192], tf.constant_initializer(0.1))
    local4 = tf.nn.relu(tf.matmul(local3, weights) + biases, name=scope.name)
    #_activation_summary(local4)

  # linear layer(WX + b),
  # We don't apply softmax here because 
  # tf.nn.sparse_softmax_cross_entropy_with_logits accepts the unscaled logits 
  # and performs the softmax internally for efficiency.
  with tf.variable_scope('softmax_linear') as scope:
    weights = _variable_with_weight_decay('weights', [192, NUM_CLASSES],
                                          stddev=1/192.0, wd=0.0)
    biases = _variable_on_cpu('biases', [NUM_CLASSES],
                              tf.constant_initializer(0.0))
    softmax_linear = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
    #_activation_summary(softmax_linear)

  return softmax_linear

# %%
with tf.Graph().as_default():
    global_step = tf.contrib.framework.get_or_create_global_step()

    # Get images and labels for CIFAR-10.
    images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/data_batch*', 128, 'train')

    # Build a Graph that computes the logits predictions from the
    # inference model.
    logits = inference(images)

    # Calculate loss.
    losses = loss(logits, labels)
    
    accuracies = accuracy(logits, labels)

    # Build a Graph that trains the model with one batch of examples and
    # updates the model parameters.
    train_op = train(losses, global_step)

    class _LoggerHook(tf.train.SessionRunHook):
      """Logs loss and runtime."""

      def begin(self):
        self._step = -1
        open('training_data.csv', 'w').close()
        f = open("log.txt",'ab')
        f.write('\n\n==== Run ===\nInfo: Alexnet\n')
        f.close()

      def before_run(self, run_context):
        self._step += 1
        self._start_time = time.time()
        return tf.train.SessionRunArgs([losses, accuracies])  # Asks for loss value.

      def after_run(self, run_context, run_values):
        duration = time.time() - self._start_time
        loss_value = run_values.results[0]
        accuracy_value = run_values.results[1]
        if self._step % 10 == 0:
          num_examples_per_step = batch_size
          examples_per_sec = num_examples_per_step / duration
          sec_per_batch = float(duration)

          format_str = ('%s: step %d, loss = %.2f, accuracy = %.2f (%.1f examples/sec; %.3f '
                        'sec/batch)')
          print (format_str % (datetime.now(), self._step, loss_value, accuracy_value,
                               examples_per_sec, sec_per_batch))
          f = open("log.txt",'ab')
          f.write('{0}: step {1}, loss = {2:.4f} ({3:.2f} examples/sec; {4:.2f} sec/batch)\n'.format(datetime.now(), self._step, loss_value,
                               examples_per_sec, sec_per_batch))
          f.close()
          f = open("training_data.csv",'ab')
          f.write('{0},{1},{2}\n'.format(self._step,loss_value,accuracy_value))
          f.close()
            
    with tf.train.MonitoredTrainingSession(checkpoint_dir=train_dir,
                                           hooks=[tf.train.StopAtStepHook(last_step=max_steps),
                                                  tf.train.NanTensorHook(losses),
                                                  _LoggerHook()],save_checkpoint_secs=30, 
                                           config=tf.ConfigProto(
                                               log_device_placement=log_device_placement)) as mon_sess:
        while not mon_sess.should_stop():
            mon_sess.run(train_op)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:36:42.376915: step 0, loss = 6.38, accuracy = 0.13 (59.0 examples/sec; 2.168 sec/batch)
# 2017-03-10 22:36:44.359495: step 10, loss = 6.31, accuracy = 0.14 (512.9 examples/sec; 0.250 sec/batch)
# 2017-03-10 22:36:46.460521: step 20, loss = 6.18, accuracy = 0.17 (588.0 examples/sec; 0.218 sec/batch)
# 2017-03-10 22:36:48.561194: step 30, loss = 6.06, accuracy = 0.25 (577.9 examples/sec; 0.221 sec/batch)
examples/sec; 0.209 sec/batch)
# 2017-03-10 22:37:49.549196: step 310, loss = 4.68, accuracy = 0.51 (612.1 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:37:51.618839: step 320, loss = 4.76, accuracy = 0.43 (616.0 examples/sec; 0.208 sec/batch)
# 2017-03-10 22:37:53.724198: step 330, loss = 4.65, accuracy = 0.47 (626.6 examples/sec; 0.204 sec/batch)
# 2017-03-10 22:37:55.811797: step 340, loss = 4.64, accuracy = 0.53 (614.4 examples/sec; 0.208 sec/batch)
# 2017-03-10 22:37:58.112928: step 350, loss = 4.57, accuracy = 0.45 (530.7 examples/sec; 0.241 sec/batch)
# 2017-03-10 22:38:00.472393: step 360, loss = 4.59, accuracy = 0.48 (541.4 examples/sec; 0.236 sec/batch)
# 2017-03-10 22:38:02.809262: step 370, loss = 4.50, accuracy = 0.55 (536.9 examples/sec; 0.238 sec/batch)
# 2017-03-10 22:38:05.126971: step 380, loss = 4.47, accuracy = 0.55 (558.0 examples/sec; 0.229 sec/batch)
# 2017-03-10 22:38:07.401322: step 390, loss = 4.37, accuracy = 0.52 (545.0 examples/sec; 0.235 sec/batch)
# INFO:tensorflow:global_step/sec: 4.50169
# 2017-03-10 22:38:09.700764: step 400, loss = 4.49, accuracy = 0.44 (552.8 examples/sec; 0.232 sec/batch)
# 2017-03-10 22:38:11.830454: step 410, loss = 4.60, accuracy = 0.38 (640.0 examples/sec; 0.200 sec/batch)
# INFO:tensorflow:Saving checkpoints for 415 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:38:13.931213: step 420, loss = 4.34, accuracy = 0.52 (612.4 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:38:15.992767: step 430, loss = 4.29, accuracy = 0.49 (630.2 examples/sec; 0.203 sec/batch)
# 2017-03-10 22:38:18.070561: step 440, loss = 4.26, accuracy = 0.54 (610.7 examples/sec; 0.210 sec/batch)
# 2017-03-10 22:38:20.131015: step 450, loss = 4.38, accuracy = 0.42 (633.0 examples/sec; 0.202 sec/batch)
# 2017-03-10 22:38:22.198289: step 460, loss = 4.05, accuracy = 0.60 (595.1 examples/sec; 0.215 sec/batch)
# 2017-03-10 22:38:24.256983: step 470, loss = 4.15, accuracy = 0.52 (639.7 examples/sec; 0.200 sec/batch)
# 2017-03-10 22:38:26.316666: step 480, loss = 4.33, accuracy = 0.48 (626.2 examples/sec; 0.204 sec/batch)
# 2017-03-10 22:38:28.368144: step 490, loss = 4.39, accuracy = 0.39 (707.0 examples/sec; 0.181 sec/batch)
# INFO:tensorflow:global_step/sec: 4.81338
# 2017-03-10 22:38:30.476834: step 500, loss = 4.17, accuracy = 0.47 (544.8 examples/sec; 0.235 sec/batch)
# 2017-03-10 22:38:32.850251: step 510, loss = 3.85, accuracy = 0.62 (525.5 examples/sec; 0.244 sec/batch)
# 2017-03-10 22:38:35.160876: step 520, loss = 3.94, accuracy = 0.52 (549.8 examples/sec; 0.233 sec/batch)
# 2017-03-10 22:38:37.505964: step 530, loss = 3.87, accuracy = 0.58 (527.3 examples/sec; 0.243 sec/batch)
# 2017-03-10 22:38:39.851514: step 540, loss = 4.06, accuracy = 0.51 (569.0 examples/sec; 0.225 sec/batch)
# 2017-03-10 22:38:42.200889: step 550, loss = 3.97, accuracy = 0.51 (536.1 examples/sec; 0.239 sec/batch)
# INFO:tensorflow:Saving checkpoints for 553 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:38:44.539356: step 560, loss = 4.03, accuracy = 0.50 (631.5 examples/sec; 0.203 sec/batch)
# 2017-03-10 22:38:46.603045: step 570, loss = 3.98, accuracy = 0.51 (605.6 examples/sec; 0.211 sec/batch)
# 2017-03-10 22:38:48.712177: step 580, loss = 3.89, accuracy = 0.52 (608.7 examples/sec; 0.210 sec/batch)
# 2017-03-10 22:38:50.823451: step 590, loss = 4.15, accuracy = 0.44 (611.9 examples/sec; 0.209 sec/batch)
# INFO:tensorflow:global_step/sec: 4.45444
# 2017-03-10 22:38:52.926273: step 600, loss = 3.72, accuracy = 0.55 (613.1 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:38:54.998041: step 610, loss = 3.98, accuracy = 0.49 (627.4 examples/sec; 0.204 sec/batch)
# 2017-03-10 22:38:57.089487: step 620, loss = 3.81, accuracy = 0.58 (610.3 examples/sec; 0.210 sec/batch)
# 2017-03-10 22:38:59.193419: step 630, loss = 3.66, accuracy = 0.61 (601.2 examples/sec; 0.213 sec/batch)
# 2017-03-10 22:39:01.273986: step 640, loss = 3.88, accuracy = 0.54 (626.7 examples/sec; 0.204 sec/batch)
# 2017-03-10 22:39:03.369426: step 650, loss = 3.73, accuracy = 0.58 (599.9 examples/sec; 0.213 sec/batch)
# 2017-03-10 22:39:05.733473: step 660, loss = 3.77, accuracy = 0.55 (546.9 examples/sec; 0.234 sec/batch)
# 2017-03-10 22:39:08.094698: step 670, loss = 3.76, accuracy = 0.59 (523.4 examples/sec; 0.245 sec/batch)
# 2017-03-10 22:39:10.456773: step 680, loss = 3.52, accuracy = 0.62 (546.1 examples/sec; 0.234 sec/batch)
# INFO:tensorflow:Saving checkpoints for 691 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:39:12.968651: step 690, loss = 3.77, accuracy = 0.52 (300.4 examples/sec; 0.426 sec/batch)
# INFO:tensorflow:global_step/sec: 4.49833
# 2017-03-10 22:39:15.158269: step 700, loss = 3.76, accuracy = 0.52 (490.9 examples/sec; 0.261 sec/batch)
# 2017-03-10 22:39:17.457625: step 710, loss = 3.41, accuracy = 0.66 (617.0 examples/sec; 0.207 sec/batch)
# 2017-03-10 22:39:19.557779: step 720, loss = 3.64, accuracy = 0.52 (611.3 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:39:21.622436: step 730, loss = 3.55, accuracy = 0.55 (614.0 examples/sec; 0.208 sec/batch)
# 2017-03-10 22:39:23.688779: step 740, loss = 3.65, accuracy = 0.51 (644.8 examples/sec; 0.199 sec/batch)
# 2017-03-10 22:39:25.750692: step 750, loss = 3.38, accuracy = 0.60 (632.8 examples/sec; 0.202 sec/batch)
# 2017-03-10 22:39:27.820837: step 760, loss = 3.73, accuracy = 0.48 (601.9 examples/sec; 0.213 sec/batch)
# 2017-03-10 22:39:29.889420: step 770, loss = 3.37, accuracy = 0.62 (610.5 examples/sec; 0.210 sec/batch)
# 2017-03-10 22:39:31.981423: step 780, loss = 3.51, accuracy = 0.57 (602.3 examples/sec; 0.213 sec/batch)
# 2017-03-10 22:39:34.092390: step 790, loss = 3.45, accuracy = 0.57 (589.3 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:global_step/sec: 4.75456
# 2017-03-10 22:39:36.189210: step 800, loss = 3.52, accuracy = 0.50 (611.6 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:39:38.420978: step 810, loss = 3.44, accuracy = 0.56 (572.0 examples/sec; 0.224 sec/batch)
# 2017-03-10 22:39:40.759206: step 820, loss = 3.48, accuracy = 0.55 (584.7 examples/sec; 0.219 sec/batch)
# INFO:tensorflow:Saving checkpoints for 830 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:39:43.177964: step 830, loss = 3.36, accuracy = 0.56 (1059.8 examples/sec; 0.121 sec/batch)
# 2017-03-10 22:39:45.441906: step 840, loss = 3.36, accuracy = 0.59 (528.6 examples/sec; 0.242 sec/batch)
# 2017-03-10 22:39:47.791409: step 850, loss = 3.30, accuracy = 0.59 (549.1 examples/sec; 0.233 sec/batch)
# 2017-03-10 22:39:50.087881: step 860, loss = 3.46, accuracy = 0.52 (600.2 examples/sec; 0.213 sec/batch)
# 2017-03-10 22
# 2017-03-10 22:47:58.572283: step 3080, loss = 1.34, accuracy = 0.67 (463.4 examples/sec; 0.276 sec/batch)
# 2017-03-10 22:48:01.011688: step 3090, loss = 1.31, accuracy = 0.73 (516.0 examples/sec; 0.248 sec/batch)
# INFO:tensorflow:global_step/sec: 4.36784
# 2017-03-10 22:48:03.637196: step 3100, loss = 1.24, accuracy = 0.74 (504.6 examples/sec; 0.254 sec/batch)
# 2017-03-10 22:48:06.435692: step 3110, loss = 1.14, accuracy = 0.75 (494.5 examples/sec; 0.259 sec/batch)
# 2017-03-10 22:48:09.380900: step 3120, loss = 1.07, accuracy = 0.79 (497.3 examples/sec; 0.257 sec/batch)
# 2017-03-10 22:48:12.237881: step 3130, loss = 1.29, accuracy = 0.72 (430.4 examples/sec; 0.297 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3139 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:48:14.780202: step 3140, loss = 1.23, accuracy = 0.70 (517.2 examples/sec; 0.247 sec/batch)
# 2017-03-10 22:48:17.228269: step 3150, loss = 1.00, accuracy = 0.85 (644.4 examples/sec; 0.199 sec/batch)
# 2017-03-10 22:48:19.459749: step 3160, loss = 1.05, accuracy = 0.79 (559.5 examples/sec; 0.229 sec/batch)
# 2017-03-10 22:48:21.660732: step 3170, loss = 1.13, accuracy = 0.77 (587.0 examples/sec; 0.218 sec/batch)
# 2017-03-10 22:48:23.775252: step 3180, loss = 1.21, accuracy = 0.73 (558.2 examples/sec; 0.229 sec/batch)
# 2017-03-10 22:48:25.878134: step 3190, loss = 1.04, accuracy = 0.76 (618.3 examples/sec; 0.207 sec/batch)
# INFO:tensorflow:global_step/sec: 4.10538
# 2017-03-10 22:48:27.996800: step 3200, loss = 0.95, accuracy = 0.84 (593.7 examples/sec; 0.216 sec/batch)
# 2017-03-10 22:48:30.094143: step 3210, loss = 1.34, accuracy = 0.68 (601.4 examples/sec; 0.213 sec/batch)
# 2017-03-10 22:48:32.205139: step 3220, loss = 1.34, accuracy = 0.68 (593.1 examples/sec; 0.216 sec/batch)
# 2017-03-10 22:48:34.300274: step 3230, loss = 1.35, accuracy = 0.70 (590.3 examples/sec; 0.217 sec/batch)
# 2017-03-10 22:48:36.464015: step 3240, loss = 1.07, accuracy = 0.82 (534.0 examples/sec; 0.240 sec/batch)
# 2017-03-10 22:48:38.802900: step 3250, loss = 1.36, accuracy = 0.69 (542.8 examples/sec; 0.236 sec/batch)
# 2017-03-10 22:48:41.101735: step 3260, loss = 1.35, accuracy = 0.71 (605.8 examples/sec; 0.211 sec/batch)
# 2017-03-10 22:48:43.462666: step 3270, loss = 0.92, accuracy = 0.84 (520.4 examples/sec; 0.246 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3275 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:48:45.886762: step 3280, loss = 1.33, accuracy = 0.68 (569.4 examples/sec; 0.225 sec/batch)
# 2017-03-10 22:48:48.225763: step 3290, loss = 1.12, accuracy = 0.80 (554.8 examples/sec; 0.231 sec/batch)
# INFO:tensorflow:global_step/sec: 4.43666
# 2017-03-10 22:48:50.536028: step 3300, loss = 1.23, accuracy = 0.68 (516.9 examples/sec; 0.248 sec/batch)
# 2017-03-10 22:48:52.655895: step 3310, loss = 1.00, accuracy = 0.77 (639.6 examples/sec; 0.200 sec/batch)
# 2017-03-10 22:48:54.768015: step 3320, loss = 1.04, accuracy = 0.79 (617.4 examples/sec; 0.207 sec/batch)
# 2017-03-10 22:48:56.903568: step 3330, loss = 1.07, accuracy = 0.77 (603.6 examples/sec; 0.212 sec/batch)
# 2017-03-10 22
examples/sec; 0.217 sec/batch)
# 2017-03-10 22:50:01.573812: step 3620, loss = 1.08, accuracy = 0.76 (618.4 examples/sec; 0.207 sec/batch)
# 2017-03-10 22:50:03.687920: step 3630, loss = 1.09, accuracy = 0.73 (611.6 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:50:05.810745: step 3640, loss = 1.15, accuracy = 0.73 (611.1 examples/sec; 0.209 sec/batch)
# 2017-03-10 22:50:07.935726: step 3650, loss = 1.11, accuracy = 0.73 (602.3 examples/sec; 0.213 sec/batch)
# 2017-03-10 22:50:10.044382: step 3660, loss = 1.23, accuracy = 0.69 (569.1 examples/sec; 0.225 sec/batch)
# 2017-03-10 22:50:12.147417: step 3670, loss = 0.96, accuracy = 0.81 (642.1 examples/sec; 0.199 sec/batch)
# 2017-03-10 22:50:14.259052: step 3680, loss = 1.14, accuracy = 0.71 (583.6 examples/sec; 0.219 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3683 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:50:16.403596: step 3690, loss = 0.95, accuracy = 0.78 (556.6 examples/sec; 0.230 sec/batch)
# INFO:tensorflow:global_step/sec: 4.66447
# 2017-03-10 22:50:18.647180: step 3700, loss = 1.04, accuracy = 0.75 (524.4 examples/sec; 0.244 sec/batch)
# 2017-03-10 22:50:21.014660: step 3710, loss = 1.06, accuracy = 0.78 (539.8 examples/sec; 0.237 sec/batch)
# 2017-03-10 22:50:23.365884: step 3720, loss = 1.08, accuracy = 0.73 (543.7 examples/sec; 0.235 sec/batch)
# 2017-03-10 22:50:25.704469: step 3730, loss = 0.92, accuracy = 0.78 (557.1 examples/sec; 0.230 sec/batch)
# 2017-03-10 22:50:28.051746: step 3740, loss = 0.88, accuracy = 0.84 (597.9 examples/sec; 0.214 sec/batch)
# 2017-03-10 22:50:30.402069: step 3750, loss = 1.17, accuracy = 0.73 (513.0 examples/sec; 0.250 sec/batch)
# 2017-03-10 22:50:32.658176: step 3760, loss = 1.15, accuracy = 0.72 (642.6 examples/sec; 0.199 sec/batch)
# 2017-03-10 22:50:34.792612: step 3770, loss = 0.89, accuracy = 0.83 (596.3 examples/sec; 0.215 sec/batch)
# 2017-03-10 22:50:36.963803: step 3780, loss = 1.16, accuracy = 0.69 (582.6 examples/sec; 0.220 sec/batch)
# 2017-03-10 22:50:39.122806: step 3790, loss = 1.13, accuracy = 0.75 (591.6 examples/sec; 0.216 sec/batch)
# INFO:tensorflow:global_step/sec: 4.4192
# 2017-03-10 22:50:41.275761: step 3800, loss = 1.07, accuracy = 0.74 (599.3 examples/sec; 0.214 sec/batch)
# 2017-03-10 22:50:43.416046: step 3810, loss = 1.02, accuracy = 0.73 (596.9 examples/sec; 0.214 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3817 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:50:45.596791: step 3820, loss = 1.15, accuracy = 0.70 (591.6 examples/sec; 0.216 sec/batch)
# 2017-03-10 22:50:47.741915: step 3830, loss = 1.21, accuracy = 0.71 (589.5 examples/sec; 0.217 sec/batch)
# 2017-03-10 22:50:49.898830: step 3840, loss = 1.20, accuracy = 0.70 (597.9 examples/sec; 0.214 sec/batch)
# 2017-03-10 22:50:52.129633: step 3850, loss = 0.94, accuracy = 0.81 (547.1 examples/sec; 0.234 sec/batch)
# 2017-03-10 22:50:54.448641: step 3860, loss = 1.10, accuracy = 0.73 (579.3 examples/sec; 0.221 sec/batch)
# 2017-03-10 22:50:56.866133: step 3870, loss = 0.88, accuracy = 0.82 (507.5 examples/sec; 0.252 sec/batch)
# 2017-03-10 22:50:59.272234: step 3880, loss = 0.93, accuracy = 0.80 (551.9 examples/sec; 0.232 sec/batch)
# 2017-03-10 22:51:01.692653: step 3890, loss = 0.94, accuracy = 0.79 (508.7 examples/sec; 0.252 sec/batch)
# INFO:tensorflow:global_step/sec: 4.38639
# 2017-03-10 22:51:04.075501: step 3900, loss = 0.95, accuracy = 0.75 (495.0 examples/sec; 0.259 sec/batch)
# 2017-03-10 22:51:06.279750: step 3910, loss = 0.87, accuracy = 0.82 (620.9 examples/sec; 0.206 sec/batch)
# 2017-03-10 22:51:08.397801: step 3920, loss = 1.00, accuracy = 0.80 (611.0 examples/sec; 0.210 sec/batch)
# 2017-03-10 22:51:10.510299: step 3930, loss = 0.93, accuracy = 0.81 (604.9 examples/sec; 0.212 sec/batch)
# 2017-03-10 22:51:12.617923: step 3940, loss = 0.92, accuracy = 0.80 (625.8 examples/sec; 0.205 sec/batch)
# 2017-03-10 22:51:14.731241: step 3950, loss = 0.97, accuracy = 0.76 (602.1 examples/sec; 0.213 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3952 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:51:16.910697: step 3960, loss = 1.22, accuracy = 0.68 (583.3 examples/sec; 0.219 sec/batch)
# 2017-03-10 22:51:19.021842: step 3970, loss = 0.96, accuracy = 0.77 (622.5 examples/sec; 0.206 sec/batch)
# 2017-03-10 22:51:21.156368: step 3980, loss = 1.08, accuracy = 0.75 (589.0 examples/sec; 0.217 sec/batch)
# 2017-03-10 22:51:23.294503: step 3990, loss = 0.98, accuracy = 0.76 (611.9 examples/sec; 0.209 sec/batch)
# INFO:tensorflow:global_step/sec: 4.66415
# 2017-03-10 22:51:25.513874: step 4000, loss = 1.02, accuracy = 0.78 (504.0 examples/sec; 0.254 sec/batch)
# 2017-03-10 22:51:27.905236: step 4010, loss = 0.85, accuracy = 0.80 (566.7 examples/sec; 0.226 sec/batch)
# 2017-03-10 22:51:30.240047: step 4020, loss = 0.95, accuracy = 0.81 (567.9 examples/sec; 0.225 sec/batch)
# 2017-03-10 22:51:32.642442: step 4030, loss = 1.01, accuracy = 0.76 (546.3 examples/sec; 0.234 sec/batch)
# 2017-03-10 22:51:35.018517: step 4040, loss = 1.12, accuracy = 0.73 (560.6 examples/sec; 0.228 sec/batch)
# 2017-03-10 22:51:37.323140: step 4050, loss = 0.92, accuracy = 0.80 (561.9 examples/sec; 0.228 sec/batch)
# 2017-03-10 22:51:39.633621: step 4060, loss = 0.98, accuracy = 0.79 (618.1 examples/sec; 0.207 sec/batch)
# 2017-03-10 22:51:41.754181: step 4070, loss = 1.03, accuracy = 0.79 (620.7 examples/sec; 0.206 sec/batch)
# 2017-03-10 22:51:43.892455: step 4080, loss = 1.13, accuracy = 0.77 (563.2 examples/sec; 0.227 sec/batch)
# INFO:tensorflow:Saving checkpoints for 4087 into cifar10_trial_train/model.ckpt.
# 2017-03-10 22:51:45.988879: step 4090, loss = 0.86, accuracy = 0.88 (631.0 examples/sec; 0.203 sec/batch)
# INFO:tensorflow:global_step/sec: 4.42597
# 2017-03-10 22:51:48.109325: step 4100, loss = 0.83, accuracy = 0.81 (608.3 examples/sec; 0.210 sec/batch)
# 2017-03-10 22:51:50.218360: step 4110, loss = 0.98, accuracy = 0.74 (650.1 examples/sec; 0.197 sec/batch)
# 2017-03-10 23:43:45.495409: step 17400, loss = 0.68, accuracy = 0.86 (443.4 examples/sec; 0.289 sec/batch)
# 2017-03-10 23:43:47.899981: step 17410, loss = 0.74, accuracy = 0.85 (580.2 examples/sec; 0.221 sec/batch)
# 2017-03-10 23:43:50.186071: step 17420, loss = 0.80, accuracy = 0.83 (544.5 examples/sec; 0.235 sec/batch)
# 2017-03-10 23:43:52.480992: step 17430, loss = 0.65, accuracy = 0.90 (578.1 examples/sec; 0.221 sec/batch)
# 2017-03-10 23:43:54.768366: step 17440, loss = 0.77, accuracy = 0.84 (560.4 examples/sec; 0.228 sec/batch)
# INFO:tensorflow:Saving checkpoints for 17451 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:43:57.187342: step 17450, loss = 0.60, accuracy = 0.90 (339.1 examples/sec; 0.377 sec/batch)
# 2017-03-10 23:43:59.348114: step 17460, loss = 0.66, accuracy = 0.89 (558.8 examples/sec; 0.229 sec/batch)
# 2017-03-10 23:44:01.656642: step 17470, loss = 0.65, accuracy = 0.87 (561.2 examples/sec; 0.228 sec/batch)
# 2017-03-10 23:44:03.978860: step 17480, loss = 0.80, accuracy = 0.82 (532.8 examples/sec; 0.240 sec/batch)
# 2017-03-10 23:44:06.280434: step 17490, loss = 0.77, accuracy = 0.83 (552.3 examples/sec; 0.232 sec/batch)
# INFO:tensorflow:global_step/sec: 4.2401
# 2017-03-10 23:44:09.077436: step 17500, loss = 0.77, accuracy = 0.84 (450.0 examples/sec; 0.284 sec/batch)
# 2017-03-10 23:44:11.794868: step 17510, loss = 0.74, accuracy = 0.84 (435.6 examples/sec; 0.294 sec/batch)
# 2017-03-10 23:44:14.514339: step 17520, loss = 0.64, accuracy = 0.89 (507.4 examples/sec; 0.252 sec/batch)
# 2017-03-10 23:44:17.226436: step 17530, loss = 0.69, accuracy = 0.87 (486.2 examples/sec; 0.263 sec/batch)
# 2017-03-10 23:44:19.917560: step 17540, loss = 0.64, accuracy = 0.88 (488.1 examples/sec; 0.262 sec/batch)
# 2017-03-10 23:44:22.291230: step 17550, loss = 0.72, accuracy = 0.87 (569.8 examples/sec; 0.225 sec/batch)
# 2017-03-10 23:44:24.557735: step 17560, loss = 0.75, accuracy = 0.84 (567.1 examples/sec; 0.226 sec/batch)
# 2017-03-10 23:44:26.797967: step 17570, loss = 0.68, accuracy = 0.85 (605.0 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:Saving checkpoints for 17573 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:44:29.091944: step 17580, loss = 0.70, accuracy = 0.85 (582.9 examples/sec; 0.220 sec/batch)
# 2017-03-10 23:44:31.347590: step 17590, loss = 0.68, accuracy = 0.90 (561.6 examples/sec; 0.228 sec/batch)
# INFO:tensorflow:global_step/sec: 4.07742
# 2017-03-10 23:44:33.603620: step 17600, loss = 0.85, accuracy = 0.82 (568.7 examples/sec; 0.225 sec/batch)
# 2017-03-10 23:44:35.854971: step 17610, loss = 0.62, accuracy = 0.87 (618.8 examples/sec; 0.207 sec/batch)
# 2017-03-10 23:44:38.125367: step 17620, loss = 0.65, accuracy = 0.88 (545.4 examples/sec; 0.235 sec/batch)
# 2017-03-10 23:44:40.479476: step 17630, loss = 0.75, accuracy = 0.86 (478.3 examples/sec; 0.268 sec/batch)
# 2017-03-10 23:44:43.295085: step 17640, loss = 0.63, accuracy = 0.87 (445.1 examples/sec; 0.288 sec/batch)
# 2017-03-10 23:44:46.026772: step 17650, loss = 0.69, accuracy = 0.88 (445.3 examples/sec; 0.287 sec/batch)
# 2017-03-10 23:44:48.789827: step 17660, loss = 0.85, accuracy = 0.81 (418.3 examples/sec; 0.306 sec/batch)
# 2017-03-10 23:44:51.414387: step 17670, loss = 0.57, accuracy = 0.91 (464.5 examples/sec; 0.276 sec/batch)
# 2017-03-10 23:44:54.184623: step 17680, loss = 0.64, accuracy = 0.84 (517.2 examples/sec; 0.247 sec/batch)
# 2017-03-10 23:44:56.499892: step 17690, loss = 0.70, accuracy = 0.89 (596.2 examples/sec; 0.215 sec/batch)
# INFO:tensorflow:Saving checkpoints for 17695 into cifar10_trial_train/model.ckpt.
# INFO:tensorflow:global_step/sec: 3.97478
# 2017-03-10 23:44:58.761827: step 17700, loss = 0.59, accuracy = 0.89 (548.3 examples/sec; 0.233 sec/batch)
# 2017-03-10 23:45:00.997737: step 17710, loss = 0.63, accuracy = 0.87 (586.6 examples/sec; 0.218 sec/batch)
# 2017-03-10 23:45:03.257652: step 17720, loss = 0.64, accuracy = 0.87 (615.0 examples/sec; 0.208 sec/batch)
# 2017-03-10 23:45:05.519679: step 17730, loss = 0.83, accuracy = 0.82 (571.0 examples/sec; 0.224 sec/batch)
# 2017-03-10 23:45:07.746462: step 17740, loss = 0.70, accuracy = 0.84 (572.4 examples/sec; 0.224 sec/batch)
# 2017-03-10 23:45:10.008623: step 17750, loss = 0.76, accuracy = 0.82 (605.8 examples/sec; 0.211 sec/batch)
# 2017-03-10 23:45:12.259466: step 17760, loss = 0.60, accuracy = 0.90 (558.4 examples/sec; 0.229 sec/batch)
# 2017-03-10 23:45:14.611495: step 17770, loss = 0.78, accuracy = 0.86 (441.2 examples/sec; 0.290 sec/batch)
# 2017-03-10 23:45:17.454033: step 17780, loss = 0.74, accuracy = 0.84 (447.0 examples/sec; 0.286 sec/batch)
# 2017-03-10 23:45:20.241816: step 17790, loss = 0.65, accuracy = 0.89 (468.8 examples/sec; 0.273 sec/batch)
# INFO:tensorflow:global_step/sec: 4.12604
# 2017-03-10 23:45:22.997954: step 17800, loss = 0.66, accuracy = 0.91 (484.0 examples/sec; 0.264 sec/batch)
# 2017-03-10 23:45:25.668525: step 17810, loss = 0.62, accuracy = 0.88 (491.3 examples/sec; 0.261 sec/batch)
# INFO:tensorflow:Saving checkpoints for 17818 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:45:28.461955: step 17820, loss = 0.55, accuracy = 0.92 (458.9 examples/sec; 0.279 sec/batch)
# 2017-03-10 23:45:30.765163: step 17830, loss = 0.64, accuracy = 0.88 (551.1 examples/sec; 0.232 sec/batch)
# 2017-03-10 23:45:33.069514: step 17840, loss = 0.71, accuracy = 0.86 (556.6 examples/sec; 0.230 sec/batch)
# 2017-03-10 23:45:35.402873: step 17850, loss = 0.75, accuracy = 0.85 (531.3 examples/sec; 0.241 sec/batch)
# 2017-03-10 23:45:37.717262: step 17860, loss = 0.68, accuracy = 0.88 (565.2 examples/sec; 0.226 sec/batch)
# 2017-03-10 23:45:40.045480: step 17870, loss = 0.66, accuracy = 0.87 (533.8 examples/sec; 0.240 sec/batch)
# 2017-03-10 23:45:42.375499: step 17880, loss = 0.61, accuracy = 0.91 (558.2 examples/sec; 0.229 sec/batch)
# 2017-03-10 23:45:44.684223: step 17890, loss = 0.70, accuracy = 0.84 (561.7 examples/sec; 0.228 sec/batch)
# INFO:tensorflow:global_step/sec: 4.15886
# 2017-03-10 23:45:47.044365: step 17900, loss = 0.55, accuracy = 0.93 (556.4 examples/sec; 0.230 sec/batch)
# 2017-03-10 23:45:49.649671: step 17910, loss = 0.72, accuracy = 0.83 (496.3 examples/sec; 0.258 sec/batch)
# 2017-03-10 23:45:52.362080: step 17920, loss = 0.52, accuracy = 0.93 (494.3 examples/sec; 0.259 sec/batch)
# 2017-03-10 23:45:55.078189: step 17930, loss = 0.65, accuracy = 0.89 (438.1 examples/sec; 0.292 sec/batch)
# INFO:tensorflow:Saving checkpoints for 17941 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:45:58.056977: step 17940, loss = 0.62, accuracy = 0.91 (250.3 examples/sec; 0.511 sec/batch)
# 2017-03-10 23:46:00.607831: step 17950, loss = 0.65, accuracy = 0.88 (433.6 examples/sec; 0.295 sec/batch)
# 2017-03-10 23:46:03.177151: step 17960, loss = 0.63, accuracy = 0.88 (557.0 examples/sec; 0.230 sec/batch)
# 2017-03-10 23:46:05.418020: step 17970, loss = 0.79, accuracy = 0.80 (535.9 examples/sec; 0.239 sec/batch)
# 2017-03-10 23:46:07.680803: step 17980, loss = 0.72, accuracy = 0.84 (594.0 examples/sec; 0.215 sec/batch)
# 2017-03-10 23:46:09.912328: step 17990, loss = 0.66, accuracy = 0.89 (545.1 examples/sec; 0.235 sec/batch)
# INFO:tensorflow:global_step/sec: 3.98082
# 2017-03-10 23:46:12.163480: step 18000, loss = 0.69, accuracy = 0.88 (560.9 examples/sec; 0.228 sec/batch)
# 2017-03-10 23:46:14.435028: step 18010, loss = 0.63, accuracy = 0.89 (566.4 examples/sec; 0.226 sec/batch)
# 2017-03-10 23:46:16.706056: step 18020, loss = 0.61, accuracy = 0.91 (592.0 examples/sec; 0.216 sec/batch)
# 2017-03-10 23:46:18.972893: step 18030, loss = 0.65, accuracy = 0.88 (554.5 examples/sec; 0.231 sec/batch)
# 2017-03-10 23:46:21.252024: step 18040, loss = 0.72, accuracy = 0.84 (581.6 examples/sec; 0.220 sec/batch)
# 2017-03-10 23:46:23.896902: step 18050, loss = 0.66, accuracy = 0.89 (431.8 examples/sec; 0.296 sec/batch)
# 2017-03-10 23:46:26.708588: step 18060, loss = 0.68, accuracy = 0.88 (486.1 examples/sec; 0.263 sec/batch)
# INFO:tensorflow:Saving checkpoints for 18065 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:46:29.458506: step 18070, loss = 0.55, accuracy = 0.91 (497.9 examples/sec; 0.257 sec/batch)
# 2017-03-10 23:46:32.215780: step 18080, loss = 0.75, accuracy = 0.87 (521.4 examples/sec; 0.245 sec/batch)
# 2017-03-10 23:46:34.974969: step 18090, loss = 0.64, accuracy = 0.87 (530.9 examples/sec; 0.241 sec/batch)
# INFO:tensorflow:global_step/sec: 3.95715
# 2017-03-10 23:46:37.435902: step 18100, loss = 0.62, accuracy = 0.88 (515.6 examples/sec; 0.248 sec/batch)
# 2017-03-10 23:46:39.682918: step 18110, loss = 0.57, accuracy = 0.88 (557.4 examples/sec; 0.230 sec/batch)
# 2017-03-10 23:46:41.892542: step 18120, loss = 0.85, accuracy = 0.78 (606.3 examples/sec; 0.211 sec/batch)
# 2017-03-10 23:46:44.144685: step 18130, loss = 0.79, accuracy = 0.81 (629.9 examples/sec; 0.203 sec/batch)
# 2017-03-10 23:46:46.427774: step 18140, loss = 0.62, accuracy = 0.91 (548.6 examples/sec; 0.233 sec/batch)
# 2017-03-10 23:46:48.670452: step 18150, loss = 0.70, accuracy = 0.84 (584.1 examples/sec; 0.219 sec/batch)
# 2017-03-10 23:46:50.921635: step 18160, loss = 0.80, accuracy = 0.82 (573.5 examples/sec; 0.223 sec/batch)
# 2017-03-10 23:46:53.167686: step 18170, loss = 0.64, accuracy = 0.88 (587.1 examples/sec; 0.218 sec/batch)
# 2017-03-10 23:46:55.411478: step 18180, loss = 0.71, accuracy = 0.88 (582.7 examples/sec; 0.220 sec/batch)
# INFO:tensorflow:Saving checkpoints for 18190 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:46:58.275597: step 18190, loss = 0.71, accuracy = 0.84 (956.8 examples/sec; 0.134 sec/batch)
# INFO:tensorflow:global_step/sec: 4.25848
# 2017-03-10 23:47:00.918197: step 18200, loss = 0.63, accuracy = 0.91 (446.8 examples/sec; 0.286 sec/batch)
# 2017-03-10 23:47:03.703160: step 18210, loss = 0.74, accuracy = 0.84 (457.4 examples/sec; 0.280 sec/batch)
# 2017-03-10 23:47:06.527293: step 18220, loss = 0.68, accuracy = 0.86 (482.0 examples/sec; 0.266 sec/batch)
# 2017-03-10 23:47:09.291258: step 18230, loss = 0.77, accuracy = 0.83 (460.4 examples/sec; 0.278 sec/batch)
# 2017-03-10 23:47:11.695400: step 18240, loss = 0.69, accuracy = 0.86 (583.5 examples/sec; 0.219 sec/batch)
# 2017-03-10 23:47:13.982189: step 18250, loss = 0.60, accuracy = 0.91 (571.0 examples/sec; 0.224 sec/batch)
# 2017-03-10 23:47:16.286680: step 18260, loss = 0.78, accuracy = 0.85 (554.4 examples/sec; 0.231 sec/batch)
# 2017-03-10 23:47:18.613678: step 18270, loss = 0.69, accuracy = 0.86 (568.3 examples/sec; 0.225 sec/batch)
# 2017-03-10 23:47:20.955886: step 18280, loss = 0.64, accuracy = 0.88 (539.3 examples/sec; 0.237 sec/batch)
# 2017-03-10 23:47:23.265375: step 18290, loss = 0.88, accuracy = 0.81 (554.3 examples/sec; 0.231 sec/batch)
# INFO:tensorflow:global_step/sec: 4.05296
# 2017-03-10 23:47:25.589781: step 18300, loss = 0.66, accuracy = 0.87 (544.8 examples/sec; 0.235 sec/batch)
# INFO:tensorflow:Saving checkpoints for 18311 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:47:28.101961: step 18310, loss = 0.61, accuracy = 0.89 (329.0 examples/sec; 0.389 sec/batch)
# 2017-03-10 23:47:30.434904: step 18320, loss = 0.67, accuracy = 0.88 (466.3 examples/sec; 0.274 sec/batch)
# 2017-03-10 23:47:33.216910: step 18330, loss = 0.72, accuracy = 0.85 (457.6 examples/sec; 0.280 sec/batch)
# 2017-03-10 23:47:35.912354: step 18340, loss = 0.63, accuracy = 0.88 (462.7 examples/sec; 0.277 sec/batch)
# 2017-03-10 23:47:38.659524: step 18350, loss = 0.74, accuracy = 0.85 (478.8 examples/sec; 0.267 sec/batch)
# 2017-03-10 23:47:41.425815: step 18360, loss = 0.62, accuracy = 0.86 (478.4 examples/sec; 0.268 sec/batch)
# 2017-03-10 23:47:44.158266: step 18370, loss = 0.61, accuracy = 0.91 (590.2 examples/sec; 0.217 sec/batch)
# 2017-03-10 23:47:46.415229: step 18380, loss = 0.59, accuracy = 0.89 (570.2 examples/sec; 0.224 sec/batch)
# 2017-03-10 23:47:48.677545: step 18390, loss = 0.61, accuracy = 0.88 (555.3 examples/sec; 0.231 sec/batch)
# INFO:tensorflow:global_step/sec: 3.9444
# 2017-03-10 23:47:50.942350: step 18400, loss = 0.65, accuracy = 0.91 (563.9 examples/sec; 0.227 sec/batch)
# 2017-03-10 23:47:53.192125: step 18410, loss = 0.64, accuracy = 0.89 (611.8 examples/sec; 0.209 sec/batch)
# 2017-03-10 23:47:55.454755: step 18420, loss = 0.67, accuracy = 0.86 (578.2 examples/sec; 0.221 sec/batch)
# 2017-03-10 23:47:57.715104: step 18430, loss = 0.57, accuracy = 0.91 (550.6 examples/sec; 0.232 sec/batch)
# INFO:tensorflow:Saving checkpoints for 18433 into cifar10_trial_train/model.ckpt.
# 2017-03-10 23:47:59.988183: step 18440, loss = 0.58, accuracy = 0.91 (613.1 examples/sec; 0.209 sec/batch)
# 2017-03-10 23:48:02.319081: step 18450, loss = 0.68, accuracy = 0.90 (518.4 examples/sec; 0.247 sec/batch)
# 2017-03-10 23:48:04.919734: step 18460, loss = 0.79, accuracy = 0.80 (438.1 examples/sec; 0.292 sec/batch)
# 2017-03-10 23:48:07.712602: step 18470, loss = 0.70, accuracy = 0.86 (484.8 examples/sec; 0.264 sec/batch)
# 2017-03-10 23:48:10.488321: step 18480, loss = 0.72, accuracy = 0.84 (441.9 examples/sec; 0.290 sec/batch)
# 2017-03-10 23:48:13.284849: step 18490, loss = 0.55, accuracy = 0.92 (450.7 examples/sec; 0.284 sec/batch)
# INFO:tensorflow:global_step/sec: 3.98622
# 2017-03-10 23:48:16.030109: step 18500, loss = 0.72, accuracy = 0.84 (430.5 examples/sec; 0.297 sec/batch)
# 2017-03-10 23:48:18.580802: step 18510, loss = 0.63, accuracy = 0.90 (585.0 examples/sec; 0.219 sec/batch)
# 2017-03-10 23:48:20.844885: step 18520, loss = 0.70, accuracy = 0.88 (568.5 examples/sec; 0.225 sec/batch)
# 2017-03-10 23:48:23.091718: step 18530, loss = 0.75, accuracy = 0.84 (558.1 examples/sec; 0.229 sec/batch)
