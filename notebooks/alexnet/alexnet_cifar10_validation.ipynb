# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar10_alexnet_model/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/test_batch.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=10)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= 50
        validation_accuracy /= 50
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(20)
# Out:
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1
# INFO:tensorflow:loss: 6.376, best accuracy: 0.144
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-137
# INFO:tensorflow:loss: 5.298, best accuracy: 0.405
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-273
# INFO:tensorflow:loss: 4.797, best accuracy: 0.448
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-409
# INFO:tensorflow:loss: 4.700, best accuracy: 0.413
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-544
# INFO:tensorflow:loss: 3.962, best accuracy: 0.533
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-681
# INFO:tensorflow:loss: 3.639, best accuracy: 0.565
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-817
# INFO:tensorflow:loss: 3.269, best accuracy: 0.610
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-954
# INFO:tensorflow:loss: 3.219, best accuracy: 0.571
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1225
# INFO:tensorflow:loss: 2.559, best accuracy: 0.660
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1360
# INFO:tensorflow:loss: 2.450, best accuracy: 0.656
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1495
# INFO:tensorflow:loss: 2.226, best accuracy: 0.679
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1630
# INFO:tensorflow:loss: 2.130, best accuracy: 0.677
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1764
# INFO:tensorflow:loss: 2.099, best accuracy: 0.652
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1899
# INFO:tensorflow:loss: 1.800, best accuracy: 0.718
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2036
# INFO:tensorflow:loss: 1.902, best accuracy: 0.662
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2171
# INFO:tensorflow:loss: 1.650, best accuracy: 0.707
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2443
# INFO:tensorflow:loss: 1.524, best accuracy: 0.711
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2577
# INFO:tensorflow:loss: 1.422, best accuracy: 0.732
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2711
# INFO:tensorflow:loss: 1.427, best accuracy: 0.716
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2845
# INFO:tensorflow:loss: 1.314, best accuracy: 0.741
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2979
# INFO:tensorflow:loss: 1.253, best accuracy: 0.747
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3112
# INFO:tensorflow:loss: 1.226, best accuracy: 0.741
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3247
# INFO:tensorflow:loss: 1.243, best accuracy: 0.732
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3383
# INFO:tensorflow:loss: 1.188, best accuracy: 0.738
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3518
# INFO:tensorflow:loss: 1.186, best accuracy: 0.735
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3788
# INFO:tensorflow:loss: 1.057, best accuracy: 0.760
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-3921
# INFO:tensorflow:loss: 1.084, best accuracy: 0.750
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4054
# INFO:tensorflow:loss: 1.043, best accuracy: 0.753
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4187
# INFO:tensorflow:loss: 1.048, best accuracy: 0.756
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4319
# INFO:tensorflow:loss: 0.985, best accuracy: 0.771
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4453
# INFO:tensorflow:loss: 1.087, best accuracy: 0.740
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4587
# INFO:tensorflow:loss: 0.979, best accuracy: 0.767
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4720
# INFO:tensorflow:loss: 0.931, best accuracy: 0.780
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-4986
# INFO:tensorflow:loss: 1.023, best accuracy: 0.745
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5118
# INFO:tensorflow:loss: 0.978, best accuracy: 0.763
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5249
# INFO:tensorflow:loss: 0.953, best accuracy: 0.763
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5380
# INFO:tensorflow:loss: 0.968, best accuracy: 0.765
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5507
# INFO:tensorflow:loss: 0.929, best accuracy: 0.774
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5638
# INFO:tensorflow:loss: 0.935, best accuracy: 0.775
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5772
# INFO:tensorflow:loss: 0.911, best accuracy: 0.775
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-5905
# INFO:tensorflow:loss: 0.870, best accuracy: 0.790
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-6169
# INFO:tensorflow:loss: 0.909, best accuracy: 0.779
