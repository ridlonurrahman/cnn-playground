# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time
import six

import numpy as np
import tensorflow as tf

import cifar_input
from train import *
from loss import *
from accuracy import *
from model import *


train_dir = 'cifar10_alexnet_model/'
batch_size = 128
log_device_placement = False

# %%
def evaluate():
  eval_batch_count = 50
  validation_error=0
  validation_accuracy=0
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar10', '../../cifar/cifar10/test_batch.bin', batch_size, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images, NUM_CLASSES=10)
        saver = tf.train.Saver()
        
        losses = loss(logits, labels)
    
        accuracies = accuracy(logits, labels)
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (value_losses, value_accuracy) = sess.run(
              [losses, accuracies])
          validation_error += value_losses
          validation_accuracy += value_accuracy
        validation_error /= 50
        validation_accuracy /= 50
        
        step = str(ckpt_state.model_checkpoint_path).split('-')[1]
        tf.logging.info('loss: %.3f, best accuracy: %.3f' %
                        (validation_error, validation_accuracy))
        f = open(train_dir+"validation_data.csv",'ab')
        f.write('{0},{1},{2}\n'.format(step, validation_error,validation_accuracy))
        f.close()
        f = open(train_dir+"log.txt",'ab')
        f.write('loss: {0}, best accuracy: {1}\n'.format(validation_error, validation_accuracy))
        f.close()

# %%
if not os.path.exists(train_dir):
    os.makedirs(train_dir)
open(train_dir+'validation_data.csv', 'w').close()
while True:
    evaluate()
    time.sleep(15)
# Out:
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1
# INFO:tensorflow:loss: 12.765, best accuracy: 0.105
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-101
# INFO:tensorflow:loss: 11.220, best accuracy: 0.294
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-201
# INFO:tensorflow:loss: 9.890, best accuracy: 0.407
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-302
# INFO:tensorflow:loss: 8.836, best accuracy: 0.452
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-403
# INFO:tensorflow:loss: 8.304, best accuracy: 0.376
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-504
# INFO:tensorflow:loss: 7.131, best accuracy: 0.511
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-605
# INFO:tensorflow:loss: 6.426, best accuracy: 0.528
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-707
# INFO:tensorflow:loss: 5.925, best accuracy: 0.518
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-909
# INFO:tensorflow:loss: 4.906, best accuracy: 0.531
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1008
# INFO:tensorflow:loss: 4.335, best accuracy: 0.605
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1107
# INFO:tensorflow:loss: 3.977, best accuracy: 0.610
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1206
# INFO:tensorflow:loss: 3.658, best accuracy: 0.610
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1305
# INFO:tensorflow:loss: 3.339, best accuracy: 0.634
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1405
# INFO:tensorflow:loss: 3.113, best accuracy: 0.633
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1506
# INFO:tensorflow:loss: 2.834, best accuracy: 0.658
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1607
# INFO:tensorflow:loss: 2.711, best accuracy: 0.631
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1708
# INFO:tensorflow:loss: 2.475, best accuracy: 0.659
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1809
# INFO:tensorflow:loss: 2.455, best accuracy: 0.622
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-1910
# INFO:tensorflow:loss: 2.155, best accuracy: 0.672
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2112
# INFO:tensorflow:loss: 1.941, best accuracy: 0.678
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2211
# INFO:tensorflow:loss: 1.977, best accuracy: 0.646
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2310
# INFO:tensorflow:loss: 1.886, best accuracy: 0.642
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-2409
# INFO:tensorflow:loss: 1.672, best accuracy: 0.694
# INFO:tensorflow:Loading checkpoint cifar10_alexnet_model/model.ckpt-