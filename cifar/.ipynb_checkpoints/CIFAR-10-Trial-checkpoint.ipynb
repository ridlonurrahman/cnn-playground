# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time

import numpy as np
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

import cifar10, cifar_input, cifar_input_ver2

FLAGS = tf.app.flags.FLAGS

IMAGE_SIZE = 24

# Global constants describing the CIFAR-10 data set.
NUM_CLASSES = 10
NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN = 50000
NUM_EXAMPLES_PER_EPOCH_FOR_EVAL = 10000


# Constants describing the training process.
MOVING_AVERAGE_DECAY = 0.9999     # The decay to use for the moving average.
NUM_EPOCHS_PER_DECAY = 350.0      # Epochs after which learning rate decays.
LEARNING_RATE_DECAY_FACTOR = 0.1  # Learning rate decay factor.
INITIAL_LEARNING_RATE = 0.1       # Initial learning rate.

max_steps = 20000
train_dir = 'cifar10_trial_train/'
batch_size = 128
log_device_placement = False

# %%
def loss(logits, labels):
  """Add L2Loss to all the trainable variables.

  Add summary for "Loss" and "Loss/avg".
  Args:
    logits: Logits from inference().
    labels: Labels from distorted_inputs or inputs(). 1-D tensor
            of shape [batch_size]

  Returns:
    Loss tensor of type float.
  """
  # Calculate the average cross entropy loss across the batch.
  # labels = tf.cast(labels, tf.int64)
  cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
          logits=logits, labels=labels, name='cross_entropy_per_example')
  cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')
  tf.add_to_collection('losses', cross_entropy_mean)

  # The total loss is defined as the cross entropy loss plus all of the weight
  # decay terms (L2 loss).
  return tf.add_n(tf.get_collection('losses'), name='total_loss')

# %%
def accuracy(logits, labels):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1)), tf.float32))

# %%
def _add_loss_summaries(total_loss):
  """Add summaries for losses in CIFAR-10 model.

  Generates moving average for all losses and associated summaries for
  visualizing the performance of the network.

  Args:
    total_loss: Total loss from loss().
  Returns:
    loss_averages_op: op for generating moving averages of losses.
  """
  # Compute the moving average of all individual losses and the total loss.
  loss_averages = tf.train.ExponentialMovingAverage(0.9, name='avg')
  losses = tf.get_collection('losses')
  loss_averages_op = loss_averages.apply(losses + [total_loss])

  return loss_averages_op

def train(total_loss, global_step):
  """Train CIFAR-10 model.

  Create an optimizer and apply to all trainable variables. Add moving
  average for all trainable variables.

  Args:
    total_loss: Total loss from loss().
    global_step: Integer Variable counting the number of training steps
      processed.
  Returns:
    train_op: op for training.
  """
  # Variables that affect learning rate.
  num_batches_per_epoch = NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN / 128
  decay_steps = int(num_batches_per_epoch * NUM_EPOCHS_PER_DECAY)

  # Decay the learning rate exponentially based on the number of steps.
  lr = tf.train.exponential_decay(INITIAL_LEARNING_RATE,
                                  global_step,
                                  decay_steps,
                                  LEARNING_RATE_DECAY_FACTOR,
                                  staircase=True)

  # Generate moving averages of all losses and associated summaries.
  loss_averages_op = _add_loss_summaries(total_loss)

  # Compute gradients.
  with tf.control_dependencies([loss_averages_op]):
    opt = tf.train.GradientDescentOptimizer(lr)
    grads = opt.compute_gradients(total_loss)

  # Apply gradients.
  apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)

  # Track the moving averages of all trainable variables.
  variable_averages = tf.train.ExponentialMovingAverage(
      MOVING_AVERAGE_DECAY, global_step)
  variables_averages_op = variable_averages.apply(tf.trainable_variables())

  with tf.control_dependencies([apply_gradient_op, variables_averages_op]):
    train_op = tf.no_op(name='train')

  return train_op

# %%
def _variable_on_cpu(name, shape, initializer):
  """Helper to create a Variable stored on CPU memory.

  Args:
    name: name of the variable
    shape: list of ints
    initializer: initializer for Variable

  Returns:
    Variable Tensor
  """
  with tf.device('/cpu:0'):
    dtype = tf.float16 if 0 else tf.float32
    var = tf.get_variable(name, shape, initializer=initializer, dtype=dtype)
  return var


def _variable_with_weight_decay(name, shape, stddev, wd):
  """Helper to create an initialized Variable with weight decay.

  Note that the Variable is initialized with a truncated normal distribution.
  A weight decay is added only if one is specified.

  Args:
    name: name of the variable
    shape: list of ints
    stddev: standard deviation of a truncated Gaussian
    wd: add L2Loss weight decay multiplied by this float. If None, weight
        decay is not added for this Variable.

  Returns:
    Variable Tensor
  """
  dtype = tf.float16 if 0 else tf.float32
  var = _variable_on_cpu(
      name,
      shape,
      tf.truncated_normal_initializer(stddev=stddev, dtype=dtype))
  if wd is not None:
    weight_decay = tf.multiply(tf.nn.l2_loss(var), wd, name='weight_loss')
    tf.add_to_collection('losses', weight_decay)
  return var

def inference(images):
  """Build the CIFAR-10 model.

  Args:
    images: Images returned from distorted_inputs() or inputs().

  Returns:
    Logits.
  """
  # We instantiate all variables using tf.get_variable() instead of
  # tf.Variable() in order to share variables across multiple GPU training runs.
  # If we only ran this model on a single GPU, we could simplify this function
  # by replacing all instances of tf.get_variable() with tf.Variable().
  #
  # conv1
  with tf.variable_scope('conv1') as scope:
    kernel = _variable_with_weight_decay('weights',
                                         shape=[5, 5, 3, 64],
                                         stddev=5e-2,
                                         wd=0.0)
    conv = tf.nn.conv2d(images, kernel, [1, 1, 1, 1], padding='SAME')
    biases = _variable_on_cpu('biases', [64], tf.constant_initializer(0.0))
    pre_activation = tf.nn.bias_add(conv, biases)
    conv1 = tf.nn.relu(pre_activation, name=scope.name)
    #_activation_summary(conv1)

  # pool1
  pool1 = tf.nn.max_pool(conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1],
                         padding='SAME', name='pool1')
  # norm1
  norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm1')

  # conv2
  with tf.variable_scope('conv2') as scope:
    kernel = _variable_with_weight_decay('weights',
                                         shape=[5, 5, 64, 64],
                                         stddev=5e-2,
                                         wd=0.0)
    conv = tf.nn.conv2d(norm1, kernel, [1, 1, 1, 1], padding='SAME')
    biases = _variable_on_cpu('biases', [64], tf.constant_initializer(0.1))
    pre_activation = tf.nn.bias_add(conv, biases)
    conv2 = tf.nn.relu(pre_activation, name=scope.name)
    #_activation_summary(conv2)

  # norm2
  norm2 = tf.nn.lrn(conv2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75,
                    name='norm2')
  # pool2
  pool2 = tf.nn.max_pool(norm2, ksize=[1, 3, 3, 1],
                         strides=[1, 2, 2, 1], padding='SAME', name='pool2')

  # local3
  with tf.variable_scope('local3') as scope:
    # Move everything into depth so we can perform a single matrix multiply.
    reshape = tf.reshape(pool2, [128, -1])
    dim = reshape.get_shape()[1].value
    weights = _variable_with_weight_decay('weights', shape=[dim, 384],
                                          stddev=0.04, wd=0.004)
    biases = _variable_on_cpu('biases', [384], tf.constant_initializer(0.1))
    local3 = tf.nn.relu(tf.matmul(reshape, weights) + biases, name=scope.name)
    #_activation_summary(local3)

  # local4
  with tf.variable_scope('local4') as scope:
    weights = _variable_with_weight_decay('weights', shape=[384, 192],
                                          stddev=0.04, wd=0.004)
    biases = _variable_on_cpu('biases', [192], tf.constant_initializer(0.1))
    local4 = tf.nn.relu(tf.matmul(local3, weights) + biases, name=scope.name)
    #_activation_summary(local4)

  # linear layer(WX + b),
  # We don't apply softmax here because 
  # tf.nn.sparse_softmax_cross_entropy_with_logits accepts the unscaled logits 
  # and performs the softmax internally for efficiency.
  with tf.variable_scope('softmax_linear') as scope:
    weights = _variable_with_weight_decay('weights', [192, NUM_CLASSES],
                                          stddev=1/192.0, wd=0.0)
    biases = _variable_on_cpu('biases', [NUM_CLASSES],
                              tf.constant_initializer(0.0))
    softmax_linear = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
    #_activation_summary(softmax_linear)

  return softmax_linear

# %%
with tf.Graph().as_default():
    global_step = tf.contrib.framework.get_or_create_global_step()

    # Get images and labels for CIFAR-10.
    images, labels = cifar_input.build_input('cifar10', 'cifar10/data_batch*', 128, 'train')

    # Build a Graph that computes the logits predictions from the
    # inference model.
    logits = inference(images)

    # Calculate loss.
    losses = loss(logits, labels)
    
    accuracies = accuracy(logits, labels)

    # Build a Graph that trains the model with one batch of examples and
    # updates the model parameters.
    train_op = train(losses, global_step)

    class _LoggerHook(tf.train.SessionRunHook):
      """Logs loss and runtime."""

      def begin(self):
        self._step = -1
        open('training_data.csv', 'w').close()
        f = open("log.txt",'ab')
        f.write('\n\n==== Run ===\nInfo: Alexnet\n')
        f.close()

      def before_run(self, run_context):
        self._step += 1
        self._start_time = time.time()
        return tf.train.SessionRunArgs([losses, accuracies])  # Asks for loss value.

      def after_run(self, run_context, run_values):
        duration = time.time() - self._start_time
        loss_value = run_values.results[0]
        accuracy_value = run_values.results[1]
        if self._step % 10 == 0:
          num_examples_per_step = batch_size
          examples_per_sec = num_examples_per_step / duration
          sec_per_batch = float(duration)

          format_str = ('%s: step %d, loss = %.2f, accuracy = %.2f (%.1f examples/sec; %.3f '
                        'sec/batch)')
          print (format_str % (datetime.now(), self._step, loss_value, accuracy_value,
                               examples_per_sec, sec_per_batch))
          f = open("log.txt",'ab')
          f.write('{0}: step {1}, loss = {2:.4f} ({3:.2f} examples/sec; {4:.2f} sec/batch)\n'.format(datetime.now(), self._step, loss_value,
                               examples_per_sec, sec_per_batch))
          f.close()
          f = open("training_data.csv",'ab')
          f.write('{0},{1},{2}'.format(self._step,loss_value,accuracy_value))
          f.close()
            
    with tf.train.MonitoredTrainingSession(checkpoint_dir=train_dir,
                                           hooks=[tf.train.StopAtStepHook(last_step=max_steps),
                                                  tf.train.NanTensorHook(losses),
                                                  _LoggerHook()],save_checkpoint_secs=30, 
                                           config=tf.ConfigProto(
                                               log_device_placement=log_device_placement)) as mon_sess:
        while not mon_sess.should_stop():
            mon_sess.run(train_op)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:53:01.224345: step 0, loss = 6.38, accuracy = 0.07 (60.6 examples/sec; 2.114 sec/batch)
# 2017-03-10 20:53:03.085789: step 10, loss = 6.28, accuracy = 0.23 (617.8 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:53:05.463947: step 20, loss = 6.05, accuracy = 0.26 (505.2 examples/sec; 0.253 sec/batch)
# 2017-03-10 20:53:07.802436: step 30, loss = 6.13, accuracy = 0.20 (547.6 examples/sec; 0.234 sec/batch)
# 2017-03-10 20:53:10.169856: step 40, loss = 6.01, accuracy = 0.27 (552.0 examples/sec; 0.232 sec/batch)
# 2017-03-10 20:53:12.483415: step 50, loss = 6.00, accuracy = 0.21 (554.3 examples/sec; 0.231 sec/batch)
# 2017-03-10 20:53:14.827789: step 60, loss = 6.03, accuracy = 0.19 (553.8 examples/sec; 0.231 sec/batch)
# 2017-03-10 20:53:17.139477: step 70, loss = 5.75, accuracy = 0.26 (598.1 examples/sec; 0.214 sec/batch)
# 2017-03-10 20:53:19.344618: step 80, loss = 5.62, accuracy = 0.31 (643.1 examples/sec; 0.199 sec/batch)
# 2017-03-10 20:53:21.423311: step 90, loss = 5.64, accuracy = 0.34 (596.8 examples/sec; 0.214 sec/batch)
# INFO:tensorflow:global_step/sec: 4.45886
# 2017-03-10 20:53:23.520393: step 100, loss = 5.81, accuracy = 0.29 (639.5 examples/sec; 0.200 sec/batch)
# 2017-03-10 20:53:25.607955: step 110, loss = 5.80, accuracy = 0.27 (638.1 examples/sec; 0.201 sec/batch)
# 2017-03-10 20:53:27.711511: step 120, loss = 5.38, accuracy = 0.34 (618.5 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:53:29.814733: step 130, loss = 5.59, accuracy = 0.31 (616.0 examples/sec; 0.208 sec/batch)
# INFO:tensorflow:Saving checkpoints for 138 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:53:31.960396: step 140, loss = 5.64, accuracy = 0.27 (594.8 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:53:34.062738: step 150, loss = 5.50, accuracy = 0.25 (630.9 examples/sec; 0.203 sec/batch)
# 2017-03-10 20:53:36.164257: step 160, loss = 5.30, accuracy = 0.37 (614.1 examples/sec; 0.208 sec/batch)
# 2017-03-10 20:53:38.263586: step 170, loss = 5.38, accuracy = 0.37 (607.7 examples/sec; 0.211 sec/batch)
# 2017-03-10 20:53:40.368297: step 180, loss = 5.14, accuracy = 0.48 (618.8 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:53:42.466700: step 190, loss = 5.03, accuracy = 0.43 (627.2 examples/sec; 0.204 sec/batch)
# INFO:tensorflow:global_step/sec: 4.75052
# 2017-03-10 20:53:44.571098: step 200, loss = 5.13, accuracy = 0.40 (619.4 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:53:46.689222: step 210, loss = 5.12, accuracy = 0.41 (575.5 examples/sec; 0.222 sec/batch)
# 2017-03-10 20:53:48.985597: step 220, loss = 5.12, accuracy = 0.40 (522.8 examples/sec; 0.245 sec/batch)
# 2017-03-10 20:53:51.359508: step 230, loss = 5.08, accuracy = 0.34 (551.0 examples/sec; 0.232 sec/batch)
# 2017-03-10 20:53:53.730122: step 240, loss = 4.92, accuracy = 0.41 (535.8 examples/sec; 0.239 sec/batch)
# 2017-03-10 20:53:56.095413: step 250, loss = 4.75, accuracy = 0.55 (550.3 examples/sec; 0.233 sec/batch)
# 2017-03-10 20:53:58.377649: step 260, loss = 4.96, accuracy = 0.41 (559.4 examples/sec; 0.229 sec/batch)
# 2017-03-10 20:54:00.748029: step 270, loss = 4.54, accuracy = 0.53 (513.0 examples/sec; 0.250 sec/batch)
# INFO:tensorflow:Saving checkpoints for 274 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:54:02.973530: step 280, loss = 5.05, accuracy = 0.35 (638.1 examples/sec; 0.201 sec/batch)
# 2017-03-10 20:54:05.055280: step 290, loss = 4.71, accuracy = 0.48 (637.2 examples/sec; 0.201 sec/batch)
# INFO:tensorflow:global_step/sec: 4.43037
# 2017-03-10 20:54:07.142234: step 300, loss = 4.65, accuracy = 0.52 (609.1 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:54:09.231992: step 310, loss = 4.83, accuracy = 0.44 (620.7 examples/sec; 0.206 sec/batch)
# 2017-03-10 20:54:11.334455: step 320, loss = 4.69, accuracy = 0.43 (609.8 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:54:13.444522: step 330, loss = 4.59, accuracy = 0.48 (621.1 examples/sec; 0.206 sec/batch)
# 2017-03-10 20:54:15.575782: step 340, loss = 4.74, accuracy = 0.43 (600.1 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:54:17.683271: step 350, loss = 4.66, accuracy = 0.43 (581.8 examples/sec; 0.220 sec/batch)
# 2017-03-10 20:54:19.786345: step 360, loss = 4.55, accuracy = 0.47 (600.0 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:54:21.886638: step 370, loss = 4.50, accuracy = 0.47 (594.0 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:54:23.987329: step 380, loss = 4.63, accuracy = 0.41 (610.9 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:54:26.098197: step 390, loss = 4.47, accuracy = 0.45 (619.7 examples/sec; 0.207 sec/batch)
# INFO:tensorflow:global_step/sec: 4.74174
# 2017-03-10 20:54:28.232845: step 400, loss = 4.33, accuracy = 0.52 (610.4 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:54:30.337632: step 410, loss = 4.39, accuracy = 0.44 (589.6 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:Saving checkpoints for 417 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:54:32.690780: step 420, loss = 4.18, accuracy = 0.55 (527.6 examples/sec; 0.243 sec/batch)
# 2017-03-10 20:54:35.050554: step 430, loss = 4.36, accuracy = 0.47 (570.7 examples/sec; 0.224 sec/batch)
# 2017-03-10 20:54:37.422657: step 440, loss = 4.22, accuracy = 0.51 (526.5 examples/sec; 0.243 sec/batch)
# 2017-03-10 20:54:39.732375: step 450, loss = 4.31, accuracy = 0.52 (644.9 examples/sec; 0.198 sec/batch)
# 2017-03-10 20:54:42.103646: step 460, loss = 4.28, accuracy = 0.43 (559.1 examples/sec; 0.229 sec/batch)
# 2017-03-10 20:54:44.488741: step 470, loss = 4.29, accuracy = 0.46 (556.9 examples/sec; 0.230 sec/batch)
# 2017-03-10 20:54:46.589036: step 480, loss = 4.36, accuracy = 0.47 (675.2 examples/sec; 0.190 sec/batch)
# 2017-03-10 20:54:48.674707: step 490, loss = 4.23, accuracy = 0.52 (593.0 examples/sec; 0.216 sec/batch)
# INFO:tensorflow:global_step/sec: 4.44033
# 2017-03-10 20:54:50.753047: step 500, loss = 4.34, accuracy = 0.45 (592.7 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:54:52.836881: step 510, loss = 3.99, accuracy = 0.55 (628.2 examples/sec; 0.204 sec/batch)
# 2017-03-10 20:54:54.959935: step 520, loss = 4.11, accuracy = 0.49 (603.2 examples/sec; 0.212 sec/batch)
# 2017-03-10 20:54:57.080320: step 530, loss = 4.14, accuracy = 0.43 (573.3 examples/sec; 0.223 sec/batch)
# 2017-03-10 20:54:59.184224: step 540, loss = 3.85, accuracy = 0.56 (629.5 examples/sec; 0.203 sec/batch)
# 2017-03-10 20:55:01.298900: step 550, loss = 3.92, accuracy = 0.52 (627.5 examples/sec; 0.204 sec/batch)
# INFO:tensorflow:Saving checkpoints for 553 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:55:03.446199: step 560, loss = 3.99, accuracy = 0.48 (613.2 examples/sec; 0.209 sec/batch)
# 2017-03-10 20:55:05.567435: step 570, loss = 4.11, accuracy = 0.46 (581.0 examples/sec; 0.220 sec/batch)
# 2017-03-10 20:55:07.673741: step 580, loss = 3.94, accuracy = 0.56 (608.3 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:55:09.789099: step 590, loss = 4.29, accuracy = 0.41 (583.4 examples/sec; 0.219 sec/batch)
# INFO:tensorflow:global_step/sec: 4.72633
# 2017-03-10 20:55:11.912714: step 600, loss = 4.01, accuracy = 0.48 (594.7 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:55:14.022437: step 610, loss = 3.66, accuracy = 0.62 (599.6 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:55:16.316442: step 620, loss = 3.83, accuracy = 0.52 (541.1 examples/sec; 0.237 sec/batch)
# 2017-03-10 20:55:18.706433: step 630, loss = 3.76, accuracy = 0.54 (517.7 examples/sec; 0.247 sec/batch)
# 2017-03-10 20:55:21.074524: step 640, loss = 4.06, accuracy = 0.48 (551.5 examples/sec; 0.232 sec/batch)
# 2017-03-10 20:55:23.490766: step 650, loss = 3.60, accuracy = 0.60 (546.5 examples/sec; 0.234 sec/batch)
# 2017-03-10 20:55:25.845875: step 660, loss = 3.67, accuracy = 0.53 (547.6 examples/sec; 0.234 sec/batch)
# 2017-03-10 20:55:28.225958: step 670, loss = 3.61, accuracy = 0.59 (550.6 examples/sec; 0.232 sec/batch)
# 2017-03-10 20:55:30.331685: step 680, loss = 3.59, accuracy = 0.62 (600.6 examples/sec; 0.213 sec/batch)
# INFO:tensorflow:Saving checkpoints for 688 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:55:32.420919: step 690, loss = 3.62, accuracy = 0.52 (605.4 examples/sec; 0.211 sec/batch)
# INFO:tensorflow:global_step/sec: 4.42514
# 2017-03-10 20:55:34.508534: step 700, loss = 3.73, accuracy = 0.55 (616.1 examples/sec; 0.208 sec/batch)
# 2017-03-10 20:55:36.588190: step 710, loss = 3.71, accuracy = 0.55 (611.7 examples/sec; 0.209 sec/batch)
# 2017-03-10 20:55:38.681609: step 720, loss = 3.63, accuracy = 0.55 (595.8 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:55:40.777214: step 730, loss = 3.63, accuracy = 0.57 (607.2 examples/sec; 0.211 sec/batch)
# 2017-03-10 20:55:42.898868: step 740, loss = 3.67, accuracy = 0.46 (590.9 examples/sec; 0.217 sec/batch)
# 2017-03-10 20:55:45.029454: step 750, loss = 3.65, accuracy = 0.48 (562.1 examples/sec; 0.228 sec/batch)
# 2017-03-10 20:55:47.130088: step 760, loss = 3.41, accuracy = 0.62 (612.0 examples/sec; 0.209 sec/batch)
# 2017-03-10 20:55:49.253113: step 770, loss = 3.32, accuracy = 0.58 (602.0 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:55:51.342568: step 780, loss = 3.49, accuracy = 0.50 (594.3 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:55:53.461925: step 790, loss = 3.39, accuracy = 0.55 (601.4 examples/sec; 0.213 sec/batch)
# INFO:tensorflow:global_step/sec: 4.74322
# 2017-03-10 20:55:55.592875: step 800, loss = 3.34, accuracy = 0.60 (597.6 examples/sec; 0.214 sec/batch)
# 2017-03-10 20:55:57.727472: step 810, loss = 3.38, accuracy = 0.57 (584.8 examples/sec; 0.219 sec/batch)
# 2017-03-10 20:56:00.066401: step 820, loss = 3.27, accuracy = 0.59 (535.0 examples/sec; 0.239 sec/batch)
# INFO:tensorflow:Saving checkpoints for 829 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:56:02.512108: step 830, loss = 3.21, accuracy = 0.58 (608.4 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:56:04.917674: step 840, loss = 3.22, accuracy = 0.66 (506.3 examples/sec; 0.253 sec/batch)
# 2017-03-10 20:56:07.252529: step 850, loss = 3.12, accuracy = 0.69 (540.9 examples/sec; 0.237 sec/batch)
# 2017-03-10 20:56:09.635879: step 860, loss = 3.24, accuracy = 0.58 (514.3 examples/sec; 0.249 sec/batch)
# 2017-03-10 20:56:11.989361: step 870, loss = 3.25, accuracy = 0.60 (531.3 examples/sec; 0.241 sec/batch)
# 2017-03-10 20:56:14.089476: step 880, loss = 3.23, accuracy = 0.61 (572.6 examples/sec; 0.224 sec/batch)
# 2017-03-10 20:56:16.169288: step 890, loss = 2.98, accuracy = 0.68 (637.0 examples/sec; 0.201 sec/batch)
# INFO:tensorflow:global_step/sec: 4.40732
# 2017-03-10 20:56:18.280786: step 900, loss = 3.21, accuracy = 0.58 (610.2 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:56:20.360046: step 910, loss = 3.19, accuracy = 0.57 (610.8 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:56:22.447921: step 920, loss = 3.11, accuracy = 0.58 (638.0 examples/sec; 0.201 sec/batch)
# 2017-03-10 20:56:24.552526: step 930, loss = 3.01, accuracy = 0.64 (594.2 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:56:26.648801: step 940, loss = 3.30, accuracy = 0.50 (591.5 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:56:28.755716: step 950, loss = 3.09, accuracy = 0.55 (609.0 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:56:30.844273: step 960, loss = 3.10, accuracy = 0.61 (596.5 examples/sec; 0.215 sec/batch)
# INFO:tensorflow:Saving checkpoints for 967 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:56:32.943696: step 970, loss = 3.15, accuracy = 0.61 (631.8 examples/sec; 0.203 sec/batch)
# 2017-03-10 20:56:35.044985: step 980, loss = 2.94, accuracy = 0.64 (594.6 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:56:37.150191: step 990, loss = 2.94, accuracy = 0.62 (571.1 examples/sec; 0.224 sec/batch)
# INFO:tensorflow:global_step/sec: 4.77087
# 2017-03-10 20:56:39.242819: step 1000, loss = 3.09, accuracy = 0.61 (623.4 examples/sec; 0.205 sec/batch)
# 2017-03-10 20:56:41.326590: step 1010, loss = 3.01, accuracy = 0.56 (601.1 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:56:43.672414: step 1020, loss = 3.02, accuracy = 0.62 (516.7 examples/sec; 0.248 sec/batch)
# 2017-03-10 20:56:46.114401: step 1030, loss = 2.96, accuracy = 0.61 (511.8 examples/sec; 0.250 sec/batch)
# 2017-03-10 20:56:48.491451: step 1040, loss = 3.06, accuracy = 0.54 (558.0 examples/sec; 0.229 sec/batch)
# 2017-03-10 20:56:50.879312: step 1050, loss = 2.84, accuracy = 0.64 (575.8 examples/sec; 0.222 sec/batch)
# 2017-03-10 20:56:53.308474: step 1060, loss = 2.71, accuracy = 0.68 (518.4 examples/sec; 0.247 sec/batch)
# 2017-03-10 20:56:55.612121: step 1070, loss = 3.11, accuracy = 0.58 (610.0 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:56:57.702478: step 1080, loss = 2.85, accuracy = 0.62 (615.0 examples/sec; 0.208 sec/batch)
# 2017-03-10 20:56:59.806277: step 1090, loss = 2.93, accuracy = 0.57 (620.7 examples/sec; 0.206 sec/batch)
# INFO:tensorflow:global_step/sec: 4.4133
# 2017-03-10 20:57:01.901659: step 1100, loss = 2.83, accuracy = 0.61 (591.6 examples/sec; 0.216 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1102 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:57:04.014674: step 1110, loss = 2.85, accuracy = 0.59 (609.0 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:57:06.108146: step 1120, loss = 2.71, accuracy = 0.66 (621.4 examples/sec; 0.206 sec/batch)
# 2017-03-10 20:57:08.197910: step 1130, loss = 2.85, accuracy = 0.52 (626.4 examples/sec; 0.204 sec/batch)
# 2017-03-10 20:57:10.296880: step 1140, loss = 2.76, accuracy = 0.60 (598.9 examples/sec; 0.214 sec/batch)
# 2017-03-10 20:57:12.394365: step 1150, loss = 2.72, accuracy = 0.67 (586.9 examples/sec; 0.218 sec/batch)
# 2017-03-10 20:57:14.481126: step 1160, loss = 2.81, accuracy = 0.59 (609.7 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:57:16.574168: step 1170, loss = 2.65, accuracy = 0.67 (617.5 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:57:18.688488: step 1180, loss = 2.53, accuracy = 0.69 (584.8 examples/sec; 0.219 sec/batch)
# 2017-03-10 20:57:20.787039: step 1190, loss = 2.67, accuracy = 0.63 (611.7 examples/sec; 0.209 sec/batch)
# INFO:tensorflow:global_step/sec: 4.76425
# 2017-03-10 20:57:22.890019: step 1200, loss = 2.51, accuracy = 0.66 (584.0 examples/sec; 0.219 sec/batch)
# 2017-03-10 20:57:24.971754: step 1210, loss = 2.59, accuracy = 0.66 (588.2 examples/sec; 0.218 sec/batch)
# 2017-03-10 20:57:27.343362: step 1220, loss = 2.50, accuracy = 0.70 (553.0 examples/sec; 0.231 sec/batch)
# 2017-03-10 20:57:29.749632: step 1230, loss = 2.45, accuracy = 0.72 (534.1 examples/sec; 0.240 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1241 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:57:32.337417: step 1240, loss = 2.63, accuracy = 0.65 (302.7 examples/sec; 0.423 sec/batch)
# 2017-03-10 20:57:34.662116: step 1250, loss = 2.52, accuracy = 0.65 (539.2 examples/sec; 0.237 sec/batch)
# 2017-03-10 20:57:37.035514: step 1260, loss = 2.56, accuracy = 0.60 (564.5 examples/sec; 0.227 sec/batch)
# 2017-03-10 20:57:39.324452: step 1270, loss = 2.85, accuracy = 0.55 (570.6 examples/sec; 0.224 sec/batch)
# 2017-03-10 20:57:41.422991: step 1280, loss = 2.53, accuracy = 0.67 (616.9 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:57:43.557711: step 1290, loss = 2.33, accuracy = 0.70 (587.3 examples/sec; 0.218 sec/batch)
# INFO:tensorflow:global_step/sec: 4.38382
# 2017-03-10 20:57:45.702473: step 1300, loss = 2.41, accuracy = 0.66 (574.0 examples/sec; 0.223 sec/batch)
# 2017-03-10 20:57:47.829669: step 1310, loss = 2.45, accuracy = 0.64 (578.6 examples/sec; 0.221 sec/batch)
# 2017-03-10 20:57:49.955435: step 1320, loss = 2.63, accuracy = 0.60 (617.4 examples/sec; 0.207 sec/batch)
# 2017-03-10 20:57:52.096217: step 1330, loss = 2.35, accuracy = 0.69 (601.6 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:57:54.219265: step 1340, loss = 2.82, accuracy = 0.55 (625.3 examples/sec; 0.205 sec/batch)
# 2017-03-10 20:57:56.362503: step 1350, loss = 2.37, accuracy = 0.66 (628.8 examples/sec; 0.204 sec/batch)
# 2017-03-10 20:57:58.490206: step 1360, loss = 2.38, accuracy = 0.68 (592.8 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:58:00.630419: step 1370, loss = 2.42, accuracy = 0.66 (575.2 examples/sec; 0.223 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1379 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:58:02.768259: step 1380, loss = 2.20, accuracy = 0.73 (642.5 examples/sec; 0.199 sec/batch)
# 2017-03-10 20:58:04.893959: step 1390, loss = 2.54, accuracy = 0.59 (611.4 examples/sec; 0.209 sec/batch)
# INFO:tensorflow:global_step/sec: 4.68921
# 2017-03-10 20:58:07.028300: step 1400, loss = 2.37, accuracy = 0.63 (590.0 examples/sec; 0.217 sec/batch)
# 2017-03-10 20:58:09.252699: step 1410, loss = 2.33, accuracy = 0.65 (522.5 examples/sec; 0.245 sec/batch)
# 2017-03-10 20:58:11.643685: step 1420, loss = 2.32, accuracy = 0.70 (518.6 examples/sec; 0.247 sec/batch)
# 2017-03-10 20:58:14.030875: step 1430, loss = 2.30, accuracy = 0.61 (501.4 examples/sec; 0.255 sec/batch)
# 2017-03-10 20:58:16.358860: step 1440, loss = 2.47, accuracy = 0.63 (591.8 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:58:18.729123: step 1450, loss = 2.21, accuracy = 0.73 (557.4 examples/sec; 0.230 sec/batch)
# 2017-03-10 20:58:21.119831: step 1460, loss = 2.46, accuracy = 0.64 (511.4 examples/sec; 0.250 sec/batch)
# 2017-03-10 20:58:23.332386: step 1470, loss = 2.28, accuracy = 0.70 (590.3 examples/sec; 0.217 sec/batch)
# 2017-03-10 20:58:25.436124: step 1480, loss = 2.22, accuracy = 0.68 (598.0 examples/sec; 0.214 sec/batch)
# 2017-03-10 20:58:27.525139: step 1490, loss = 2.22, accuracy = 0.70 (623.5 examples/sec; 0.205 sec/batch)
# INFO:tensorflow:global_step/sec: 4.41681
# 2017-03-10 20:58:29.667726: step 1500, loss = 2.27, accuracy = 0.66 (593.7 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:58:31.807717: step 1510, loss = 2.22, accuracy = 0.67 (567.0 examples/sec; 0.226 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1514 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:58:33.992816: step 1520, loss = 2.13, accuracy = 0.71 (612.4 examples/sec; 0.209 sec/batch)
# 2017-03-10 20:58:36.131041: step 1530, loss = 2.53, accuracy = 0.61 (593.7 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:58:38.267284: step 1540, loss = 2.22, accuracy = 0.70 (601.6 examples/sec; 0.213 sec/batch)
# 2017-03-10 20:58:40.400534: step 1550, loss = 2.35, accuracy = 0.57 (616.5 examples/sec; 0.208 sec/batch)
# 2017-03-10 20:58:42.523544: step 1560, loss = 2.23, accuracy = 0.66 (592.3 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:58:44.658963: step 1570, loss = 2.07, accuracy = 0.72 (586.6 examples/sec; 0.218 sec/batch)
# 2017-03-10 20:58:46.794287: step 1580, loss = 2.23, accuracy = 0.58 (615.1 examples/sec; 0.208 sec/batch)
# 2017-03-10 20:58:48.929331: step 1590, loss = 2.52, accuracy = 0.61 (590.9 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:global_step/sec: 4.67005
# 2017-03-10 20:58:51.080640: step 1600, loss = 2.09, accuracy = 0.69 (595.9 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:58:53.446968: step 1610, loss = 2.34, accuracy = 0.65 (520.7 examples/sec; 0.246 sec/batch)
# 2017-03-10 20:58:55.853566: step 1620, loss = 2.06, accuracy = 0.70 (558.8 examples/sec; 0.229 sec/batch)
# 2017-03-10 20:58:58.256266: step 1630, loss = 2.16, accuracy = 0.68 (488.4 examples/sec; 0.262 sec/batch)
# 2017-03-10 20:59:00.629267: step 1640, loss = 2.12, accuracy = 0.63 (500.4 examples/sec; 0.256 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1649 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:59:03.017966: step 1650, loss = 2.00, accuracy = 0.73 (676.6 examples/sec; 0.189 sec/batch)
# 2017-03-10 20:59:05.428949: step 1660, loss = 2.12, accuracy = 0.68 (517.0 examples/sec; 0.248 sec/batch)
# 2017-03-10 20:59:07.571677: step 1670, loss = 2.16, accuracy = 0.64 (598.1 examples/sec; 0.214 sec/batch)
# 2017-03-10 20:59:09.671394: step 1680, loss = 1.95, accuracy = 0.70 (611.4 examples/sec; 0.209 sec/batch)
# 2017-03-10 20:59:11.794591: step 1690, loss = 2.17, accuracy = 0.62 (567.5 examples/sec; 0.226 sec/batch)
# INFO:tensorflow:global_step/sec: 4.38341
# 2017-03-10 20:59:13.893877: step 1700, loss = 1.90, accuracy = 0.70 (591.6 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:59:16.031377: step 1710, loss = 2.09, accuracy = 0.68 (596.0 examples/sec; 0.215 sec/batch)
# 2017-03-10 20:59:18.160596: step 1720, loss = 2.05, accuracy = 0.68 (610.7 examples/sec; 0.210 sec/batch)
# 2017-03-10 20:59:20.302200: step 1730, loss = 2.28, accuracy = 0.57 (591.7 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:59:22.446372: step 1740, loss = 1.85, accuracy = 0.77 (553.7 examples/sec; 0.231 sec/batch)
# 2017-03-10 20:59:24.569824: step 1750, loss = 2.05, accuracy = 0.68 (604.9 examples/sec; 0.212 sec/batch)
# 2017-03-10 20:59:26.703192: step 1760, loss = 1.86, accuracy = 0.77 (629.8 examples/sec; 0.203 sec/batch)
# 2017-03-10 20:59:28.864708: step 1770, loss = 1.90, accuracy = 0.70 (582.8 examples/sec; 0.220 sec/batch)
# 2017-03-10 20:59:30.983598: step 1780, loss = 2.05, accuracy = 0.65 (607.3 examples/sec; 0.211 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1789 into cifar10_trial_train/model.ckpt.
# 2017-03-10 20:59:33.156956: step 1790, loss = 1.95, accuracy = 0.72 (620.3 examples/sec; 0.206 sec/batch)
# INFO:tensorflow:global_step/sec: 4.67012
# 2017-03-10 20:59:35.306220: step 1800, loss = 1.87, accuracy = 0.72 (587.4 examples/sec; 0.218 sec/batch)
# 2017-03-10 20:59:37.758232: step 1810, loss = 1.96, accuracy = 0.66 (575.8 examples/sec; 0.222 sec/batch)
# 2017-03-10 20:59:40.163504: step 1820, loss = 1.84, accuracy = 0.70 (518.1 examples/sec; 0.247 sec/batch)
# 2017-03-10 20:59:42.552296: step 1830, loss = 1.88, accuracy = 0.66 (543.5 examples/sec; 0.236 sec/batch)
# 2017-03-10 20:59:44.917357: step 1840, loss = 1.73, accuracy = 0.76 (477.3 examples/sec; 0.268 sec/batch)
# 2017-03-10 20:59:47.310064: step 1850, loss = 1.68, accuracy = 0.77 (509.8 examples/sec; 0.251 sec/batch)
# 2017-03-10 20:59:49.574689: step 1860, loss = 1.86, accuracy = 0.73 (592.3 examples/sec; 0.216 sec/batch)
# 2017-03-10 20:59:51.705322: step 1870, loss = 1.94, accuracy = 0.69 (566.3 examples/sec; 0.226 sec/batch)
# 2017-03-10 20:59:53.806719: step 1880, loss = 1.89, accuracy = 0.66 (667.0 examples/sec; 0.192 sec/batch)
# 2017-03-10 20:59:55.914058: step 1890, loss = 1.93, accuracy = 0.70 (603.1 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.40531
# 2017-03-10 20:59:58.006323: step 1900, loss = 1.83, accuracy = 0.71 (648.3 examples/sec; 0.197 sec/batch)
# 2017-03-10 21:00:00.121422: step 1910, loss = 1.77, accuracy = 0.72 (607.1 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:00:02.270804: step 1920, loss = 1.88, accuracy = 0.67 (612.4 examples/sec; 0.209 sec/batch)
# INFO:tensorflow:Saving checkpoints for 1923 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:00:04.474355: step 1930, loss = 1.87, accuracy = 0.61 (583.1 examples/sec; 0.220 sec/batch)
# 2017-03-10 21:00:06.604133: step 1940, loss = 1.93, accuracy = 0.63 (585.1 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:00:08.713752: step 1950, loss = 1.95, accuracy = 0.66 (612.1 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:00:10.826078: step 1960, loss = 1.80, accuracy = 0.72 (606.6 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:00:12.943468: step 1970, loss = 1.80, accuracy = 0.70 (636.1 examples/sec; 0.201 sec/batch)
# 2017-03-10 21:00:15.071415: step 1980, loss = 1.69, accuracy = 0.76 (605.7 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:00:17.182998: step 1990, loss = 1.84, accuracy = 0.66 (588.5 examples/sec; 0.218 sec/batch)
# INFO:tensorflow:global_step/sec: 4.68099
# 2017-03-10 21:00:19.369270: step 2000, loss = 1.86, accuracy = 0.66 (602.4 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:00:21.751045: step 2010, loss = 1.68, accuracy = 0.75 (619.1 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:00:24.128681: step 2020, loss = 1.68, accuracy = 0.72 (475.1 examples/sec; 0.269 sec/batch)
# 2017-03-10 21:00:26.469406: step 2030, loss = 1.71, accuracy = 0.73 (575.7 examples/sec; 0.222 sec/batch)
# 2017-03-10 21:00:28.797926: step 2040, loss = 1.76, accuracy = 0.71 (551.4 examples/sec; 0.232 sec/batch)
# 2017-03-10 21:00:31.205565: step 2050, loss = 1.74, accuracy = 0.70 (531.2 examples/sec; 0.241 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2058 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:00:33.509093: step 2060, loss = 1.73, accuracy = 0.73 (643.2 examples/sec; 0.199 sec/batch)
# 2017-03-10 21:00:35.601783: step 2070, loss = 1.79, accuracy = 0.66 (621.3 examples/sec; 0.206 sec/batch)
# 2017-03-10 21:00:37.692508: step 2080, loss = 1.78, accuracy = 0.68 (625.6 examples/sec; 0.205 sec/batch)
# 2017-03-10 21:00:39.785426: step 2090, loss = 1.77, accuracy = 0.64 (649.5 examples/sec; 0.197 sec/batch)
# INFO:tensorflow:global_step/sec: 4.44287
# 2017-03-10 21:00:41.877302: step 2100, loss = 1.95, accuracy = 0.61 (624.4 examples/sec; 0.205 sec/batch)
# 2017-03-10 21:00:43.968042: step 2110, loss = 1.68, accuracy = 0.71 (622.3 examples/sec; 0.206 sec/batch)
# 2017-03-10 21:00:46.054715: step 2120, loss = 1.60, accuracy = 0.75 (626.4 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:00:48.168921: step 2130, loss = 1.55, accuracy = 0.78 (616.9 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:00:50.309190: step 2140, loss = 1.70, accuracy = 0.70 (610.4 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:00:52.439972: step 2150, loss = 1.59, accuracy = 0.71 (585.2 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:00:54.571146: step 2160, loss = 1.61, accuracy = 0.70 (619.3 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:00:56.691211: step 2170, loss = 1.59, accuracy = 0.75 (614.6 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:00:58.833074: step 2180, loss = 1.56, accuracy = 0.79 (579.4 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:01:00.958555: step 2190, loss = 1.52, accuracy = 0.76 (591.2 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2200 into cifar10_trial_train/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.67231
# 2017-03-10 21:01:03.281470: step 2200, loss = 1.66, accuracy = 0.69 (969.8 examples/sec; 0.132 sec/batch)
# 2017-03-10 21:01:05.607609: step 2210, loss = 1.65, accuracy = 0.75 (603.7 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:01:08.000836: step 2220, loss = 1.56, accuracy = 0.71 (536.6 examples/sec; 0.239 sec/batch)
# 2017-03-10 21:01:10.414952: step 2230, loss = 1.79, accuracy = 0.66 (544.0 examples/sec; 0.235 sec/batch)
# 2017-03-10 21:01:12.824162: step 2240, loss = 1.49, accuracy = 0.73 (507.2 examples/sec; 0.252 sec/batch)
# 2017-03-10 21:01:15.199230: step 2250, loss = 1.51, accuracy = 0.73 (518.9 examples/sec; 0.247 sec/batch)
# 2017-03-10 21:01:17.429821: step 2260, loss = 1.51, accuracy = 0.73 (614.5 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:01:19.537781: step 2270, loss = 1.54, accuracy = 0.72 (602.8 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:01:21.638708: step 2280, loss = 1.51, accuracy = 0.73 (615.3 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:01:23.736947: step 2290, loss = 1.62, accuracy = 0.74 (588.4 examples/sec; 0.218 sec/batch)
# INFO:tensorflow:global_step/sec: 4.4355
# 2017-03-10 21:01:25.825000: step 2300, loss = 1.67, accuracy = 0.68 (615.5 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:01:27.924972: step 2310, loss = 1.65, accuracy = 0.70 (623.2 examples/sec; 0.205 sec/batch)
# 2017-03-10 21:01:30.029762: step 2320, loss = 1.49, accuracy = 0.70 (598.6 examples/sec; 0.214 sec/batch)
# 2017-03-10 21:01:32.121155: step 2330, loss = 1.64, accuracy = 0.69 (619.2 examples/sec; 0.207 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2335 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:01:34.236565: step 2340, loss = 1.63, accuracy = 0.67 (594.9 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:01:36.352255: step 2350, loss = 1.28, accuracy = 0.82 (612.3 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:01:38.489118: step 2360, loss = 1.47, accuracy = 0.73 (571.5 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:01:40.578523: step 2370, loss = 1.34, accuracy = 0.80 (584.8 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:01:42.701279: step 2380, loss = 1.58, accuracy = 0.73 (642.1 examples/sec; 0.199 sec/batch)
# 2017-03-10 21:01:44.838753: step 2390, loss = 1.62, accuracy = 0.72 (570.2 examples/sec; 0.224 sec/batch)
# INFO:tensorflow:global_step/sec: 4.71091
# 2017-03-10 21:01:47.052499: step 2400, loss = 1.70, accuracy = 0.70 (535.2 examples/sec; 0.239 sec/batch)
# 2017-03-10 21:01:49.447599: step 2410, loss = 1.43, accuracy = 0.79 (523.4 examples/sec; 0.245 sec/batch)
# 2017-03-10 21:01:51.775110: step 2420, loss = 1.61, accuracy = 0.68 (609.5 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:01:54.189678: step 2430, loss = 1.54, accuracy = 0.68 (505.0 examples/sec; 0.253 sec/batch)
# 2017-03-10 21:01:56.510698: step 2440, loss = 1.38, accuracy = 0.77 (578.3 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:01:58.918580: step 2450, loss = 1.57, accuracy = 0.72 (560.7 examples/sec; 0.228 sec/batch)
# 2017-03-10 21:02:01.103045: step 2460, loss = 1.76, accuracy = 0.59 (609.5 examples/sec; 0.210 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2470 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:02:03.226653: step 2470, loss = 1.41, accuracy = 0.77 (1391.9 examples/sec; 0.092 sec/batch)
# 2017-03-10 21:02:05.306402: step 2480, loss = 1.41, accuracy = 0.75 (614.0 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:02:07.408957: step 2490, loss = 1.41, accuracy = 0.73 (594.9 examples/sec; 0.215 sec/batch)
# INFO:tensorflow:global_step/sec: 4.45319
# 2017-03-10 21:02:09.508483: step 2500, loss = 1.25, accuracy = 0.80 (605.8 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:02:11.603830: step 2510, loss = 1.52, accuracy = 0.69 (629.3 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:02:13.699560: step 2520, loss = 1.57, accuracy = 0.71 (606.9 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:02:15.784951: step 2530, loss = 1.59, accuracy = 0.68 (612.5 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:02:17.889106: step 2540, loss = 1.37, accuracy = 0.79 (618.6 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:02:19.999705: step 2550, loss = 1.44, accuracy = 0.71 (619.1 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:02:22.113168: step 2560, loss = 1.42, accuracy = 0.73 (654.3 examples/sec; 0.196 sec/batch)
# 2017-03-10 21:02:24.226946: step 2570, loss = 1.31, accuracy = 0.77 (617.2 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:02:26.345215: step 2580, loss = 1.41, accuracy = 0.74 (612.7 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:02:28.490324: step 2590, loss = 1.68, accuracy = 0.71 (610.5 examples/sec; 0.210 sec/batch)
# INFO:tensorflow:global_step/sec: 4.69412
# 2017-03-10 21:02:30.811808: step 2600, loss = 1.55, accuracy = 0.63 (484.1 examples/sec; 0.264 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2611 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:02:33.361799: step 2610, loss = 1.42, accuracy = 0.68 (302.9 examples/sec; 0.423 sec/batch)
# 2017-03-10 21:02:35.635111: step 2620, loss = 1.30, accuracy = 0.78 (510.1 examples/sec; 0.251 sec/batch)
# 2017-03-10 21:02:38.028109: step 2630, loss = 1.27, accuracy = 0.80 (516.4 examples/sec; 0.248 sec/batch)
# 2017-03-10 21:02:40.475593: step 2640, loss = 1.27, accuracy = 0.78 (519.5 examples/sec; 0.246 sec/batch)
# 2017-03-10 21:02:42.825887: step 2650, loss = 1.53, accuracy = 0.67 (534.0 examples/sec; 0.240 sec/batch)
# 2017-03-10 21:02:44.953794: step 2660, loss = 1.37, accuracy = 0.72 (569.2 examples/sec; 0.225 sec/batch)
# 2017-03-10 21:02:47.051915: step 2670, loss = 1.30, accuracy = 0.75 (600.9 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:02:49.150147: step 2680, loss = 1.33, accuracy = 0.73 (636.1 examples/sec; 0.201 sec/batch)
# 2017-03-10 21:02:51.237548: step 2690, loss = 1.28, accuracy = 0.76 (619.9 examples/sec; 0.206 sec/batch)
# INFO:tensorflow:global_step/sec: 4.43714
# 2017-03-10 21:02:53.348690: step 2700, loss = 1.33, accuracy = 0.75 (592.6 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:02:55.444140: step 2710, loss = 1.32, accuracy = 0.73 (592.1 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:02:57.559164: step 2720, loss = 1.48, accuracy = 0.65 (596.6 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:02:59.653768: step 2730, loss = 1.40, accuracy = 0.75 (600.4 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:03:01.742058: step 2740, loss = 1.34, accuracy = 0.68 (590.8 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2748 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:03:03.840884: step 2750, loss = 1.39, accuracy = 0.74 (617.5 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:03:05.948398: step 2760, loss = 1.22, accuracy = 0.77 (654.3 examples/sec; 0.196 sec/batch)
# 2017-03-10 21:03:08.073294: step 2770, loss = 1.19, accuracy = 0.81 (618.3 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:03:10.193882: step 2780, loss = 1.33, accuracy = 0.73 (631.0 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:03:12.327680: step 2790, loss = 1.29, accuracy = 0.75 (603.9 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.67865
# 2017-03-10 21:03:14.724262: step 2800, loss = 1.09, accuracy = 0.84 (540.3 examples/sec; 0.237 sec/batch)
# 2017-03-10 21:03:17.139357: step 2810, loss = 1.20, accuracy = 0.77 (487.7 examples/sec; 0.262 sec/batch)
# 2017-03-10 21:03:19.527821: step 2820, loss = 1.18, accuracy = 0.81 (605.7 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:03:21.890635: step 2830, loss = 1.19, accuracy = 0.79 (575.4 examples/sec; 0.222 sec/batch)
# 2017-03-10 21:03:24.205133: step 2840, loss = 1.30, accuracy = 0.76 (525.7 examples/sec; 0.243 sec/batch)
# 2017-03-10 21:03:26.558087: step 2850, loss = 1.45, accuracy = 0.70 (558.9 examples/sec; 0.229 sec/batch)
# 2017-03-10 21:03:28.683560: step 2860, loss = 1.17, accuracy = 0.77 (578.0 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:03:30.770985: step 2870, loss = 1.26, accuracy = 0.74 (647.6 examples/sec; 0.198 sec/batch)
# 2017-03-10 21:03:32.891676: step 2880, loss = 1.14, accuracy = 0.80 (629.8 examples/sec; 0.203 sec/batch)
# INFO:tensorflow:Saving checkpoints for 2883 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:03:35.001870: step 2890, loss = 1.35, accuracy = 0.75 (622.8 examples/sec; 0.206 sec/batch)
# INFO:tensorflow:global_step/sec: 4.46625
# 2017-03-10 21:03:37.112528: step 2900, loss = 1.16, accuracy = 0.78 (598.5 examples/sec; 0.214 sec/batch)
# 2017-03-10 21:03:39.221339: step 2910, loss = 1.14, accuracy = 0.76 (593.0 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:03:41.317344: step 2920, loss = 1.34, accuracy = 0.73 (603.3 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:03:43.410621: step 2930, loss = 1.28, accuracy = 0.76 (618.7 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:03:45.517953: step 2940, loss = 1.37, accuracy = 0.70 (602.1 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:03:47.621907: step 2950, loss = 1.37, accuracy = 0.72 (593.3 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:03:49.716340: step 2960, loss = 1.00, accuracy = 0.80 (608.2 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:03:51.810900: step 2970, loss = 1.26, accuracy = 0.73 (605.2 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:03:53.935438: step 2980, loss = 1.15, accuracy = 0.79 (608.9 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:03:56.062481: step 2990, loss = 1.40, accuracy = 0.66 (619.0 examples/sec; 0.207 sec/batch)
# INFO:tensorflow:global_step/sec: 4.6876
# 2017-03-10 21:03:58.445081: step 3000, loss = 1.19, accuracy = 0.77 (549.1 examples/sec; 0.233 sec/batch)
# 2017-03-10 21:04:00.822874: step 3010, loss = 1.17, accuracy = 0.78 (511.9 examples/sec; 0.250 sec/batch)
# 2017-03-10 21:04:03.144722: step 3020, loss = 1.15, accuracy = 0.76 (568.8 examples/sec; 0.225 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3022 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:04:05.577891: step 3030, loss = 1.17, accuracy = 0.80 (496.1 examples/sec; 0.258 sec/batch)
# 2017-03-10 21:04:07.891585: step 3040, loss = 1.10, accuracy = 0.80 (572.2 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:04:10.240730: step 3050, loss = 1.31, accuracy = 0.73 (564.0 examples/sec; 0.227 sec/batch)
# 2017-03-10 21:04:12.361268: step 3060, loss = 1.24, accuracy = 0.71 (602.3 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:04:14.477387: step 3070, loss = 1.26, accuracy = 0.71 (601.8 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:04:16.588192: step 3080, loss = 1.07, accuracy = 0.81 (584.2 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:04:18.698633: step 3090, loss = 1.18, accuracy = 0.75 (604.4 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.47388
# 2017-03-10 21:04:20.798310: step 3100, loss = 1.18, accuracy = 0.75 (598.3 examples/sec; 0.214 sec/batch)
# 2017-03-10 21:04:22.910301: step 3110, loss = 1.35, accuracy = 0.68 (578.5 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:04:24.997002: step 3120, loss = 1.16, accuracy = 0.80 (623.0 examples/sec; 0.205 sec/batch)
# 2017-03-10 21:04:27.085688: step 3130, loss = 1.15, accuracy = 0.74 (653.4 examples/sec; 0.196 sec/batch)
# 2017-03-10 21:04:29.195915: step 3140, loss = 1.07, accuracy = 0.77 (603.0 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:04:31.307485: step 3150, loss = 1.31, accuracy = 0.68 (580.1 examples/sec; 0.221 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3161 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:04:33.555188: step 3160, loss = 1.12, accuracy = 0.80 (363.3 examples/sec; 0.352 sec/batch)
# 2017-03-10 21:04:35.506327: step 3170, loss = 1.11, accuracy = 0.75 (629.2 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:04:37.601627: step 3180, loss = 1.11, accuracy = 0.78 (613.5 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:04:39.732329: step 3190, loss = 1.22, accuracy = 0.73 (580.6 examples/sec; 0.220 sec/batch)
# INFO:tensorflow:global_step/sec: 4.70271
# 2017-03-10 21:04:42.061361: step 3200, loss = 1.16, accuracy = 0.79 (552.4 examples/sec; 0.232 sec/batch)
# 2017-03-10 21:04:44.455349: step 3210, loss = 1.23, accuracy = 0.77 (508.3 examples/sec; 0.252 sec/batch)
# 2017-03-10 21:04:46.799635: step 3220, loss = 1.32, accuracy = 0.70 (523.7 examples/sec; 0.244 sec/batch)
# 2017-03-10 21:04:49.126296: step 3230, loss = 1.17, accuracy = 0.71 (629.3 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:04:51.568516: step 3240, loss = 1.22, accuracy = 0.73 (565.0 examples/sec; 0.227 sec/batch)
# 2017-03-10 21:04:53.909513: step 3250, loss = 1.34, accuracy = 0.67 (560.2 examples/sec; 0.228 sec/batch)
# 2017-03-10 21:04:56.059189: step 3260, loss = 1.22, accuracy = 0.75 (578.9 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:04:58.155488: step 3270, loss = 1.24, accuracy = 0.73 (583.5 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:05:00.249472: step 3280, loss = 1.46, accuracy = 0.68 (671.8 examples/sec; 0.191 sec/batch)
# 2017-03-10 21:05:02.369698: step 3290, loss = 1.14, accuracy = 0.77 (581.0 examples/sec; 0.220 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3296 into cifar10_trial_train/model.ckpt.
# INFO:tensorflow:global_step/sec: 4.45419
# 2017-03-10 21:05:04.512931: step 3300, loss = 1.14, accuracy = 0.72 (628.6 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:05:06.605025: step 3310, loss = 1.17, accuracy = 0.74 (602.8 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:05:08.694596: step 3320, loss = 1.02, accuracy = 0.81 (603.6 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:05:10.788357: step 3330, loss = 1.25, accuracy = 0.71 (614.1 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:05:12.882759: step 3340, loss = 1.00, accuracy = 0.80 (612.4 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:05:14.973512: step 3350, loss = 1.03, accuracy = 0.78 (603.8 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:05:17.067577: step 3360, loss = 1.17, accuracy = 0.71 (582.1 examples/sec; 0.220 sec/batch)
# 2017-03-10 21:05:19.151450: step 3370, loss = 1.01, accuracy = 0.80 (611.6 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:05:21.236894: step 3380, loss = 1.06, accuracy = 0.76 (628.9 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:05:23.328693: step 3390, loss = 1.29, accuracy = 0.73 (624.7 examples/sec; 0.205 sec/batch)
# INFO:tensorflow:global_step/sec: 4.72669
# 2017-03-10 21:05:25.668641: step 3400, loss = 1.08, accuracy = 0.78 (538.0 examples/sec; 0.238 sec/batch)
# 2017-03-10 21:05:27.954886: step 3410, loss = 1.15, accuracy = 0.74 (538.8 examples/sec; 0.238 sec/batch)
# 2017-03-10 21:05:30.358258: step 3420, loss = 1.10, accuracy = 0.73 (509.6 examples/sec; 0.251 sec/batch)
# 2017-03-10 21:05:32.638699: step 3430, loss = 1.12, accuracy = 0.79 (583.4 examples/sec; 0.219 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3435 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:05:35.053727: step 3440, loss = 1.15, accuracy = 0.77 (545.3 examples/sec; 0.235 sec/batch)
# 2017-03-10 21:05:37.413863: step 3450, loss = 1.28, accuracy = 0.73 (547.4 examples/sec; 0.234 sec/batch)
# 2017-03-10 21:05:39.543820: step 3460, loss = 1.13, accuracy = 0.78 (619.1 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:05:41.650222: step 3470, loss = 1.02, accuracy = 0.77 (632.5 examples/sec; 0.202 sec/batch)
# 2017-03-10 21:05:43.755242: step 3480, loss = 1.12, accuracy = 0.74 (610.3 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:05:45.862958: step 3490, loss = 1.00, accuracy = 0.80 (636.8 examples/sec; 0.201 sec/batch)
# INFO:tensorflow:global_step/sec: 4.48681
# 2017-03-10 21:05:47.956266: step 3500, loss = 1.08, accuracy = 0.77 (610.4 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:05:50.073671: step 3510, loss = 0.95, accuracy = 0.81 (585.5 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:05:52.154554: step 3520, loss = 0.90, accuracy = 0.82 (588.9 examples/sec; 0.217 sec/batch)
# 2017-03-10 21:05:54.256448: step 3530, loss = 1.00, accuracy = 0.84 (605.1 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:05:56.347636: step 3540, loss = 0.97, accuracy = 0.80 (614.1 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:05:58.434610: step 3550, loss = 1.21, accuracy = 0.74 (608.2 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:06:00.521925: step 3560, loss = 1.12, accuracy = 0.75 (610.9 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:06:02.613616: step 3570, loss = 1.10, accuracy = 0.73 (600.1 examples/sec; 0.213 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3576 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:06:04.717793: step 3580, loss = 0.97, accuracy = 0.79 (621.4 examples/sec; 0.206 sec/batch)
# 2017-03-10 21:06:06.833889: step 3590, loss = 1.16, accuracy = 0.73 (561.5 examples/sec; 0.228 sec/batch)
# INFO:tensorflow:global_step/sec: 4.72131
# 2017-03-10 21:06:09.138933: step 3600, loss = 1.19, accuracy = 0.73 (523.4 examples/sec; 0.245 sec/batch)
# 2017-03-10 21:06:11.455607: step 3610, loss = 1.13, accuracy = 0.70 (571.8 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:06:13.802485: step 3620, loss = 1.05, accuracy = 0.77 (529.0 examples/sec; 0.242 sec/batch)
# 2017-03-10 21:06:16.105802: step 3630, loss = 1.06, accuracy = 0.75 (514.3 examples/sec; 0.249 sec/batch)
# 2017-03-10 21:06:18.512390: step 3640, loss = 0.95, accuracy = 0.78 (496.7 examples/sec; 0.258 sec/batch)
# 2017-03-10 21:06:20.905205: step 3650, loss = 0.98, accuracy = 0.79 (508.4 examples/sec; 0.252 sec/batch)
# 2017-03-10 21:06:23.060527: step 3660, loss = 1.08, accuracy = 0.76 (640.2 examples/sec; 0.200 sec/batch)
# 2017-03-10 21:06:25.161038: step 3670, loss = 0.99, accuracy = 0.78 (615.4 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:06:27.296648: step 3680, loss = 1.09, accuracy = 0.76 (581.7 examples/sec; 0.220 sec/batch)
# 2017-03-10 21:06:29.421533: step 3690, loss = 0.98, accuracy = 0.80 (593.2 examples/sec; 0.216 sec/batch)
# INFO:tensorflow:global_step/sec: 4.46169
# 2017-03-10 21:06:31.551622: step 3700, loss = 0.98, accuracy = 0.80 (590.3 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3711 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:06:33.827168: step 3710, loss = 1.06, accuracy = 0.77 (348.1 examples/sec; 0.368 sec/batch)
# 2017-03-10 21:06:35.823303: step 3720, loss = 0.99, accuracy = 0.81 (584.1 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:06:37.956511: step 3730, loss = 0.93, accuracy = 0.79 (593.7 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:06:40.085406: step 3740, loss = 1.03, accuracy = 0.79 (641.9 examples/sec; 0.199 sec/batch)
# 2017-03-10 21:06:42.235211: step 3750, loss = 1.16, accuracy = 0.73 (585.3 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:06:44.367570: step 3760, loss = 0.81, accuracy = 0.84 (601.8 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:06:46.500190: step 3770, loss = 0.99, accuracy = 0.77 (615.0 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:06:48.632197: step 3780, loss = 1.03, accuracy = 0.78 (589.4 examples/sec; 0.217 sec/batch)
# 2017-03-10 21:06:50.768003: step 3790, loss = 1.18, accuracy = 0.71 (603.2 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.63657
# 2017-03-10 21:06:53.117520: step 3800, loss = 0.87, accuracy = 0.83 (525.2 examples/sec; 0.244 sec/batch)
# 2017-03-10 21:06:55.576620: step 3810, loss = 1.13, accuracy = 0.75 (480.6 examples/sec; 0.266 sec/batch)
# 2017-03-10 21:06:57.890028: step 3820, loss = 1.10, accuracy = 0.74 (613.7 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:07:00.219894: step 3830, loss = 0.89, accuracy = 0.80 (562.4 examples/sec; 0.228 sec/batch)
# 2017-03-10 21:07:02.596590: step 3840, loss = 0.85, accuracy = 0.83 (559.7 examples/sec; 0.229 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3846 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:07:04.976023: step 3850, loss = 0.91, accuracy = 0.77 (603.6 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:07:07.108091: step 3860, loss = 1.01, accuracy = 0.79 (610.9 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:07:09.208894: step 3870, loss = 1.10, accuracy = 0.76 (629.4 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:07:11.322811: step 3880, loss = 1.07, accuracy = 0.72 (589.7 examples/sec; 0.217 sec/batch)
# 2017-03-10 21:07:13.490146: step 3890, loss = 0.94, accuracy = 0.81 (580.6 examples/sec; 0.220 sec/batch)
# INFO:tensorflow:global_step/sec: 4.44178
# 2017-03-10 21:07:15.631655: step 3900, loss = 0.96, accuracy = 0.78 (570.5 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:07:17.764646: step 3910, loss = 1.09, accuracy = 0.73 (584.2 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:07:19.891649: step 3920, loss = 1.03, accuracy = 0.77 (596.6 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:07:22.032948: step 3930, loss = 1.06, accuracy = 0.73 (586.4 examples/sec; 0.218 sec/batch)
# 2017-03-10 21:07:24.160199: step 3940, loss = 1.12, accuracy = 0.73 (586.5 examples/sec; 0.218 sec/batch)
# 2017-03-10 21:07:26.288389: step 3950, loss = 1.03, accuracy = 0.79 (626.2 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:07:28.435137: step 3960, loss = 0.82, accuracy = 0.82 (595.7 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:07:30.569956: step 3970, loss = 1.01, accuracy = 0.76 (630.5 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:07:32.729857: step 3980, loss = 0.87, accuracy = 0.79 (579.6 examples/sec; 0.221 sec/batch)
# INFO:tensorflow:Saving checkpoints for 3986 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:07:34.904602: step 3990, loss = 1.20, accuracy = 0.74 (495.8 examples/sec; 0.258 sec/batch)
# INFO:tensorflow:global_step/sec: 4.62696
# 2017-03-10 21:07:37.243423: step 4000, loss = 1.01, accuracy = 0.76 (598.5 examples/sec; 0.214 sec/batch)
# 2017-03-10 21:07:39.602091: step 4010, loss = 1.00, accuracy = 0.73 (504.8 examples/sec; 0.254 sec/batch)
# 2017-03-10 21:07:41.951132: step 4020, loss = 0.99, accuracy = 0.80 (561.7 examples/sec; 0.228 sec/batch)
# 2017-03-10 21:07:44.272734: step 4030, loss = 1.06, accuracy = 0.77 (573.5 examples/sec; 0.223 sec/batch)
# 2017-03-10 21:07:46.640464: step 4040, loss = 1.05, accuracy = 0.74 (496.6 examples/sec; 0.258 sec/batch)
# 2017-03-10 21:07:49.011952: step 4050, loss = 0.94, accuracy = 0.76 (554.8 examples/sec; 0.231 sec/batch)
# 2017-03-10 21:07:51.105252: step 4060, loss = 0.91, accuracy = 0.81 (619.0 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:07:53.222991: step 4070, loss = 0.99, accuracy = 0.80 (571.7 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:07:55.322599: step 4080, loss = 1.13, accuracy = 0.73 (571.2 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:07:57.411369: step 4090, loss = 1.09, accuracy = 0.73 (614.8 examples/sec; 0.208 sec/batch)
# INFO:tensorflow:global_step/sec: 4.47693
# 2017-03-10 21:07:59.580546: step 4100, loss = 0.82, accuracy = 0.81 (548.8 examples/sec; 0.233 sec/batch)
# 2017-03-10 21:08:01.694716: step 4110, loss = 0.91, accuracy = 0.80 (618.7 examples/sec; 0.207 sec/batch)
# INFO:tensorflow:Saving checkpoints for 4121 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:08:03.975383: step 4120, loss = 0.97, accuracy = 0.77 (353.1 examples/sec; 0.363 sec/batch)
# 2017-03-10 21:08:05.986789: step 4130, loss = 0.87, accuracy = 0.81 (599.4 examples/sec; 0.214 sec/batch)
# ...
# 2017-03-10 21:15:09.495643: step 6050, loss = 0.82, accuracy = 0.80 (594.8 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:15:11.655184: step 6060, loss = 0.76, accuracy = 0.84 (611.3 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:15:13.829866: step 6070, loss = 0.71, accuracy = 0.84 (581.6 examples/sec; 0.220 sec/batch)
# 2017-03-10 21:15:15.996551: step 6080, loss = 0.61, accuracy = 0.90 (558.6 examples/sec; 0.229 sec/batch)
# 2017-03-10 21:15:18.142635: step 6090, loss = 0.77, accuracy = 0.80 (582.1 examples/sec; 0.220 sec/batch)
# INFO:tensorflow:global_step/sec: 4.47543
# 2017-03-10 21:15:20.290190: step 6100, loss = 0.86, accuracy = 0.77 (594.2 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:15:22.439940: step 6110, loss = 0.88, accuracy = 0.77 (644.2 examples/sec; 0.199 sec/batch)
# 2017-03-10 21:15:24.598321: step 6120, loss = 0.99, accuracy = 0.77 (568.1 examples/sec; 0.225 sec/batch)
# 2017-03-10 21:15:26.758977: step 6130, loss = 0.88, accuracy = 0.78 (574.2 examples/sec; 0.223 sec/batch)
# 2017-03-10 21:15:28.922156: step 6140, loss = 0.77, accuracy = 0.84 (591.6 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:15:31.075281: step 6150, loss = 0.92, accuracy = 0.73 (598.1 examples/sec; 0.214 sec/batch)
# 2017-03-10 21:15:33.240299: step 6160, loss = 0.86, accuracy = 0.77 (578.3 examples/sec; 0.221 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6171 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:15:35.567154: step 6170, loss = 1.06, accuracy = 0.76 (324.1 examples/sec; 0.395 sec/batch)
# 2017-03-10 21:15:37.803264: step 6180, loss = 0.87, accuracy = 0.80 (578.8 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:15:40.106042: step 6190, loss = 0.93, accuracy = 0.78 (554.0 examples/sec; 0.231 sec/batch)
# INFO:tensorflow:global_step/sec: 4.49498
# 2017-03-10 21:15:42.535223: step 6200, loss = 0.80, accuracy = 0.80 (512.8 examples/sec; 0.250 sec/batch)
# 2017-03-10 21:15:44.943443: step 6210, loss = 0.88, accuracy = 0.79 (625.3 examples/sec; 0.205 sec/batch)
# 2017-03-10 21:15:47.388461: step 6220, loss = 0.80, accuracy = 0.83 (519.2 examples/sec; 0.247 sec/batch)
# 2017-03-10 21:15:49.680691: step 6230, loss = 0.67, accuracy = 0.84 (575.3 examples/sec; 0.222 sec/batch)
# 2017-03-10 21:15:51.809415: step 6240, loss = 0.77, accuracy = 0.80 (587.2 examples/sec; 0.218 sec/batch)
# 2017-03-10 21:15:53.935723: step 6250, loss = 0.73, accuracy = 0.84 (635.2 examples/sec; 0.202 sec/batch)
# 2017-03-10 21:15:56.081162: step 6260, loss = 0.89, accuracy = 0.77 (565.3 examples/sec; 0.226 sec/batch)
# 2017-03-10 21:15:58.220732: step 6270, loss = 0.74, accuracy = 0.82 (627.3 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:16:00.363308: step 6280, loss = 0.64, accuracy = 0.86 (579.3 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:16:02.524580: step 6290, loss = 0.61, accuracy = 0.85 (614.6 examples/sec; 0.208 sec/batch)
# INFO:tensorflow:global_step/sec: 4.51797
# 2017-03-10 21:16:04.669534: step 6300, loss = 0.86, accuracy = 0.78 (585.7 examples/sec; 0.219 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6305 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:16:06.829815: step 6310, loss = 0.67, accuracy = 0.86 (601.3 examples/sec; 0.213 sec/batch)
# 2017-03-10 21:16:08.985515: step 6320, loss = 0.72, accuracy = 0.84 (589.1 examples/sec; 0.217 sec/batch)
# 2017-03-10 21:16:11.167492: step 6330, loss = 0.66, accuracy = 0.88 (567.7 examples/sec; 0.225 sec/batch)
# 2017-03-10 21:16:13.338270: step 6340, loss = 0.69, accuracy = 0.83 (627.2 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:16:15.541093: step 6350, loss = 0.79, accuracy = 0.78 (563.5 examples/sec; 0.227 sec/batch)
# 2017-03-10 21:16:17.840094: step 6360, loss = 0.74, accuracy = 0.84 (545.0 examples/sec; 0.235 sec/batch)
# 2017-03-10 21:16:20.208949: step 6370, loss = 0.83, accuracy = 0.79 (593.1 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:16:22.608101: step 6380, loss = 0.75, accuracy = 0.79 (518.5 examples/sec; 0.247 sec/batch)
# 2017-03-10 21:16:25.004960: step 6390, loss = 0.71, accuracy = 0.83 (519.9 examples/sec; 0.246 sec/batch)
# INFO:tensorflow:global_step/sec: 4.41356
# 2017-03-10 21:16:27.326793: step 6400, loss = 0.58, accuracy = 0.85 (545.5 examples/sec; 0.235 sec/batch)
# 2017-03-10 21:16:29.781778: step 6410, loss = 0.94, accuracy = 0.75 (521.3 examples/sec; 0.246 sec/batch)
# 2017-03-10 21:16:32.012423: step 6420, loss = 0.80, accuracy = 0.78 (589.1 examples/sec; 0.217 sec/batch)
# 2017-03-10 21:16:34.136866: step 6430, loss = 0.85, accuracy = 0.75 (588.7 examples/sec; 0.217 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6438 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:16:36.299345: step 6440, loss = 0.78, accuracy = 0.80 (613.4 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:16:38.426545: step 6450, loss = 0.92, accuracy = 0.73 (615.3 examples/sec; 0.208 sec/batch)
# 2017-03-10 21:16:40.570860: step 6460, loss = 0.75, accuracy = 0.84 (585.3 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:16:42.695168: step 6470, loss = 0.80, accuracy = 0.80 (582.8 examples/sec; 0.220 sec/batch)
# 2017-03-10 21:16:44.836390: step 6480, loss = 0.92, accuracy = 0.75 (584.6 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:16:46.973335: step 6490, loss = 0.65, accuracy = 0.84 (605.1 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.59398
# 2017-03-10 21:16:49.094751: step 6500, loss = 0.94, accuracy = 0.75 (618.2 examples/sec; 0.207 sec/batch)
# 2017-03-10 21:16:51.228098: step 6510, loss = 0.74, accuracy = 0.82 (561.4 examples/sec; 0.228 sec/batch)
# 2017-03-10 21:16:53.354231: step 6520, loss = 0.76, accuracy = 0.83 (570.6 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:16:55.483942: step 6530, loss = 0.76, accuracy = 0.82 (623.4 examples/sec; 0.205 sec/batch)
# 2017-03-10 21:16:57.607734: step 6540, loss = 0.79, accuracy = 0.76 (609.7 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:16:59.781085: step 6550, loss = 0.80, accuracy = 0.77 (613.0 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:17:02.161372: step 6560, loss = 0.86, accuracy = 0.75 (483.1 examples/sec; 0.265 sec/batch)
# 2017-03-10 21:17:04.553363: step 6570, loss = 0.87, accuracy = 0.77 (617.9 examples/sec; 0.207 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6576 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:17:07.015122: step 6580, loss = 0.71, accuracy = 0.81 (511.5 examples/sec; 0.250 sec/batch)
# 2017-03-10 21:17:09.441820: step 6590, loss = 0.74, accuracy = 0.79 (524.5 examples/sec; 0.244 sec/batch)
# INFO:tensorflow:global_step/sec: 4.40602
# 2017-03-10 21:17:11.790551: step 6600, loss = 0.84, accuracy = 0.79 (611.2 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:17:14.178330: step 6610, loss = 0.71, accuracy = 0.81 (499.0 examples/sec; 0.257 sec/batch)
# 2017-03-10 21:17:16.295776: step 6620, loss = 0.85, accuracy = 0.77 (610.8 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:17:18.421178: step 6630, loss = 0.75, accuracy = 0.86 (596.0 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:17:20.556401: step 6640, loss = 0.83, accuracy = 0.80 (609.8 examples/sec; 0.210 sec/batch)
# 2017-03-10 21:17:22.679869: step 6650, loss = 0.66, accuracy = 0.86 (612.7 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:17:24.824628: step 6660, loss = 0.82, accuracy = 0.82 (611.6 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:17:26.962250: step 6670, loss = 0.69, accuracy = 0.84 (607.6 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:17:29.094024: step 6680, loss = 0.72, accuracy = 0.84 (584.3 examples/sec; 0.219 sec/batch)
# 2017-03-10 21:17:31.205707: step 6690, loss = 0.75, accuracy = 0.81 (604.8 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.64104
# 2017-03-10 21:17:33.338634: step 6700, loss = 0.73, accuracy = 0.82 (594.9 examples/sec; 0.215 sec/batch)
# 2017-03-10 21:17:35.470661: step 6710, loss = 0.68, accuracy = 0.84 (601.2 examples/sec; 0.213 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6713 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:17:37.610288: step 6720, loss = 0.71, accuracy = 0.86 (606.6 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:17:39.729204: step 6730, loss = 0.65, accuracy = 0.88 (592.5 examples/sec; 0.216 sec/batch)
# 2017-03-10 21:17:41.858493: step 6740, loss = 0.69, accuracy = 0.83 (580.4 examples/sec; 0.221 sec/batch)
# 2017-03-10 21:17:43.985711: step 6750, loss = 0.78, accuracy = 0.81 (606.5 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:17:46.390827: step 6760, loss = 0.77, accuracy = 0.81 (513.4 examples/sec; 0.249 sec/batch)
# 2017-03-10 21:17:48.795065: step 6770, loss = 0.82, accuracy = 0.82 (511.8 examples/sec; 0.250 sec/batch)
# 2017-03-10 21:17:51.226356: step 6780, loss = 0.81, accuracy = 0.83 (560.2 examples/sec; 0.228 sec/batch)
# 2017-03-10 21:17:53.635342: step 6790, loss = 0.69, accuracy = 0.82 (630.7 examples/sec; 0.203 sec/batch)
# INFO:tensorflow:global_step/sec: 4.40948
# 2017-03-10 21:17:56.016130: step 6800, loss = 0.87, accuracy = 0.78 (511.6 examples/sec; 0.250 sec/batch)
# 2017-03-10 21:17:58.388105: step 6810, loss = 0.86, accuracy = 0.77 (589.5 examples/sec; 0.217 sec/batch)
# 2017-03-10 21:18:00.549918: step 6820, loss = 0.71, accuracy = 0.81 (563.0 examples/sec; 0.227 sec/batch)
# 2017-03-10 21:18:02.983871: step 6830, loss = 0.76, accuracy = 0.80 (586.7 examples/sec; 0.218 sec/batch)
# 2017-03-10 21:18:05.500501: step 6840, loss = 0.66, accuracy = 0.88 (532.8 examples/sec; 0.240 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6843 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:18:07.983901: step 6850, loss = 0.77, accuracy = 0.84 (527.5 examples/sec; 0.243 sec/batch)
# 2017-03-10 21:18:10.413527: step 6860, loss = 0.85, accuracy = 0.79 (531.8 examples/sec; 0.241 sec/batch)
# 2017-03-10 21:18:12.853643: step 6870, loss = 0.91, accuracy = 0.74 (556.9 examples/sec; 0.230 sec/batch)
# 2017-03-10 21:18:15.214360: step 6880, loss = 0.94, accuracy = 0.77 (574.6 examples/sec; 0.223 sec/batch)
# 2017-03-10 21:18:17.342268: step 6890, loss = 0.65, accuracy = 0.86 (613.2 examples/sec; 0.209 sec/batch)
# INFO:tensorflow:global_step/sec: 4.26105
# 2017-03-10 21:18:19.484298: step 6900, loss = 0.73, accuracy = 0.81 (613.3 examples/sec; 0.209 sec/batch)
# 2017-03-10 21:18:21.604486: step 6910, loss = 0.73, accuracy = 0.84 (634.2 examples/sec; 0.202 sec/batch)
# 2017-03-10 21:18:23.750599: step 6920, loss = 0.73, accuracy = 0.84 (630.7 examples/sec; 0.203 sec/batch)
# 2017-03-10 21:18:25.873475: step 6930, loss = 0.73, accuracy = 0.84 (628.4 examples/sec; 0.204 sec/batch)
# 2017-03-10 21:18:28.339853: step 6940, loss = 0.74, accuracy = 0.82 (516.0 examples/sec; 0.248 sec/batch)
# 2017-03-10 21:18:30.788098: step 6950, loss = 0.86, accuracy = 0.80 (465.1 examples/sec; 0.275 sec/batch)
# 2017-03-10 21:18:33.236608: step 6960, loss = 0.81, accuracy = 0.81 (535.5 examples/sec; 0.239 sec/batch)
# 2017-03-10 21:18:35.659968: step 6970, loss = 0.72, accuracy = 0.81 (518.2 examples/sec; 0.247 sec/batch)
# INFO:tensorflow:Saving checkpoints for 6973 into cifar10_trial_train/model.ckpt.
# 2017-03-10 21:18:38.120272: step 6980, loss = 0.68, accuracy = 0.84 (552.8 examples/sec; 0.232 sec/batch)
# 2017-03-10 21:18:40.525363: step 6990, loss = 0.72, accuracy = 0.81 (605.0 examples/sec; 0.212 sec/batch)
# INFO:tensorflow:global_step/sec: 4.31936
# 2017-03-10 21:18:42.637630: step 7000, loss = 0.75, accuracy = 0.78 (603.8 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:18:44.794120: step 7010, loss = 0.91, accuracy = 0.79 (574.1 examples/sec; 0.223 sec/batch)
# 2017-03-10 21:18:46.935703: step 7020, loss = 0.84, accuracy = 0.80 (598.1 examples/sec; 0.214 sec/batch)
# 2017-03-10 21:18:49.103119: step 7030, loss = 0.80, accuracy = 0.77 (606.5 examples/sec; 0.211 sec/batch)
# 2017-03-10 21:18:51.277692: step 7040, loss = 0.76, accuracy = 0.80 (603.5 examples/sec; 0.212 sec/batch)
# 2017-03-10 21:18:53.450345: step 7050, loss = 0.75, accuracy = 0.83 (570.9 examples/sec; 0.224 sec/batch)
# 2017-03-10 21:18:55.633920: step 7060, loss = 0.60, accuracy = 0.85 (578.1 examples/sec; 0.221 sec/batch)
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-ba6beb78e35f> in <module>()
#      58                                                log_device_placement=log_device_placement)) as mon_sess:
#      59         while not mon_sess.should_stop():
# ---> 60             mon_sess.run(train_op)
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     460                           feed_dict=feed_dict,
#     461                           options=options,
# --> 462                           run_metadata=run_metadata)
#     463
#     464   def should_stop(self):
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     784                               feed_dict=feed_dict,
#     785                               options=options,
# --> 786                               run_metadata=run_metadata)
#     787       except errors.AbortedError:
#     788         logging.info('An AbortedError was raised. Closing the current session. '
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, *args, **kwargs)
#     742
#     743   def run(self, *args, **kwargs):
# --> 744     return self._sess.run(*args, **kwargs)
#     745
#     746
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     889                                   feed_dict=feed_dict,
#     890                                   options=options,
# --> 891                                   run_metadata=run_metadata)
#     892
#     893     for hook in self._hooks:
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/training/monitored_session.pyc in run(self, *args, **kwargs)
#     742
#     743   def run(self, *args, **kwargs):
# --> 744     return self._sess.run(*args, **kwargs)
#     745
#     746
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/ubuntu/miniconda2/envs/cifar/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import six

def evaluate():
  eval_batch_count = 50
  """Eval CIFAR-10 for a number of steps."""
  with tf.device('/cpu:0'):
      with tf.Graph().as_default() as g:
        # Get images and labels for CIFAR-10.
        images, labels = cifar_input.build_input('cifar10', 'cifar10/test_batch.bin', 128, 'eval')

        # Build a Graph that computes the logits predictions from the
        # inference model.
        logits = inference(images)
        saver = tf.train.Saver()
        #summary_writer = tf.summary.FileWriter(FLAGS.eval_dir)

        sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
        tf.train.start_queue_runners(sess)

        best_precision = 0.0
        try:
          ckpt_state = tf.train.get_checkpoint_state(train_dir)
        except tf.errors.OutOfRangeError as e:
          tf.logging.error('Cannot restore checkpoint: %s', e)
        if not (ckpt_state and ckpt_state.model_checkpoint_path):
          tf.logging.info('No model to eval yet at %s', train_dir)
        tf.logging.info('Loading checkpoint %s', ckpt_state.model_checkpoint_path)
        saver.restore(sess, ckpt_state.model_checkpoint_path)

        total_prediction, correct_prediction = 0, 0
        for _ in six.moves.range(eval_batch_count):
          (predictions, truth) = sess.run(
              [logits, labels])

          truth = np.argmax(truth, axis=1)
          predictions = np.argmax(predictions, axis=1)
          correct_prediction += np.sum(truth == predictions)
          total_prediction += predictions.shape[0]

        precision = 1.0 * correct_prediction / total_prediction
        best_precision = max(precision, best_precision)

        tf.logging.info('precision: %.3f, best precision: %.3f' %
                        (precision, best_precision))
        f = open("log.txt",'ab')
        f.write('precision: {0}, best precision: {1}'.format(precision, best_precision))
        f.close()

# %%
evaluate()
